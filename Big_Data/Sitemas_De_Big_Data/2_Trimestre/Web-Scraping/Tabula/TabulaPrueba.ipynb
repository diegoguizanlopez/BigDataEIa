# %%
import pandas as pd
from tabula import read_pdf

table = read_pdf("Contratos_JUNIO.pdf", pages='all',lattice=True,encoding="utf-8")

# %%
start = 2
multip = 3
dfs=[]
for i in range(int(len(table)/multip)):
    #dfs.append(table[int(multip*i+start)])
    #df = table[int(multip*i+start)]
    #df.iloc
    for j in table.

df = table[2]
df.iloc[:,2]

#table[2]
#table[5]
#table[8]
#table[11]
#table[14]
# Out:
# 0
# 1
# 2
# 3
# 4
#    Anuncio de formalización de contratos efectuados pola Excma. Deputación Provincial da Coruña do 01/06/2022 ao\r30/06/2022\rExpediente: 2022000038955\rCon arranxo ao disposto no artigo 154 da Lei 9/2017, do 8 de novembro, de Contratos do Sector Público) faise pública\ra relación de contratos formalizados por esta Deputación Provincial da Coruña do 1/06/2022 ao 30/06/2022.  \
# 0                                                EXP.
# 1                                  PCO.001.2022.00015
# 2                           PCO.001,2019.00053 LOTE 1
# 3                                  PCO.001.2020.00371
# 4                                  PCO.001.2022.00086
# 5                                  PCO.001.2021.00460
# 6                                  PCO.001.2017.00027
# 7        Número de anuncio\rPCO.001,2019,00053 LOTE 2
# 8                                  PCO.001.2022.00153
# 9                                  PCO.001.2022.00089
# 10                                 PCO.001.2022.00233
# 11                                 PCO.001.2022.00142
# 12                                                NaN
#
#                                            Unnamed: 0  Unnamed: 1  \
# 0                                            CONCEPTO      PTO. €
# 1   MELLORA DA INTERSEC-\rCIÓN DA DP 6121 MERA A\r...  392.811,01
# 2   ÚNICA PRORROGA DE LOS\rSERVICIOS DE TRANSPORTE...         NaN
# 3   REDACCIÓN DEL PROYECTO\rDE MEJORA DE SEGURIDAD...   18.918,50
# 4   DP 7603.- PAVIMENTACIÓN\rCON M.B.Q.; P.Q. 4+25...  448.457,71
# 5   CONTRATO DE DIGITALI-\rZACIÓN DE FONDOS DEL\rA...  102.801,60
# 6   SEGUNDA PRÓRROGA DEL\rCAFÉ-BAR EN EL MONAS-\rT...         NaN
# 7   ÚNICA PRÓRROGA DE\rS0ER2V2IC/OS4 D1E4 T0RANSPO...         NaN
# 8   OBRAS GRUPO 16 ARTEIXO,\rA CORUÑA E CULLEREDO\...  504.405,80
# 9   DP 1603 MELLORA CAPA\rRODAXE MBQ PQ 1+315 AO\r...  178.063,21
# 10         SERVICIO QUENDA Y OFICI-\rNA VIRTUAL CLOUD   23.716,00
# 11  OBRAS GRUPO 6 ARES,\rFENE, MUGARDOS E NEDA\rIN...  242.457,89
# 12                                                NaN         NaN
#
#                Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 0                 PREZO €  PRÓ-\rRROGA  MO-\rDIF.
# 1              379.062,62          NaN        NaN
# 2               60,000,00           SI        NaN
# 3               15.669,50          NaN        NaN
# 4              428.949,80          NaN        NaN
# 5               96.307,53          NaN        NaN
# 6   CANON ANUEAL\r5.000 €           SI        NaN
# 7               10,000,00           SI        NaN
# 8              482.766,79          NaN        NaN
# 9              174.056,78          NaN        NaN
# 10              22.281,72          NaN        NaN
# 11             230.456,22          NaN        NaN
# 12                    NaN          NaN        NaN
#
#                                            Unnamed: 5 Unnamed: 6  \
# 0                                          PROC. ADX.        NIF
# 1     ABERTO - CUN ÚNICO\rCRITERIO DE ADXUDI-\rCACIÓN  B70123005
# 2                                            PRÓRROGA  ***3624**
# 3   ABERTO - CON MÚL-\rTIPLES CRITERIOS DE\rADXUDI...  B85097962
# 4     ABERTO - CUN ÚNICO\rCRITERIO DE ADXUDI-\rCACIÓN  B32108334
# 5   ABERTO - CON MÚL-\rTIPLES CRITERIOS DE\rADXUDI...  A28989788
# 6                                            PRÓRROGA  ***4027**
# 7                                            PRÓRROGA  A27010651
# 8     ABERTO - CUN ÚNICO\rCRITERIO DE ADXUDI-\rCACIÓN  B32404972
# 9     ABERTO - CUN ÚNICO\rCRITERIO DE ADXUDI-\rCACIÓN  B15866965
# 10                     NEGOCIADO - SEN PU-\rBLICIDADE  B15726177
# 11    ABERTO - CUN ÚNICO\rCRITERIO DE ADXUDI-\rCACIÓN  B15293145
# 12                                                NaN        NaN
#
#                                Unnamed: 7    Unnamed: 8       Unnamed: 9  \
# 0                           ADXUDICATARIO  DATA\rAPROB.  DATA\rFORMALIZ.
# 1       JSTOP, OBRAS Y SERVI-\rCIOS, S.L.    27/05/2022       03/06/2022
# 2                 DAVID GARCÍA BO-\rQUETE    27/05/2022       03/06/2022
# 3   EPTISA SERVICIOS DE\rINGENIERIA, S.L.    27/05/2022       03/06/2022
# 4                         HORDESCON, S.L.    27/05/2022       03/06/2022
# 5                            VINFRA, S.A.    05/05/2022       03/06/2022
# 6                 CARMEN BLANCO\rSANJURJO    27/05/2022       03/06/2022
# 7           SEVERIANO SERVICIO\rMÓVIL,SAU    27/05/2022       03/06/2022
# 8        ASFALGAL TECNICAS\rVIARIAS, S.L.    24/05/2022       03/06/2022
# 9   CONSTRUCCIONES Y\rOBRAS ANDUJAR, S.L.    02/06/2022       09/06/2022
# 10              TECNOLOGIAS PLEXUS,\rS.L.    03/06/2022       09/06/2022
# 11   CONSTRUCCIONES\rPONCIANO NIETO, S.L.    07/06/2022       09/06/2022
# 12                                    NaN           NaN              NaN
#
#          Unnamed: 10
# 0   N.o\rCON-\rTRATO
# 1                 70
# 2                 71
# 3                 72
# 4                 73
# 5                 74
# 6                 75
# 7                 76
# 8                 77
# 9                 78
# 10                79
# 11                80
# 12               NaN
