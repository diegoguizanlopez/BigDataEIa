# %% [markdown]
# # ![pandas-logo-300.png](attachment:pandas-logo-300.png) PANDAS
#
# A continuación imos aprender como instalar a libraría PANDAS e faremos unha pequena introducción e referencia para futuras prácticas.

# %% [markdown]
# ## 🐍 Instalar a librería con conda
#
# Imaxinamos que temos unha contorna con nome **bigdata** con jupyterlab, ipython/ipykernel e librarías básicas instaladas.
#
# **(paso previo opcional)** Se queremos instalar por defecto de **conda-forge**:
#
#     conda config --env --add channels conda-forge
#
# Instalamos **numpy** e **pandas** (pandas debería desencadenar a instlación de numpy no caso que non estea xa instalado):
#
#     conda activate bigdata
#     conda install numpy pandas

# %% [markdown]
# ## Importar a libraría no código

# %%
import pandas as pd
import os

# %% [markdown]
# ## Abrir os arquivos CSV

# %%
path_base="C:/Users/USUARIO/Downloads/centros/"

df1 = pd.read_csv(f"{path_base}1.csv")
df2 = pd.read_csv(os.path.join(path_base, "2.csv") )

dfTotal = pd.concat([df1, df2])
