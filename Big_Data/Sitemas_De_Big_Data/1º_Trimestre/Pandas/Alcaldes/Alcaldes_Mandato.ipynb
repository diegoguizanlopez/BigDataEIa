# %% [markdown]
# # **ALCALDES**
#
# De los .XSLX sacados del gobierno se leerá los ficheros de una carpeta XSLX.
#
# Y se añadirá en una nueva columna los nombres limpiados en mayúsculas

# %%
import pathlib
XLSX=str(pathlib.Path().resolve())+"/XLSX"
from os import listdir
from os.path import isfile, join

ficherosXLSX = [f for f in listdir(XLSX) if isfile(join(XLSX, f))] #Tenemos en la variable ficherosXLSX la lista de ficheros de la carpeta

# %%
import pandas as pd


def cargaAlcaldes(archivo, columna, fila, cabecera, nombreHoja):
    return pd.read_excel(archivo, sheet_name=nombreHoja,
         names=cabecera, usecols=columna, skiprows=fila)

dfAlcaldes = pd.DataFrame([])

for fichero in ficherosXLSX:
    """
    Con los ficheros leidos en el paso anterior se leerá de 1 en 1 de la lista con el método de cargaAlcaldes
    """
    print(fichero)
    dfAlcaldes = pd.concat([dfAlcaldes,
                            cargaAlcaldes(XLSX+"/"+fichero,"D:K",8,
        ['CCAA', 'PROVINCIA', 'MUNICIPIO', 'CODIGO INE', 'NOMBRE','LISTA','FECHA POSESIÓN','FECHA BAJA'], 
        pd.ExcelFile(XLSX+"/"+fichero).sheet_names[0])],)
# Out:
# Alcaldes_Mandato_1979_1983.xlsx
# Alcaldes_Mandato_1983_1987.xlsx
# Alcaldes_Mandato_1987_1991.xlsx
# Alcaldes_Mandato_1991_1995.xlsx
# Alcaldes_Mandato_1995_1999.xlsx
# Alcaldes_Mandato_1999_2003.xlsx
# Alcaldes_Mandato_2003_2007.xlsx
# Alcaldes_Mandato_2007_2011.xlsx
# Alcaldes_Mandato_2011_2015.xlsx
# Alcaldes_Mandato_2015_2019.xlsx
# Alcaldes_Mandato_2019_2023.xlsx

# %% [markdown]
# **Limpieza de datos**

# %%
import re
import string
import unicodedata

def transformar_fecha(columna,dataFrame):
    dataFrame[columna]=(dataFrame[columna].astype(str))
    dataFrame.loc[dataFrame[columna] == 'SIN FECHA', columna] = pd.NA
    dataFrame[columna]=pd.to_datetime((dataFrame[columna].str.replace("-","/").str[:10]),format='mixed')
    return dataFrame

"""
    Remplaza todos los signos de puntuación por vacío eliminando '.,'...
    Cambia la normalización con el encode ASCII y lo descodifica a UTF-8 español para eliminar todas las tildes
    Convierte todo a UPPER para que los nombres estén en mayúscula
"""
dfAlcaldes['NOMBRE NORMALIZADO']=(dfAlcaldes['NOMBRE']
                                  .str.replace('[{}]'.format(string.punctuation), '',regex=True)
                                  .str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.upper())


dfAlcaldes = transformar_fecha("FECHA POSESIÓN",dfAlcaldes)
dfAlcaldes = transformar_fecha("FECHA BAJA",dfAlcaldes)
dfAlcaldes=dfAlcaldes.drop_duplicates()

# %%
dfAlcaldes
# Out:
#            CCAA  PROVINCIA           MUNICIPIO CODIGO INE  \
# 0     Andalucía    Almería            ABRUCENA     040025
# 1     Andalucía    Almería                ADRA     040031
# 2     Andalucía    Almería           ALBANCHEZ     040046
# 3     Andalucía    Almería           ALBOLODUY     040059
# 4     Andalucía    Almería               ALBOX     040062
# ...         ...        ...                 ...        ...
# 8758  Rioja, La  Rioja, La   Viniegra de Abajo     261780
# 8759  Rioja, La  Rioja, La  Viniegra de Arriba     261793
# 8760  Rioja, La  Rioja, La            Zarratón     261807
# 8761  Rioja, La  Rioja, La             Zarzosa     261814
# 8762  Rioja, La  Rioja, La           Zorraquín     261835
#
#                                NOMBRE  LISTA FECHA POSESIÓN FECHA BAJA  \
# 0                  MARTINEZ LAO, JUAN   PSOE     1979-04-19        NaT
# 1             SARMIENTO POSADA, PEDRO  OTROS     1979-04-19        NaT
# 2                 MARTOS AYBAR, RAMON    UCD     1979-04-19        NaT
# 3            BLANES PANIAGUA, MARIANO    UCD     1979-04-19        NaT
# 4                MIRAS CARRASCO, JOSE    UCD     1979-04-19        NaT
# ...                               ...    ...            ...        ...
# 8758  Juan Ignacio Martínez Fernández     PP     2019-06-15        NaT
# 8759              Laura Crespi Lázaro     PP     2019-06-15        NaT
# 8760         Víctor Manuel Manso Ocio   PSOE     2019-06-15        NaT
# 8761          José María Sáenz Blanco     PP     2019-06-15        NaT
# 8762        José Ángel Capellán Marín     PP     2019-06-15        NaT
#
#                    NOMBRE NORMALIZADO
# 0                   MARTINEZ LAO JUAN
# 1              SARMIENTO POSADA PEDRO
# 2                  MARTOS AYBAR RAMON
# 3             BLANES PANIAGUA MARIANO
# 4                 MIRAS CARRASCO JOSE
# ...                               ...
# 8758  JUAN IGNACIO MARTINEZ FERNANDEZ
# 8759              LAURA CRESPI LAZARO
# 8760         VICTOR MANUEL MANSO OCIO
# 8761          JOSE MARIA SAENZ BLANCO
# 8762        JOSE ANGEL CAPELLAN MARIN
#
# [95402 rows x 9 columns]

# %% [markdown]
# **ALCALDES QUE REPITIERON ALCALDÍA**

# %%
df_duplicated = dfAlcaldes[dfAlcaldes.duplicated(subset=['NOMBRE NORMALIZADO'], keep=False)].copy()
# Contar el número de filas duplicadas por cada valor en 'NOMBRE NORMALIZADO'
duplicated_counts = df_duplicated.groupby(['NOMBRE NORMALIZADO']).size()

# Añadir la cuenta de duplicados como una nueva columna en df_duplicated
df_duplicated['DUPLICADOS'] = df_duplicated['NOMBRE NORMALIZADO'].map(duplicated_counts)

# %% [markdown]
# **CUANDO FUE SU PRIMERA ALCALDÍA**

# %%
min_dates = df_duplicated.groupby('NOMBRE NORMALIZADO')['FECHA POSESIÓN'].min()

df_duplicated['PRIMERA ALCALDÍA'] = df_duplicated['NOMBRE NORMALIZADO'].map(min_dates)

df_duplicated
# Out:
#            CCAA  PROVINCIA           MUNICIPIO CODIGO INE  \
# 1     Andalucía    Almería                ADRA     040031
# 2     Andalucía    Almería           ALBANCHEZ     040046
# 3     Andalucía    Almería           ALBOLODUY     040059
# 4     Andalucía    Almería               ALBOX     040062
# 10    Andalucía    Almería              ALICUN     040123
# ...         ...        ...                 ...        ...
# 8758  Rioja, La  Rioja, La   Viniegra de Abajo     261780
# 8759  Rioja, La  Rioja, La  Viniegra de Arriba     261793
# 8760  Rioja, La  Rioja, La            Zarratón     261807
# 8761  Rioja, La  Rioja, La             Zarzosa     261814
# 8762  Rioja, La  Rioja, La           Zorraquín     261835
#
#                                NOMBRE  LISTA FECHA POSESIÓN FECHA BAJA  \
# 1             SARMIENTO POSADA, PEDRO  OTROS     1979-04-19        NaT
# 2                 MARTOS AYBAR, RAMON    UCD     1979-04-19        NaT
# 3            BLANES PANIAGUA, MARIANO    UCD     1979-04-19        NaT
# 4                MIRAS CARRASCO, JOSE    UCD     1979-04-19        NaT
# 10            GONZALEZ MARTINEZ, JUAN    IND     1979-04-19        NaT
# ...                               ...    ...            ...        ...
# 8758  Juan Ignacio Martínez Fernández     PP     2019-06-15        NaT
# 8759              Laura Crespi Lázaro     PP     2019-06-15        NaT
# 8760         Víctor Manuel Manso Ocio   PSOE     2019-06-15        NaT
# 8761          José María Sáenz Blanco     PP     2019-06-15        NaT
# 8762        José Ángel Capellán Marín     PP     2019-06-15        NaT
#
#                    NOMBRE NORMALIZADO  DUPLICADOS PRIMERA ALCALDÍA
# 1              SARMIENTO POSADA PEDRO           2       1979-04-19
# 2                  MARTOS AYBAR RAMON           2       1979-04-19
# 3             BLANES PANIAGUA MARIANO           2       1979-04-19
# 4                 MIRAS CARRASCO JOSE           2       1979-04-19
# 10             GONZALEZ MARTINEZ JUAN           3       1979-04-19
# ...                               ...         ...              ...
# 8758  JUAN IGNACIO MARTINEZ FERNANDEZ           2       2015-06-13
# 8759              LAURA CRESPI LAZARO           2       2015-06-13
# 8760         VICTOR MANUEL MANSO OCIO           2       2015-06-13
# 8761          JOSE MARIA SAENZ BLANCO           4       2007-06-16
# 8762        JOSE ANGEL CAPELLAN MARIN           3       2011-06-11
#
# [58907 rows x 11 columns]

# %% [markdown]
# **ÚLTIMA ALCALDÍA**

# %%
min_dates = df_duplicated.groupby('NOMBRE NORMALIZADO')['FECHA POSESIÓN'].max()

df_duplicated['COMIENZO ÚLTIMA ALCALDÍA'] = df_duplicated['NOMBRE NORMALIZADO'].map(min_dates)

# %% [markdown]
# **VECES DE BAJA**

# %%
df_duplicated['VECES F.BAJA'] = df_duplicated['FECHA BAJA'].notna().astype(int)

min_dates = df_duplicated.groupby('NOMBRE NORMALIZADO')['VECES F.BAJA'].sum()

df_duplicated['VECES F.BAJA'] = df_duplicated['NOMBRE NORMALIZADO'].map(min_dates)

# %%
df_duplicated
# Out:
#            CCAA  PROVINCIA           MUNICIPIO CODIGO INE  \
# 1     Andalucía    Almería                ADRA     040031
# 2     Andalucía    Almería           ALBANCHEZ     040046
# 3     Andalucía    Almería           ALBOLODUY     040059
# 4     Andalucía    Almería               ALBOX     040062
# 10    Andalucía    Almería              ALICUN     040123
# ...         ...        ...                 ...        ...
# 8758  Rioja, La  Rioja, La   Viniegra de Abajo     261780
# 8759  Rioja, La  Rioja, La  Viniegra de Arriba     261793
# 8760  Rioja, La  Rioja, La            Zarratón     261807
# 8761  Rioja, La  Rioja, La             Zarzosa     261814
# 8762  Rioja, La  Rioja, La           Zorraquín     261835
#
#                                NOMBRE  LISTA FECHA POSESIÓN FECHA BAJA  \
# 1             SARMIENTO POSADA, PEDRO  OTROS     1979-04-19        NaT
# 2                 MARTOS AYBAR, RAMON    UCD     1979-04-19        NaT
# 3            BLANES PANIAGUA, MARIANO    UCD     1979-04-19        NaT
# 4                MIRAS CARRASCO, JOSE    UCD     1979-04-19        NaT
# 10            GONZALEZ MARTINEZ, JUAN    IND     1979-04-19        NaT
# ...                               ...    ...            ...        ...
# 8758  Juan Ignacio Martínez Fernández     PP     2019-06-15        NaT
# 8759              Laura Crespi Lázaro     PP     2019-06-15        NaT
# 8760         Víctor Manuel Manso Ocio   PSOE     2019-06-15        NaT
# 8761          José María Sáenz Blanco     PP     2019-06-15        NaT
# 8762        José Ángel Capellán Marín     PP     2019-06-15        NaT
#
#                    NOMBRE NORMALIZADO  DUPLICADOS PRIMERA ALCALDÍA  \
# 1              SARMIENTO POSADA PEDRO           2       1979-04-19
# 2                  MARTOS AYBAR RAMON           2       1979-04-19
# 3             BLANES PANIAGUA MARIANO           2       1979-04-19
# 4                 MIRAS CARRASCO JOSE           2       1979-04-19
# 10             GONZALEZ MARTINEZ JUAN           3       1979-04-19
# ...                               ...         ...              ...
# 8758  JUAN IGNACIO MARTINEZ FERNANDEZ           2       2015-06-13
# 8759              LAURA CRESPI LAZARO           2       2015-06-13
# 8760         VICTOR MANUEL MANSO OCIO           2       2015-06-13
# 8761          JOSE MARIA SAENZ BLANCO           4       2007-06-16
# 8762        JOSE ANGEL CAPELLAN MARIN           3       2011-06-11
#
#      COMIENZO ÚLTIMA ALCALDÍA  VECES F.BAJA
# 1                  1983-05-23             0
# 2                  1983-05-23             0
# 3                  1983-05-24             0
# 4                  1983-05-23             1
# 10                 1987-06-30             0
# ...                       ...           ...
# 8758               2019-06-15             0
# 8759               2019-06-15             0
# 8760               2019-06-15             0
# 8761               2019-06-15             0
# 8762               2019-06-15             0
#
# [58907 rows x 13 columns]

# %% [markdown]
# **CREACIÓN DATAFRAME LIMPIO CON DATOS LIMPIOS**

# %%
dfAlcaldesLimpio=pd.DataFrame()
dfAlcaldesLimpio['NOMBRE LIMPIO'] = df_duplicated['NOMBRE NORMALIZADO']
dfAlcaldesLimpio['NUM. ALCALDÍAS'] = df_duplicated['DUPLICADOS']
dfAlcaldesLimpio['PRIMERA ALCALDÍA'] = df_duplicated['PRIMERA ALCALDÍA']
dfAlcaldesLimpio['ÚLTIMA ALCALDÍA'] = df_duplicated['COMIENZO ÚLTIMA ALCALDÍA']
dfAlcaldesLimpio['VECES F.BAJA'] = df_duplicated['VECES F.BAJA']

#Colocamos de index el Nombre Limpio ya que vamos manejar nombres como PK
dfAlcaldesLimpio=dfAlcaldesLimpio.set_index('NOMBRE LIMPIO')
#Removemos duplicated
dfAlcaldesLimpio=dfAlcaldesLimpio.drop_duplicates()

# %% [markdown]
# **DATAFRAME ORDENADOS POR NUM. ALCALDÍAS**
#
# Vemos que curisomanete de los 5 que más cargos han repetido 5 tuvieron su debut en la alcaldía en 1979-04-19 y su último cargo en la misma fecha siendo 1999-07-03
#
# Todos tienen la última alcaldía el mismo día pero aún teniendo esa gran cantidad de alcaldías solo 3 de ellos los echaron y solo una vez lo que me parece bastante increible

# %%
dfAlcaldesLimpio.sort_values(by=['NUM. ALCALDÍAS'],ascending=False)
# Out:
#                            NUM. ALCALDÍAS PRIMERA ALCALDÍA ÚLTIMA ALCALDÍA  \
# NOMBRE LIMPIO
# PEREZ PEREZ JESUS                      13       1979-04-19      1999-07-03
# MARTIN SANCHEZ JOSE                    12       1979-04-19      1999-07-03
# GARCIA GARCIA MANUEL                   12       1979-04-19      1999-07-03
# SANCHEZ SANCHEZ JOSE                    9       1979-04-19      1999-07-03
# FERNANDEZ FERNANDEZ PEDRO               9       1979-04-19      1999-07-03
# ...                                   ...              ...             ...
# GARCIA GARCIA RAUL                      2       1995-06-17      1998-07-30
# BOSQUE PEREZ EMILIO DEL                 2       1996-11-08      1999-07-03
# GARCIA DELGADO VICENTE                  2       1995-11-25      1999-07-03
# GARCINUNO GARCINUNO JOSE                2       1995-06-17      2002-09-19
# JOAQUIN MARTINEZ MARTINEZ               2       2019-06-15      2019-06-15
#
#                            VECES F.BAJA
# NOMBRE LIMPIO
# PEREZ PEREZ JESUS                     1
# MARTIN SANCHEZ JOSE                   0
# GARCIA GARCIA MANUEL                  1
# SANCHEZ SANCHEZ JOSE                  0
# FERNANDEZ FERNANDEZ PEDRO             1
# ...                                 ...
# GARCIA GARCIA RAUL                    1
# BOSQUE PEREZ EMILIO DEL               0
# GARCIA DELGADO VICENTE                0
# GARCINUNO GARCINUNO JOSE              0
# JOAQUIN MARTINEZ MARTINEZ             0
#
# [3043 rows x 4 columns]

# %% [markdown]
# **ORDENADO POR VECES DE BAJA**
#
# Este también es curioso ya que tres de los que más echaron, fueron elegidas numerosas veces y los echaron en casi todas las veces que fueron elegidos

# %%
dfAlcaldesLimpio.sort_values(by=['VECES F.BAJA'],ascending=False)
# Out:
#                                   NUM. ALCALDÍAS PRIMERA ALCALDÍA  \
# NOMBRE LIMPIO
# FRANCISCO JAVIER PEREZ CUEVA                   4       2011-06-11
# JOSE OLIVER AMENGUAL                           3       2003-06-14
# LLORENC BRONDO JOVER                           2       2007-06-16
# SALVADOR POVEDA BERNABE                        4       2003-06-14
# PEDRO MANUEL BLAS AMADOR JIMENEZ               2       2016-01-08
# ...                                          ...              ...
# HEREDERO SAN FRUTOS DESIDERIO                  2       1992-11-23
# PESCADOR PEREZ ANGEL                           2       1991-07-13
# SEBASTIAN SIENES PASCUAL                       2       1991-06-15
# AYUSO PEREZ ANTONIO J                          2       1994-01-04
# JOAQUIN MARTINEZ MARTINEZ                      2       2019-06-15
#
#                                  ÚLTIMA ALCALDÍA  VECES F.BAJA
# NOMBRE LIMPIO
# FRANCISCO JAVIER PEREZ CUEVA          2017-01-23             3
# JOSE OLIVER AMENGUAL                  2015-06-13             3
# LLORENC BRONDO JOVER                  2008-07-31             2
# SALVADOR POVEDA BERNABE               2011-06-11             2
# PEDRO MANUEL BLAS AMADOR JIMENEZ      2017-04-05             2
# ...                                          ...           ...
# HEREDERO SAN FRUTOS DESIDERIO         1995-06-19             0
# PESCADOR PEREZ ANGEL                  1999-07-03             0
# SEBASTIAN SIENES PASCUAL              1995-06-22             0
# AYUSO PEREZ ANTONIO J                 1995-06-17             0
# JOAQUIN MARTINEZ MARTINEZ             2019-06-15             0
#
# [3043 rows x 4 columns]

# %% [markdown]
# **Definición método de gráficos x color x tamaño**

# %%
import datetime
from matplotlib import colors, pyplot as plt
from matplotlib.ticker import PercentFormatter
import numpy as np

def graficaColores(value,bins):

    fig, ax = plt.subplots()

    N, bins, patches = ax.hist(value,bins=bins)    


    # Ajusta las etiquetas del eje x para que aparezcan en cada año
    ax.set_xticks(np.arange(value.min(), value.max()+1, 2))
    # Ajusta las etiquetas del eje x para que aparezcan en cada año y las rota 90 grados
    ax.set_xticklabels(np.arange(int(value.min()), int(value.max())+1, 2), rotation=-90)

    fracs = N / N.max()

    #Se normaliza el valor de N / NMax correspondiente a los valores de cantidad
    norm = colors.Normalize(fracs.min(), fracs.max())

    # Loop entre cada objeto y se pondra los colores correspondientes
    for thisfrac, thispatch in zip(fracs, patches):
        color = plt.cm.viridis(norm(thisfrac))
        thispatch.set_facecolor(color)

    plt.show()

# %% [markdown]
# **GRÁFICA DE POLÍTICOS ELEGIDOS DURANTE ESOS AÑOS**
#
# En este podemos observar que donde más alcaldes fueron elegidos coincide con la fecha de inicio de cada Excel haciendo referencia a las elecciones de cada sitio, pero.
#
# También vemos que a partir del año 1991 aumentó el número de alcaldes que fueron elegidos entre elecciones por lo que también aumento el número de alcaldes que los dieron de baja durante su mandato

# %%
dfTemp = dfAlcaldes
dfTemp['Year'] = pd.DatetimeIndex(dfAlcaldes['FECHA POSESIÓN']).year

value = dfTemp['Year']
value=value.dropna()

graficaColores(value,int(datetime.date.today().year-value.min()))

# %% [markdown]
# **TOP 10 PARTIDOS POLÍTICOS Y CANTIDAD DE ALCALDES**
#
# Vemos que lo lidera el PSOE con el PP por una paliza increible en comparación al resto de partidos, pero vemos también que hay una coalición que entra en el podio que es la de coalición popular entre AP/PDP/UL

# %%
dfTemp=dfAlcaldes
conteo=dfTemp['LISTA'].value_counts().nlargest(10)

plt.figure(figsize=(7.5,7.5))
plt.pie(conteo.values, labels=conteo.index)
plt.legend()
plt.show()

# %% [markdown]
# **LOS 5 COMUNIDADES CON MAYOR NÚMERO DE ELECCIONES DESDE 1979**
#
# Vemos que para sorpresa de nadie la comunidad con mayor número de elecciones desde 1979 es Castilla y León dado a su enorme terreno, pero me sorprende que Cataluña quedara segunda ya que hay comunidades autónomas más grandes como cualquiera de las otras 3 de la lista

# %%
conteo=dfAlcaldes['CCAA'].value_counts().nlargest(5)

plt.figure(figsize=(8,8))
plt.pie(conteo.values, labels=conteo.index)
plt.legend()
plt.show()

# %% [markdown]
# **En este gráfico se puede observar el primer año de alcaldía de los alcaldes que repitieron**
#
# Podemos observar el pico de 1979 de cuando se empezó a recoger datos, pero también es visible un gran pico en el año 2003 mi teoría es el comieno de la digitalización de estos datos pero esto es una teoría ya que el repunte es evidente

# %%
import datetime
from matplotlib import colors, pyplot as plt
from matplotlib.ticker import PercentFormatter
import numpy as np

dfTemp = dfAlcaldesLimpio
dfTemp['Year'] = pd.DatetimeIndex(dfAlcaldesLimpio['PRIMERA ALCALDÍA']).year

value = dfTemp['Year']
value=value.dropna()

graficaColores(value,int(datetime.date.today().year-value.min()))
