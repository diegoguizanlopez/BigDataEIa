# %% [markdown]
# # **Juntar las dos imagenes y hacer que las letras estén en el fondo bonito**

# %%
import pathlib
path=str(pathlib.Path().resolve().parent)+"/imagenes/"

# %%
import cv2 as cv
from matplotlib import pyplot as plt

imgf = cv.imread(path+"paisaje_foto.jpeg")
imgt = cv.imread(path+"paisaje_texto.jpeg")
fig,(ax1,ax2) = plt.subplots(1,2)
ax1.imshow(imgf)
ax2.imshow(imgt)

# %%
dist = cv.resize(imgt,(int(imgt.shape[1]/2),int(imgt.shape[0]/2)),cv.INTER_CUBIC)
fig,(ax1,ax2) = plt.subplots(1,2)
ax1.imshow(imgf)
ax2.imshow(dist)

# %% [markdown]
# # **Restaurar la foto**
