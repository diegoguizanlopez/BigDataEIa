# %%
import random

import matplotlib.pyplot as plt
import numpy as np

import tensorflow
import keras
from tensorflow.keras.layers import Dense, Conv2DTranspose, LeakyReLU, Reshape, BatchNormalization, Activation, Conv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dropout, MaxPool2D
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.datasets import  fashion_mnist

# %% [markdown]
# # Cargar MNist

# %% [markdown]
# Nos quedamos solo las camisetas que son donde es 0

# %%
def cargar_imagenes():
    (Xtrain, Ytrain), (_, _) = fashion_mnist.load_data()

    # Nos quedamos con las camiseta
    indice = np.where(Ytrain == 0)
    indice = indice[0]
    Xtrain = Xtrain[indice, :,:]
    # Normalizamos los datos
    X = Xtrain.astype('float32') / 255.0
    return X

dataset = cargar_imagenes()

for i in range(49):
  plt.subplot(7, 7, 1 + i)
  plt.axis('off')
  plt.imshow(dataset[i], cmap="binary")

dataset.shape
# Out:
# (6000, 28, 28)

# %% [markdown]
# # Creación del discriminador

# %%
discriminador = Sequential()

# Padding same permite que si es multiplo de 3 no se pierdan valores
discriminador.add(Conv2D(8,kernel_size=3,padding="same",
                         input_shape=(dataset.shape[1],dataset.shape[2],1),activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Conv2D(32,kernel_size=3,padding="same",activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Conv2D(64,kernel_size=3,padding="same",activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Flatten())

discriminador.add(Dense(32,activation="relu"))


discriminador.add(Dense(1,activation="sigmoid"))

discriminador.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 28, 28, 8)         80
#
#  max_pooling2d_21 (MaxPooli  (None, 14, 14, 8)         0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 32)        2336
#
#  max_pooling2d_22 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  conv2d_23 (Conv2D)          (None, 7, 7, 64)          18496
#
#  max_pooling2d_23 (MaxPooli  (None, 3, 3, 64)          0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 576)               0
#
#  dense_31 (Dense)            (None, 32)                18464
#
#  dense_32 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 39409 (153.94 KB)
# Trainable params: 39409 (153.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Tiene que haber poco LR para poder entrenar los modelos con calma
discriminador.compile(loss="binary_crossentropy", optimizer = Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
discriminador.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 28, 28, 8)         80
#
#  max_pooling2d_21 (MaxPooli  (None, 14, 14, 8)         0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 32)        2336
#
#  max_pooling2d_22 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  conv2d_23 (Conv2D)          (None, 7, 7, 64)          18496
#
#  max_pooling2d_23 (MaxPooli  (None, 3, 3, 64)          0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 576)               0
#
#  dense_31 (Dense)            (None, 32)                18464
#
#  dense_32 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 39409 (153.94 KB)
# Trainable params: 39409 (153.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Creación del generador

# %%
generador = Sequential()

# Vamos en incremento para intentar simular el Flatten del modelo Discriminador
generador.add(Dense(32,input_shape=(1,),activation="relu"))

# No tiene porqué pero va beneficiar la cantidad de neuronas = al discriminador
generador.add(Dense(576,activation="relu"))

# La capa de MaxPooling2D antes del Flatten para darle ya un Shape
generador.add(Reshape((3,3,64)))

# Lo que hace es que vaya a saltos de 2 como iba la capa de MaxPooling2D duplicando el tamaño x2
# Con Padding = "valid" tendría el mismo (None, 7, 7, 32) en la última capa que el Discriminador
# Ya que podemos gestionar el valor de diferencia con +1 o -1 de tamaño de imagen
generador.add(Conv2DTranspose(64,kernel_size=3, strides=2,padding="valid",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Borra la mitad de las neuronas de vez en cuando
generador.add(Dropout(0.5))

# Ahora tenemos que pasar de 7 a 14 con un 16 de Neuronas
generador.add(Conv2DTranspose(32,kernel_size=3, strides=2,padding="same",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Borra la mitad de las neuronas de vez en cuando
generador.add(Dropout(0.5))

# Ahora tenemos que pasar de 14 a 28 con 8 de Neuronas
generador.add(Conv2DTranspose(8,kernel_size=3, strides=2,padding="same",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Borra la mitad de las neuronas de vez en cuando
generador.add(Dropout(0.5))

# Ahora una capa con 1 y sin modificar el tamaño con strides=1 y que acabe entre 0 y 1 con sigmoid
generador.add(Conv2DTranspose(1,kernel_size=3,strides=1,padding="same",activation="sigmoid"))

generador.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_33 (Dense)            (None, 32)                64
#
#  dense_34 (Dense)            (None, 576)               19008
#
#  reshape_7 (Reshape)         (None, 3, 3, 64)          0
#
#  conv2d_transpose_28 (Conv2  (None, 7, 7, 64)          36928
#  DTranspose)
#
#  batch_normalization_4 (Bat  (None, 7, 7, 64)          256
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 7, 7, 64)          0
#
#  conv2d_transpose_29 (Conv2  (None, 14, 14, 32)        18464
#  DTranspose)
#
#  batch_normalization_5 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_transpose_30 (Conv2  (None, 28, 28, 8)         2312
#  DTranspose)
#
#  batch_normalization_6 (Bat  (None, 28, 28, 8)         32
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 28, 28, 8)         0
#
#  conv2d_transpose_31 (Conv2  (None, 28, 28, 1)         73
#  DTranspose)
#
# =================================================================
# Total params: 77265 (301.82 KB)
# Trainable params: 77057 (301.00 KB)
# Non-trainable params: 208 (832.00 Byte)
# _________________________________________________________________

# %%
gan = Sequential()
gan.add(generador)
gan.add(discriminador)
gan.compile(loss="binary_crossentropy", optimizer = Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
def get_datos_true(nmuestras):
    """Devuelve imagenes verdaderas del DataSet

    Args:
        muestras (pd.DataFrame): DataFrame de Pandas

    Returns:
        List: Devuelve el X e Y del DataSet 
    """
    v = np.random.randint(0,dataset.shape[0],nmuestras)
    X = dataset[v]
    y = np.ones((nmuestras,1))
    return X,y

def get_datos_fake(nmuestras):
    """Genera datos falsos con el generador

    Args:
        nmuestras (int): Número de muestras

    Returns:
        List: Devuelve X e Y de un falso DataSet predicho
    """
    input = np.random.rand(nmuestras)
    X = generador.predict(input)
    y = np.zeros((nmuestras,1))
    return X,y

def entrenamiento(epochs=1, batch_size=128):
    """Entrena el modelo de Generador y Detector

    Args:
        epochs (int, optional): Nº de Epochs. Defaults to 1.
        batch_size (int, optional): Tamaño de los saltos. Defaults to 128.
    """
    max_len = dataset.shape[0]
    nbatchs = int(max_len / batch_size)
    acc_r,acc_f,acc_g=[],[],[]
    for epoch in range(epochs):
        print("Epoch : ", epoch)
        for batch in range(nbatchs):

            #region Discriminador

            discriminador.trainable = True
            X_real,y_real = get_datos_true(batch_size//2)
            # Permite entrenar a cachos el discriminador
            loss_real, acc_real = discriminador.train_on_batch(X_real,y_real)

            X_fake,y_fake = get_datos_fake(batch_size//2)
            # Permite entrenar a cachos el discriminador
            loss_fake, acc_fake = discriminador.train_on_batch(X_fake,y_fake)

            discriminador.trainable = False

            #endregion

            #region Generador
            X_gan = np.random.randn(batch_size).reshape(batch_size,1)

            # Tenemos que intentar engañarlo, por lo que ponemos por la salida unos ya que significaría que son correctos
            # Hasta que el otro diga lo contrario
            y_gan = np.ones((batch_size,1))

            loss_gan, acc_gan = gan.train_on_batch(X_gan,y_gan)
            #endregion

            print(f"Epoch: {epoch} - Batch: {batch}")
            print(f"loss_real: {loss_real} - loss_fake: {loss_fake} - loss_gan: {loss_gan}")
            print(f"acc_real: {acc_real} - acc_fake: {acc_fake} - acc_gan: {acc_gan}")
            acc_r.append(acc_real)
            acc_f.append(acc_fake)
            acc_g.append(acc_gan)
    return acc_r,acc_f,acc_g

# %%
values=entrenamiento(epochs=50)
# Out:
# Epoch :  0
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 0 - Batch: 0
# loss_real: 0.6800146102905273 - loss_fake: 0.6950092315673828 - loss_gan: 0.6657261848449707
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 1
# loss_real: 0.6531268358230591 - loss_fake: 0.7042139172554016 - loss_gan: 0.6444251537322998
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 0 - Batch: 2
# loss_real: 0.6342996954917908 - loss_fake: 0.712522029876709 - loss_gan: 0.6293281316757202
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 0 - Batch: 3
# loss_real: 0.6134800910949707 - loss_fake: 0.7208368182182312 - loss_gan: 0.610561192035675
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 4
# loss_real: 0.5954859852790833 - loss_fake: 0.7297880053520203 - loss_gan: 0.5935825109481812
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 0 - Batch: 5
# loss_real: 0.5779098272323608 - loss_fake: 0.7384541630744934 - loss_gan: 0.5814510583877563
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 0 - Batch: 6
# loss_real: 0.5547941327095032 - loss_fake: 0.7465251684188843 - loss_gan: 0.5692593455314636
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 0 - Batch: 7
# loss_real: 0.5369898676872253 - loss_fake: 0.7545351982116699 - loss_gan: 0.555073082447052
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 8
# loss_real: 0.5244335532188416 - loss_fake: 0.7626146674156189 - loss_gan: 0.5428171753883362
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 0 - Batch: 9
# loss_real: 0.5081114172935486 - loss_fake: 0.7715126276016235 - loss_gan: 0.5229244828224182
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 0 - Batch: 10
# loss_real: 0.4847428798675537 - loss_fake: 0.7806146144866943 - loss_gan: 0.504813551902771
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 11
# loss_real: 0.4825640320777893 - loss_fake: 0.7915146350860596 - loss_gan: 0.489966481924057
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 12
# loss_real: 0.45287808775901794 - loss_fake: 0.8019816875457764 - loss_gan: 0.4707692861557007
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 19ms/step
# Epoch: 0 - Batch: 13
# loss_real: 0.4428751766681671 - loss_fake: 0.8117969036102295 - loss_gan: 0.4532732665538788
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 14
# loss_real: 0.4356754422187805 - loss_fake: 0.8210767507553101 - loss_gan: 0.44033294916152954
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 15
# loss_real: 0.41509515047073364 - loss_fake: 0.8299270868301392 - loss_gan: 0.4279108941555023
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 11ms/step
# Epoch: 0 - Batch: 16
# loss_real: 0.40565118193626404 - loss_fake: 0.8381827473640442 - loss_gan: 0.41662102937698364
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 17
# loss_real: 0.402109831571579 - loss_fake: 0.8459447622299194 - loss_gan: 0.3979966640472412
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 0 - Batch: 18
# loss_real: 0.3822236657142639 - loss_fake: 0.8548308610916138 - loss_gan: 0.3844911456108093
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 19
# loss_real: 0.3635644316673279 - loss_fake: 0.862706184387207 - loss_gan: 0.3757842779159546
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 20
# loss_real: 0.3569732904434204 - loss_fake: 0.8700336813926697 - loss_gan: 0.3565257787704468
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 0 - Batch: 21
# loss_real: 0.3496365547180176 - loss_fake: 0.8773422241210938 - loss_gan: 0.3487243056297302
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 22
# loss_real: 0.3286600708961487 - loss_fake: 0.8845136165618896 - loss_gan: 0.3306223750114441
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 23
# loss_real: 0.3181135058403015 - loss_fake: 0.8911517858505249 - loss_gan: 0.3176124691963196
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 0 - Batch: 24
# loss_real: 0.31983596086502075 - loss_fake: 0.8975178003311157 - loss_gan: 0.3170090913772583
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 0 - Batch: 25
# loss_real: 0.3002564013004303 - loss_fake: 0.9036223888397217 - loss_gan: 0.2945755124092102
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 26
# loss_real: 0.29678577184677124 - loss_fake: 0.909286379814148 - loss_gan: 0.2838803231716156
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 0 - Batch: 27
# loss_real: 0.27842414379119873 - loss_fake: 0.9143730998039246 - loss_gan: 0.27499935030937195
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 0 - Batch: 28
# loss_real: 0.2853506803512573 - loss_fake: 0.919231116771698 - loss_gan: 0.26685968041419983
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 0 - Batch: 29
# loss_real: 0.2650344967842102 - loss_fake: 0.9237477779388428 - loss_gan: 0.25831788778305054
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 30
# loss_real: 0.2663462162017822 - loss_fake: 0.9278091192245483 - loss_gan: 0.24582967162132263
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 31
# loss_real: 0.2447977364063263 - loss_fake: 0.9327607154846191 - loss_gan: 0.22457414865493774
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 32
# loss_real: 0.23261921107769012 - loss_fake: 0.9367865324020386 - loss_gan: 0.22584697604179382
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 33
# loss_real: 0.22875460982322693 - loss_fake: 0.9398511648178101 - loss_gan: 0.21481381356716156
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 34
# loss_real: 0.22819679975509644 - loss_fake: 0.942018985748291 - loss_gan: 0.20615513622760773
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 35
# loss_real: 0.2154172658920288 - loss_fake: 0.9432533979415894 - loss_gan: 0.1981191784143448
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 36
# loss_real: 0.2157883495092392 - loss_fake: 0.9436876773834229 - loss_gan: 0.1920384168624878
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 37
# loss_real: 0.19773660600185394 - loss_fake: 0.9435920715332031 - loss_gan: 0.18943481147289276
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 0 - Batch: 38
# loss_real: 0.20046739280223846 - loss_fake: 0.9428941607475281 - loss_gan: 0.1809188723564148
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 39
# loss_real: 0.21530398726463318 - loss_fake: 0.9421724081039429 - loss_gan: 0.17217588424682617
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 0 - Batch: 40
# loss_real: 0.2022201120853424 - loss_fake: 0.9406447410583496 - loss_gan: 0.17024055123329163
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 12ms/step
# Epoch: 0 - Batch: 41
# loss_real: 0.1904316246509552 - loss_fake: 0.9384341835975647 - loss_gan: 0.16542835533618927
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 0 - Batch: 42
# loss_real: 0.19027331471443176 - loss_fake: 0.9354886412620544 - loss_gan: 0.16264377534389496
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 43
# loss_real: 0.17655020952224731 - loss_fake: 0.932176947593689 - loss_gan: 0.16032101213932037
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 44
# loss_real: 0.1876540631055832 - loss_fake: 0.9287721514701843 - loss_gan: 0.14835187792778015
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 45
# loss_real: 0.17926141619682312 - loss_fake: 0.9249629974365234 - loss_gan: 0.1461123824119568
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch :  1
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1 - Batch: 0
# loss_real: 0.166133850812912 - loss_fake: 0.9209175109863281 - loss_gan: 0.1457502543926239
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 1 - Batch: 1
# loss_real: 0.16253697872161865 - loss_fake: 0.9168586134910583 - loss_gan: 0.1396450698375702
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 2
# loss_real: 0.16292451322078705 - loss_fake: 0.9125575423240662 - loss_gan: 0.13647297024726868
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 1 - Batch: 3
# loss_real: 0.17630606889724731 - loss_fake: 0.9080153703689575 - loss_gan: 0.12312038242816925
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 1 - Batch: 4
# loss_real: 0.15767917037010193 - loss_fake: 0.9030990600585938 - loss_gan: 0.12326346337795258
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1 - Batch: 5
# loss_real: 0.15981432795524597 - loss_fake: 0.8974950909614563 - loss_gan: 0.12083113938570023
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 6
# loss_real: 0.15784677863121033 - loss_fake: 0.8916664123535156 - loss_gan: 0.11473280936479568
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 1 - Batch: 7
# loss_real: 0.14982861280441284 - loss_fake: 0.8856061697006226 - loss_gan: 0.11230897903442383
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 8
# loss_real: 0.13584856688976288 - loss_fake: 0.8792997598648071 - loss_gan: 0.11200118064880371
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 9
# loss_real: 0.14968295395374298 - loss_fake: 0.8725055456161499 - loss_gan: 0.10772255808115005
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 10
# loss_real: 0.13805954158306122 - loss_fake: 0.8659453392028809 - loss_gan: 0.10389338433742523
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 11
# loss_real: 0.1464255154132843 - loss_fake: 0.8583741784095764 - loss_gan: 0.09988923370838165
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 12
# loss_real: 0.12007507681846619 - loss_fake: 0.8507938385009766 - loss_gan: 0.09826282411813736
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 13
# loss_real: 0.12123331427574158 - loss_fake: 0.8430010080337524 - loss_gan: 0.0927630364894867
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 14
# loss_real: 0.1278511881828308 - loss_fake: 0.8361778855323792 - loss_gan: 0.08490736782550812
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 15
# loss_real: 0.13381162285804749 - loss_fake: 0.8299586772918701 - loss_gan: 0.08377869427204132
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 16
# loss_real: 0.12612774968147278 - loss_fake: 0.8230942487716675 - loss_gan: 0.07658232748508453
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 17
# loss_real: 0.11851923167705536 - loss_fake: 0.8163758516311646 - loss_gan: 0.076308473944664
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 18
# loss_real: 0.11154209077358246 - loss_fake: 0.8081185817718506 - loss_gan: 0.07018840312957764
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 1 - Batch: 19
# loss_real: 0.11579320579767227 - loss_fake: 0.8006454706192017 - loss_gan: 0.06526681780815125
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 20
# loss_real: 0.10845348238945007 - loss_fake: 0.7929908037185669 - loss_gan: 0.06171075627207756
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 1 - Batch: 21
# loss_real: 0.10425277799367905 - loss_fake: 0.7845984697341919 - loss_gan: 0.06574353575706482
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 1 - Batch: 22
# loss_real: 0.11302132904529572 - loss_fake: 0.7757570743560791 - loss_gan: 0.0585843026638031
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 1 - Batch: 23
# loss_real: 0.09247422218322754 - loss_fake: 0.7668565511703491 - loss_gan: 0.05782941356301308
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 1 - Batch: 24
# loss_real: 0.10636892169713974 - loss_fake: 0.7580478191375732 - loss_gan: 0.053191959857940674
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 1 - Batch: 25
# loss_real: 0.10393518209457397 - loss_fake: 0.749657154083252 - loss_gan: 0.05019313097000122
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 26
# loss_real: 0.09443105757236481 - loss_fake: 0.7415320873260498 - loss_gan: 0.04861624538898468
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 1 - Batch: 27
# loss_real: 0.09151864051818848 - loss_fake: 0.732780396938324 - loss_gan: 0.046033382415771484
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1 - Batch: 28
# loss_real: 0.09330195933580399 - loss_fake: 0.7238197326660156 - loss_gan: 0.04314916580915451
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 29
# loss_real: 0.09258995205163956 - loss_fake: 0.7145044207572937 - loss_gan: 0.04544190317392349
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 1 - Batch: 30
# loss_real: 0.10520662367343903 - loss_fake: 0.704912543296814 - loss_gan: 0.041035935282707214
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 31
# loss_real: 0.09741874039173126 - loss_fake: 0.6962965726852417 - loss_gan: 0.03769562393426895
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 32
# loss_real: 0.07954786717891693 - loss_fake: 0.6878085136413574 - loss_gan: 0.03667198866605759
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 1 - Batch: 33
# loss_real: 0.09183669090270996 - loss_fake: 0.6781337261199951 - loss_gan: 0.0340375080704689
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 34
# loss_real: 0.0864609032869339 - loss_fake: 0.6681742668151855 - loss_gan: 0.03192950785160065
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 35
# loss_real: 0.08089612424373627 - loss_fake: 0.6586772203445435 - loss_gan: 0.029291070997714996
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 36
# loss_real: 0.08560761064291 - loss_fake: 0.6495795249938965 - loss_gan: 0.028178971260786057
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 18ms/step
# Epoch: 1 - Batch: 37
# loss_real: 0.06906909495592117 - loss_fake: 0.6396834850311279 - loss_gan: 0.027693841606378555
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1 - Batch: 38
# loss_real: 0.0779477208852768 - loss_fake: 0.631117582321167 - loss_gan: 0.025023095309734344
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 1 - Batch: 39
# loss_real: 0.0711011290550232 - loss_fake: 0.621519923210144 - loss_gan: 0.0232878178358078
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 40
# loss_real: 0.07185596227645874 - loss_fake: 0.6125985383987427 - loss_gan: 0.021296879276633263
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 41
# loss_real: 0.07316949218511581 - loss_fake: 0.6038520932197571 - loss_gan: 0.019881650805473328
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 1 - Batch: 42
# loss_real: 0.06811453402042389 - loss_fake: 0.5943751335144043 - loss_gan: 0.020028574392199516
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 43
# loss_real: 0.06709668040275574 - loss_fake: 0.5852235555648804 - loss_gan: 0.01848733425140381
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 44
# loss_real: 0.0626346692442894 - loss_fake: 0.5757297277450562 - loss_gan: 0.017259180545806885
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 45
# loss_real: 0.06684106588363647 - loss_fake: 0.5656770467758179 - loss_gan: 0.017389245331287384
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  2
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 0
# loss_real: 0.06645091623067856 - loss_fake: 0.5556117296218872 - loss_gan: 0.015047946944832802
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 1
# loss_real: 0.06700272858142853 - loss_fake: 0.5464010238647461 - loss_gan: 0.014954318292438984
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 2 - Batch: 2
# loss_real: 0.06350596994161606 - loss_fake: 0.5361365675926208 - loss_gan: 0.013841906562447548
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 3
# loss_real: 0.06713562458753586 - loss_fake: 0.5267911553382874 - loss_gan: 0.012171691283583641
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 2 - Batch: 4
# loss_real: 0.06668461859226227 - loss_fake: 0.5178306102752686 - loss_gan: 0.011485576629638672
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 2 - Batch: 5
# loss_real: 0.06651674956083298 - loss_fake: 0.5086432695388794 - loss_gan: 0.010760042816400528
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 6
# loss_real: 0.05711740255355835 - loss_fake: 0.49852603673934937 - loss_gan: 0.009555494412779808
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 2 - Batch: 7
# loss_real: 0.06059781461954117 - loss_fake: 0.48917528986930847 - loss_gan: 0.008717162534594536
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 19ms/step
# Epoch: 2 - Batch: 8
# loss_real: 0.05570157617330551 - loss_fake: 0.4801119565963745 - loss_gan: 0.00787915289402008
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 2 - Batch: 9
# loss_real: 0.060094546526670456 - loss_fake: 0.4705668091773987 - loss_gan: 0.006956255994737148
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 2 - Batch: 10
# loss_real: 0.0542309433221817 - loss_fake: 0.46094340085983276 - loss_gan: 0.006659399252384901
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 11
# loss_real: 0.05464862287044525 - loss_fake: 0.45151281356811523 - loss_gan: 0.006251906976103783
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 2 - Batch: 12
# loss_real: 0.04713395610451698 - loss_fake: 0.44190293550491333 - loss_gan: 0.005150565877556801
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 13
# loss_real: 0.05303024500608444 - loss_fake: 0.4325898289680481 - loss_gan: 0.004798742942512035
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 2 - Batch: 14
# loss_real: 0.04604024812579155 - loss_fake: 0.4227522015571594 - loss_gan: 0.004475730471313
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 15
# loss_real: 0.04738393425941467 - loss_fake: 0.41320276260375977 - loss_gan: 0.004392858594655991
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 16
# loss_real: 0.052541714161634445 - loss_fake: 0.4040144383907318 - loss_gan: 0.004056253470480442
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 17
# loss_real: 0.04986916109919548 - loss_fake: 0.3950464427471161 - loss_gan: 0.0036681347992271185
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 2 - Batch: 18
# loss_real: 0.051695212721824646 - loss_fake: 0.3855353593826294 - loss_gan: 0.003268351312726736
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 19
# loss_real: 0.049703583121299744 - loss_fake: 0.37654629349708557 - loss_gan: 0.003001437522470951
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 21ms/step
# Epoch: 2 - Batch: 20
# loss_real: 0.047939784824848175 - loss_fake: 0.3677186369895935 - loss_gan: 0.002791609149426222
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 21
# loss_real: 0.04833906516432762 - loss_fake: 0.3590541481971741 - loss_gan: 0.002343022497370839
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 2 - Batch: 22
# loss_real: 0.04076364263892174 - loss_fake: 0.35010212659835815 - loss_gan: 0.0022254521027207375
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 23
# loss_real: 0.04604014381766319 - loss_fake: 0.3417367935180664 - loss_gan: 0.0019992694724351168
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 24
# loss_real: 0.03674928471446037 - loss_fake: 0.3341353237628937 - loss_gan: 0.001839907723478973
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 25
# loss_real: 0.040396176278591156 - loss_fake: 0.3258172571659088 - loss_gan: 0.001632337225601077
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 2 - Batch: 26
# loss_real: 0.04582936689257622 - loss_fake: 0.31780093908309937 - loss_gan: 0.0014420393854379654
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 2 - Batch: 27
# loss_real: 0.04059559106826782 - loss_fake: 0.3104611337184906 - loss_gan: 0.0013681193813681602
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 28
# loss_real: 0.039109524339437485 - loss_fake: 0.3029882311820984 - loss_gan: 0.0012441648868843913
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 2 - Batch: 29
# loss_real: 0.03803753852844238 - loss_fake: 0.2949163317680359 - loss_gan: 0.0011674294946715236
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 2 - Batch: 30
# loss_real: 0.03684983029961586 - loss_fake: 0.2874949872493744 - loss_gan: 0.0010474396403878927
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 2 - Batch: 31
# loss_real: 0.038915298879146576 - loss_fake: 0.2808941602706909 - loss_gan: 0.0009987560333684087
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 2 - Batch: 32
# loss_real: 0.04681021347641945 - loss_fake: 0.2736445665359497 - loss_gan: 0.0008616788545623422
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 2 - Batch: 33
# loss_real: 0.03129568696022034 - loss_fake: 0.26656508445739746 - loss_gan: 0.0008549029007554054
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 19ms/step
# Epoch: 2 - Batch: 34
# loss_real: 0.02840437740087509 - loss_fake: 0.25956493616104126 - loss_gan: 0.0007776169222779572
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 35
# loss_real: 0.0363210067152977 - loss_fake: 0.25166183710098267 - loss_gan: 0.0007574934279546142
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 2 - Batch: 36
# loss_real: 0.039579909294843674 - loss_fake: 0.24484752118587494 - loss_gan: 0.0006723521510139108
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 37
# loss_real: 0.0462481752038002 - loss_fake: 0.23876291513442993 - loss_gan: 0.0006721612298861146
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 2 - Batch: 38
# loss_real: 0.03615683317184448 - loss_fake: 0.23362666368484497 - loss_gan: 0.0005442631663754582
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 2 - Batch: 39
# loss_real: 0.03829456865787506 - loss_fake: 0.22710919380187988 - loss_gan: 0.0005024258280172944
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 2 - Batch: 40
# loss_real: 0.03675407916307449 - loss_fake: 0.22109894454479218 - loss_gan: 0.0005283187492750585
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 2 - Batch: 41
# loss_real: 0.035041116178035736 - loss_fake: 0.21565669775009155 - loss_gan: 0.00047562376130372286
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 2 - Batch: 42
# loss_real: 0.02780705876648426 - loss_fake: 0.20919692516326904 - loss_gan: 0.0004429189139045775
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 2 - Batch: 43
# loss_real: 0.03900851681828499 - loss_fake: 0.2035800814628601 - loss_gan: 0.00043782484135590494
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 2 - Batch: 44
# loss_real: 0.03180776908993721 - loss_fake: 0.1982870101928711 - loss_gan: 0.00036753335734829307
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 2 - Batch: 45
# loss_real: 0.027832183986902237 - loss_fake: 0.1929951310157776 - loss_gan: 0.0004139049560762942
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  3
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 3 - Batch: 0
# loss_real: 0.02795088291168213 - loss_fake: 0.1877121925354004 - loss_gan: 0.000353664014255628
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 3 - Batch: 1
# loss_real: 0.031099464744329453 - loss_fake: 0.18256458640098572 - loss_gan: 0.00037706608418375254
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 3 - Batch: 2
# loss_real: 0.03076617792248726 - loss_fake: 0.1777786910533905 - loss_gan: 0.00032246450427919626
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 3
# loss_real: 0.030964355915784836 - loss_fake: 0.17288324236869812 - loss_gan: 0.00033425772562623024
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 4
# loss_real: 0.03563075140118599 - loss_fake: 0.16881126165390015 - loss_gan: 0.00029784999787807465
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 3 - Batch: 5
# loss_real: 0.025959493592381477 - loss_fake: 0.1644086241722107 - loss_gan: 0.00025830455706454813
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 3 - Batch: 6
# loss_real: 0.025817254558205605 - loss_fake: 0.16013112664222717 - loss_gan: 0.00026833987794816494
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 3 - Batch: 7
# loss_real: 0.026821210980415344 - loss_fake: 0.15629476308822632 - loss_gan: 0.0002473783097229898
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 3 - Batch: 8
# loss_real: 0.02899136207997799 - loss_fake: 0.15275347232818604 - loss_gan: 0.0002190927043557167
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 419us/step
# Epoch: 3 - Batch: 9
# loss_real: 0.028227834030985832 - loss_fake: 0.1491248905658722 - loss_gan: 0.00021163068595342338
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 3 - Batch: 10
# loss_real: 0.023399891331791878 - loss_fake: 0.145160973072052 - loss_gan: 0.0002219340531155467
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 11
# loss_real: 0.027687376365065575 - loss_fake: 0.14102770388126373 - loss_gan: 0.00020317557209637016
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 12
# loss_real: 0.03675263375043869 - loss_fake: 0.13782699406147003 - loss_gan: 0.00019904055807273835
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 13
# loss_real: 0.04387673735618591 - loss_fake: 0.13493990898132324 - loss_gan: 0.00017636928532738239
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 3 - Batch: 14
# loss_real: 0.026059040799736977 - loss_fake: 0.13237768411636353 - loss_gan: 0.00015659196651540697
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 15
# loss_real: 0.03422714024782181 - loss_fake: 0.13047102093696594 - loss_gan: 0.000150070438394323
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 16
# loss_real: 0.021481841802597046 - loss_fake: 0.1269405484199524 - loss_gan: 0.00016866001533344388
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 17
# loss_real: 0.033691421151161194 - loss_fake: 0.12388002872467041 - loss_gan: 0.0001407455129083246
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 18ms/step
# Epoch: 3 - Batch: 18
# loss_real: 0.03275517374277115 - loss_fake: 0.1212863177061081 - loss_gan: 0.00011161764268763363
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 3 - Batch: 19
# loss_real: 0.023559000343084335 - loss_fake: 0.11924173682928085 - loss_gan: 0.00012084459740435705
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 20
# loss_real: 0.022449716925621033 - loss_fake: 0.1168556809425354 - loss_gan: 0.00010748986096587032
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 3 - Batch: 21
# loss_real: 0.025845298543572426 - loss_fake: 0.11460646986961365 - loss_gan: 0.00011777116742450744
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 3 - Batch: 22
# loss_real: 0.021503958851099014 - loss_fake: 0.11174392700195312 - loss_gan: 0.00010672572534531355
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 3 - Batch: 23
# loss_real: 0.02411273494362831 - loss_fake: 0.10921593010425568 - loss_gan: 8.598774729762226e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 24
# loss_real: 0.016641004011034966 - loss_fake: 0.10661432892084122 - loss_gan: 9.176147432299331e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 3 - Batch: 25
# loss_real: 0.026187710464000702 - loss_fake: 0.10424081981182098 - loss_gan: 0.00010625671711750329
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 3 - Batch: 26
# loss_real: 0.028662454336881638 - loss_fake: 0.10220463573932648 - loss_gan: 7.579087105114013e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 3 - Batch: 27
# loss_real: 0.021195920184254646 - loss_fake: 0.10027424246072769 - loss_gan: 7.781874592183158e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 3 - Batch: 28
# loss_real: 0.023517433553934097 - loss_fake: 0.09818205237388611 - loss_gan: 7.119038491509855e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 3 - Batch: 29
# loss_real: 0.017905939370393753 - loss_fake: 0.09647749364376068 - loss_gan: 7.162083056755364e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 3 - Batch: 30
# loss_real: 0.028458371758461 - loss_fake: 0.09426519274711609 - loss_gan: 6.293390470091254e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 3 - Batch: 31
# loss_real: 0.016007501631975174 - loss_fake: 0.09228375554084778 - loss_gan: 6.494726403616369e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 3 - Batch: 32
# loss_real: 0.04221341758966446 - loss_fake: 0.09032922238111496 - loss_gan: 5.999086715746671e-05
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 3 - Batch: 33
# loss_real: 0.025704003870487213 - loss_fake: 0.08888550102710724 - loss_gan: 6.119773752288893e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 34
# loss_real: 0.015017383731901646 - loss_fake: 0.08671048283576965 - loss_gan: 5.60449407203123e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 35
# loss_real: 0.023774731904268265 - loss_fake: 0.08537761867046356 - loss_gan: 6.595852028112859e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 3 - Batch: 36
# loss_real: 0.0232832133769989 - loss_fake: 0.0839361697435379 - loss_gan: 5.038540257373825e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 37
# loss_real: 0.0227106511592865 - loss_fake: 0.08254201710224152 - loss_gan: 5.707523814635351e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 3 - Batch: 38
# loss_real: 0.016753118485212326 - loss_fake: 0.08092863112688065 - loss_gan: 5.145510294823907e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 3 - Batch: 39
# loss_real: 0.018384044989943504 - loss_fake: 0.07903766632080078 - loss_gan: 6.04078704782296e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 3 - Batch: 40
# loss_real: 0.02053854987025261 - loss_fake: 0.07764160633087158 - loss_gan: 4.902822183794342e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 3 - Batch: 41
# loss_real: 0.02718590758740902 - loss_fake: 0.07622841000556946 - loss_gan: 4.55123808933422e-05
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 42
# loss_real: 0.013778341002762318 - loss_fake: 0.07454371452331543 - loss_gan: 4.79794034617953e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 3 - Batch: 43
# loss_real: 0.017347903922200203 - loss_fake: 0.07302519679069519 - loss_gan: 4.632771378965117e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 3 - Batch: 44
# loss_real: 0.024973846971988678 - loss_fake: 0.07173553109169006 - loss_gan: 4.211286432109773e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 45
# loss_real: 0.03523971885442734 - loss_fake: 0.07115637511014938 - loss_gan: 4.256117972545326e-05
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  4
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 0
# loss_real: 0.014906208962202072 - loss_fake: 0.07056381553411484 - loss_gan: 4.210598854115233e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 4 - Batch: 1
# loss_real: 0.013034841977059841 - loss_fake: 0.06912392377853394 - loss_gan: 3.1528576073469594e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 4 - Batch: 2
# loss_real: 0.016985107213258743 - loss_fake: 0.06734329462051392 - loss_gan: 3.84139857487753e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 3
# loss_real: 0.034578774124383926 - loss_fake: 0.06601832807064056 - loss_gan: 4.199390241410583e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 4
# loss_real: 0.011702345684170723 - loss_fake: 0.06474821269512177 - loss_gan: 3.8045007386244833e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 4 - Batch: 5
# loss_real: 0.02189578488469124 - loss_fake: 0.06393246352672577 - loss_gan: 3.892983659170568e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 4 - Batch: 6
# loss_real: 0.04882783070206642 - loss_fake: 0.06335335969924927 - loss_gan: 4.040528438054025e-05
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 4 - Batch: 7
# loss_real: 0.009740237146615982 - loss_fake: 0.06290537118911743 - loss_gan: 2.7032048819819465e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 8
# loss_real: 0.008157520554959774 - loss_fake: 0.06158165633678436 - loss_gan: 3.1150200811680406e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 9
# loss_real: 0.01009318232536316 - loss_fake: 0.059136077761650085 - loss_gan: 3.2060368539532647e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 10
# loss_real: 0.011377363465726376 - loss_fake: 0.05691063031554222 - loss_gan: 3.379108238732442e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 11
# loss_real: 0.01681997999548912 - loss_fake: 0.05452414229512215 - loss_gan: 3.0325361876748502e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 12
# loss_real: 0.009261330589652061 - loss_fake: 0.05273877829313278 - loss_gan: 3.94120579585433e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 4 - Batch: 13
# loss_real: 0.020050134509801865 - loss_fake: 0.05077783390879631 - loss_gan: 2.7626138034975156e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 14
# loss_real: 0.015581095591187477 - loss_fake: 0.04904074966907501 - loss_gan: 3.154735895805061e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 15
# loss_real: 0.008678557351231575 - loss_fake: 0.04818569868803024 - loss_gan: 2.9776711016893387e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 4 - Batch: 16
# loss_real: 0.01926357112824917 - loss_fake: 0.04702499508857727 - loss_gan: 2.5425420972169377e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 4 - Batch: 17
# loss_real: 0.015544334426522255 - loss_fake: 0.04642655700445175 - loss_gan: 3.050325540243648e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 4 - Batch: 18
# loss_real: 0.007306963205337524 - loss_fake: 0.045069579035043716 - loss_gan: 2.2884749341756105e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 19
# loss_real: 0.013569901697337627 - loss_fake: 0.04387159273028374 - loss_gan: 2.4186259906855412e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 4 - Batch: 20
# loss_real: 0.015172531828284264 - loss_fake: 0.04284633696079254 - loss_gan: 2.0803599909413606e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 4 - Batch: 21
# loss_real: 0.01294794213026762 - loss_fake: 0.042005255818367004 - loss_gan: 2.481772935425397e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 22
# loss_real: 0.016105495393276215 - loss_fake: 0.04130975902080536 - loss_gan: 2.4229449991253205e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 4 - Batch: 23
# loss_real: 0.007748573552817106 - loss_fake: 0.040724579244852066 - loss_gan: 2.5180514057865366e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 24
# loss_real: 0.007487116381525993 - loss_fake: 0.03980249539017677 - loss_gan: 2.4040342395892367e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 25
# loss_real: 0.020493488758802414 - loss_fake: 0.039467379450798035 - loss_gan: 2.539234992582351e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 26
# loss_real: 0.021809030324220657 - loss_fake: 0.03924613445997238 - loss_gan: 2.0103374481550418e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 27
# loss_real: 0.0150547344237566 - loss_fake: 0.039500921964645386 - loss_gan: 1.8045488104689866e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 4 - Batch: 28
# loss_real: 0.00993435364216566 - loss_fake: 0.038996968418359756 - loss_gan: 2.0689221855718642e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 4 - Batch: 29
# loss_real: 0.021330080926418304 - loss_fake: 0.03859417140483856 - loss_gan: 1.68007354659494e-05
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 4 - Batch: 30
# loss_real: 0.005540614016354084 - loss_fake: 0.03784570097923279 - loss_gan: 1.6324847820214927e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 31
# loss_real: 0.02483046054840088 - loss_fake: 0.03720686584711075 - loss_gan: 1.7432936147088185e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 32
# loss_real: 0.028204722329974174 - loss_fake: 0.03759279102087021 - loss_gan: 1.6033580322982743e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 33
# loss_real: 0.005821692757308483 - loss_fake: 0.03727639839053154 - loss_gan: 1.607111335033551e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 18ms/step
# Epoch: 4 - Batch: 34
# loss_real: 0.0075311120599508286 - loss_fake: 0.037141866981983185 - loss_gan: 1.607790545676835e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 4 - Batch: 35
# loss_real: 0.0063270386308431625 - loss_fake: 0.03570207208395004 - loss_gan: 1.836169758462347e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 36
# loss_real: 0.008229615166783333 - loss_fake: 0.034606270492076874 - loss_gan: 1.776607496140059e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 37
# loss_real: 0.0225762277841568 - loss_fake: 0.033971741795539856 - loss_gan: 1.8128448573406786e-05
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 4 - Batch: 38
# loss_real: 0.008127009496092796 - loss_fake: 0.03315269201993942 - loss_gan: 1.7384027160005644e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 39
# loss_real: 0.00717281736433506 - loss_fake: 0.03282151371240616 - loss_gan: 1.7477181245340034e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 4 - Batch: 40
# ...
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 22
# loss_real: 0.2595481872558594 - loss_fake: 1.1195294857025146 - loss_gan: 0.9603477716445923
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.0546875
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 23
# loss_real: 0.3114604353904724 - loss_fake: 1.1212254762649536 - loss_gan: 0.9530626535415649
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.046875
# 2/2 [==============================] - 0s 19ms/step
# Epoch: 20 - Batch: 24
# loss_real: 0.2518100142478943 - loss_fake: 1.1174914836883545 - loss_gan: 0.9736403226852417
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.03125
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 20 - Batch: 25
# loss_real: 0.30633533000946045 - loss_fake: 1.1245858669281006 - loss_gan: 0.9873530864715576
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 0.015625
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 26
# loss_real: 0.29271161556243896 - loss_fake: 1.1149744987487793 - loss_gan: 0.98616623878479
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.015625
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 20 - Batch: 27
# loss_real: 0.2998005151748657 - loss_fake: 1.1341924667358398 - loss_gan: 0.9797098636627197
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.0234375
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 20 - Batch: 28
# loss_real: 0.2710358798503876 - loss_fake: 1.1571896076202393 - loss_gan: 0.9502609372138977
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.0390625
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 29
# loss_real: 0.2769910991191864 - loss_fake: 1.1603872776031494 - loss_gan: 0.947821319103241
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.046875
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 20 - Batch: 30
# loss_real: 0.26356905698776245 - loss_fake: 1.16754949092865 - loss_gan: 0.9571224451065063
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.0390625
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 20 - Batch: 31
# loss_real: 0.26552194356918335 - loss_fake: 1.160556674003601 - loss_gan: 0.9679479598999023
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.0390625
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 20 - Batch: 32
# loss_real: 0.2586902976036072 - loss_fake: 1.1681339740753174 - loss_gan: 0.9732505083084106
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.03125
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 20 - Batch: 33
# loss_real: 0.2584918737411499 - loss_fake: 1.1453216075897217 - loss_gan: 0.9801480770111084
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 20 - Batch: 34
# loss_real: 0.27944791316986084 - loss_fake: 1.1296486854553223 - loss_gan: 1.0030609369277954
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.03125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 35
# loss_real: 0.2996254563331604 - loss_fake: 1.1484332084655762 - loss_gan: 0.9900686144828796
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.0078125
# 2/2 [==============================] - 0s 19ms/step
# Epoch: 20 - Batch: 36
# loss_real: 0.288504958152771 - loss_fake: 1.1512101888656616 - loss_gan: 0.9946152567863464
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.015625
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 37
# loss_real: 0.27842941880226135 - loss_fake: 1.163712978363037 - loss_gan: 0.9925359487533569
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.0078125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 38
# loss_real: 0.22807109355926514 - loss_fake: 1.1739686727523804 - loss_gan: 0.9845291972160339
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.03125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 39
# loss_real: 0.2692899703979492 - loss_fake: 1.164647102355957 - loss_gan: 0.984856903553009
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 0.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 40
# loss_real: 0.2513691186904907 - loss_fake: 1.173949956893921 - loss_gan: 0.9927393198013306
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.0390625
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 20 - Batch: 41
# loss_real: 0.2973497211933136 - loss_fake: 1.178229570388794 - loss_gan: 1.0000933408737183
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 0.0390625
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 20 - Batch: 42
# loss_real: 0.28827527165412903 - loss_fake: 1.1886310577392578 - loss_gan: 0.9883074760437012
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 0.0234375
# 2/2 [==============================] - 0s 0s/step
# Epoch: 20 - Batch: 43
# loss_real: 0.26435890793800354 - loss_fake: 1.1956552267074585 - loss_gan: 0.9753395318984985
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.0546875
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 20 - Batch: 44
# loss_real: 0.2520069479942322 - loss_fake: 1.2062679529190063 - loss_gan: 1.0074530839920044
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.0078125
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 20 - Batch: 45
# loss_real: 0.3009033799171448 - loss_fake: 1.1927881240844727 - loss_gan: 1.000718355178833
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.0390625
# Epoch :  21
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 21 - Batch: 0
# loss_real: 0.31612592935562134 - loss_fake: 1.1868484020233154 - loss_gan: 0.9857239723205566
# acc_real: 0.921875 - acc_fake: 0.0 - acc_gan: 0.03125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 1
# loss_real: 0.2998479902744293 - loss_fake: 1.1925246715545654 - loss_gan: 0.981224775314331
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 0.03125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 2
# loss_real: 0.4020387530326843 - loss_fake: 1.1889424324035645 - loss_gan: 0.9919589757919312
# acc_real: 0.890625 - acc_fake: 0.0 - acc_gan: 0.046875
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 3
# loss_real: 0.3397500216960907 - loss_fake: 1.2222392559051514 - loss_gan: 0.9355751872062683
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.0703125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 4
# loss_real: 0.2882409691810608 - loss_fake: 1.2613556385040283 - loss_gan: 0.9402548670768738
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.0625
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 5
# loss_real: 0.2846226692199707 - loss_fake: 1.2538434267044067 - loss_gan: 0.9211791157722473
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.0625
# 2/2 [==============================] - 0s 15ms/step
# Epoch: 21 - Batch: 6
# loss_real: 0.2969200015068054 - loss_fake: 1.2594869136810303 - loss_gan: 0.9102297425270081
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.0625
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 21 - Batch: 7
# loss_real: 0.2898479104042053 - loss_fake: 1.2579933404922485 - loss_gan: 0.8919800519943237
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.1015625
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 8
# loss_real: 0.30057621002197266 - loss_fake: 1.256793737411499 - loss_gan: 0.8944981694221497
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.1328125
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 21 - Batch: 9
# loss_real: 0.36397677659988403 - loss_fake: 1.241310715675354 - loss_gan: 0.8851627111434937
# acc_real: 0.90625 - acc_fake: 0.0 - acc_gan: 0.078125
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 21 - Batch: 10
# loss_real: 0.25266194343566895 - loss_fake: 1.2234306335449219 - loss_gan: 0.9004058241844177
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.109375
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 21 - Batch: 11
# loss_real: 0.28221195936203003 - loss_fake: 1.2051942348480225 - loss_gan: 0.9087093472480774
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.1015625
# 2/2 [==============================] - 0s 1ms/step
# Epoch: 21 - Batch: 12
# loss_real: 0.3014541268348694 - loss_fake: 1.175945520401001 - loss_gan: 0.9117379188537598
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.046875
# 2/2 [==============================] - 0s 20ms/step
# Epoch: 21 - Batch: 13
# loss_real: 0.2799932360649109 - loss_fake: 1.1619393825531006 - loss_gan: 0.9128665328025818
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.09375
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 14
# loss_real: 0.27644509077072144 - loss_fake: 1.1487057209014893 - loss_gan: 0.8992516994476318
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.1171875
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 21 - Batch: 15
# loss_real: 0.3269041180610657 - loss_fake: 1.1313859224319458 - loss_gan: 0.9100974798202515
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 0.109375
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 16
# loss_real: 0.26882871985435486 - loss_fake: 1.16184401512146 - loss_gan: 0.892886221408844
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 0.125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 17
# loss_real: 0.30624333024024963 - loss_fake: 1.1514451503753662 - loss_gan: 0.8840528726577759
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.109375
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 18
# loss_real: 0.327792227268219 - loss_fake: 1.164764404296875 - loss_gan: 0.8601507544517517
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.1328125
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 21 - Batch: 19
# loss_real: 0.34289830923080444 - loss_fake: 1.2077279090881348 - loss_gan: 0.8595181703567505
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 0.1328125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 20
# loss_real: 0.27398696541786194 - loss_fake: 1.205640196800232 - loss_gan: 0.8277035355567932
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.1796875
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 21
# loss_real: 0.3323988914489746 - loss_fake: 1.2249324321746826 - loss_gan: 0.7993361949920654
# acc_real: 0.953125 - acc_fake: 0.0 - acc_gan: 0.1953125
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 21 - Batch: 22
# loss_real: 0.2811414897441864 - loss_fake: 1.2344121932983398 - loss_gan: 0.8191767334938049
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.1875
# 2/2 [==============================] - 0s 18ms/step
# Epoch: 21 - Batch: 23
# loss_real: 0.2871187925338745 - loss_fake: 1.2167184352874756 - loss_gan: 0.8313432335853577
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.21875
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 24
# loss_real: 0.3073042035102844 - loss_fake: 1.2025413513183594 - loss_gan: 0.8164377808570862
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.2109375
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 21 - Batch: 25
# loss_real: 0.2657705247402191 - loss_fake: 1.1752527952194214 - loss_gan: 0.8365317583084106
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 0.125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 26
# loss_real: 0.36563795804977417 - loss_fake: 1.171629786491394 - loss_gan: 0.8516889810562134
# acc_real: 0.921875 - acc_fake: 0.0 - acc_gan: 0.125
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 21 - Batch: 27
# loss_real: 0.27557653188705444 - loss_fake: 1.1632301807403564 - loss_gan: 0.8461173176765442
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.1484375
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 28
# loss_real: 0.26669928431510925 - loss_fake: 1.1709970235824585 - loss_gan: 0.8343839049339294
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.1015625
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 21 - Batch: 29
# loss_real: 0.29491090774536133 - loss_fake: 1.1580674648284912 - loss_gan: 0.8637325763702393
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.0625
# 2/2 [==============================] - 0s 18ms/step
# Epoch: 21 - Batch: 30
# loss_real: 0.28066763281822205 - loss_fake: 1.1391184329986572 - loss_gan: 0.8513052463531494
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.09375
# 2/2 [==============================] - 0s 1ms/step
# Epoch: 21 - Batch: 31
# loss_real: 0.24633854627609253 - loss_fake: 1.1017400026321411 - loss_gan: 0.8603358864784241
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.0859375
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 32
# loss_real: 0.284339964389801 - loss_fake: 1.0992779731750488 - loss_gan: 0.8892745971679688
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.046875
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 33
# loss_real: 0.3016135096549988 - loss_fake: 1.0987894535064697 - loss_gan: 0.8704111576080322
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.046875
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 21 - Batch: 34
# loss_real: 0.24454185366630554 - loss_fake: 1.0912511348724365 - loss_gan: 0.8846015930175781
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 0.0625
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 21 - Batch: 35
# loss_real: 0.26985645294189453 - loss_fake: 1.0848572254180908 - loss_gan: 0.8657371997833252
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 0.0703125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 36
# loss_real: 0.2599838972091675 - loss_fake: 1.073242425918579 - loss_gan: 0.8820443153381348
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.0859375
# 2/2 [==============================] - 0s 0s/step
# Epoch: 21 - Batch: 37
# loss_real: 0.24570932984352112 - loss_fake: 1.0656213760375977 - loss_gan: 0.8638685941696167
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.0625
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 21 - Batch: 38
# loss_real: 0.2667730450630188 - loss_fake: 1.0486257076263428 - loss_gan: 0.8839864134788513
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.046875
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 21 - Batch: 39
# loss_real: 0.2809777855873108 - loss_fake: 1.0400357246398926 - loss_gan: 0.8457717299461365
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 0.09375
# 2/2 [==============================] - 0s 1ms/step
# Epoch: 21 - Batch: 40
# loss_real: 0.2945370674133301 - loss_fake: 1.0493707656860352 - loss_gan: 0.8464311361312866
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.0703125
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 21 - Batch: 41
# loss_real: 0.22431695461273193 - loss_fake: 1.037042260169983 - loss_gan: 0.829689621925354
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.09375
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 21 - Batch: 42
# loss_real: 0.26690930128097534 - loss_fake: 1.0522093772888184 - loss_gan: 0.809017539024353
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.1484375
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 21 - Batch: 43
# loss_real: 0.281883180141449 - loss_fake: 1.0575833320617676 - loss_gan: 0.8015590310096741
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.140625
# 2/2 [==============================] - 0s 19ms/step
# Epoch: 21 - Batch: 44
# loss_real: 0.2857341170310974 - loss_fake: 1.0598475933074951 - loss_gan: 0.7846148610115051
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.1875
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 21 - Batch: 45
# loss_real: 0.25408101081848145 - loss_fake: 1.0639681816101074 - loss_gan: 0.7842799425125122
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 0.1875
# Epoch :  22
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 22 - Batch: 0
# loss_real: 0.23637481033802032 - loss_fake: 1.0692007541656494 - loss_gan: 0.7782783508300781
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 0.203125
# 2/2 [==============================] - 0s 0s/step
# Epoch: 22 - Batch: 1
# loss_real: 0.26507142186164856 - loss_fake: 1.0575294494628906 - loss_gan: 0.7772844433784485
# acc_real: 0.984375 - acc_fake: 0.0 - acc_gan: 0.171875
# 2/2 [==============================] - 0s 0s/step

# %%
plt.imshow(values)

# %%
# Hay que intentar estabilizar la red

X_pru = np.random.randn(49)
generadas = generador.predict(X_pru)
for i in range(49):
  plt.subplot(7,7,i+1)
  plt.axis('off')
  plt.imshow(generadas[i], cmap="binary")
plt.show()
# Out:
# 2/2 [==============================] - 0s 6ms/step
