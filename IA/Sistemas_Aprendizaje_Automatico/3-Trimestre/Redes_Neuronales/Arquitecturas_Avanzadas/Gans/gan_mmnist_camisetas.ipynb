# %%
import random

import matplotlib.pyplot as plt
import numpy as np

import tensorflow
import keras
from tensorflow.keras.layers import Dense, Conv2DTranspose, LeakyReLU, Reshape, BatchNormalization, Activation, Conv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dropout, MaxPool2D
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.datasets import  fashion_mnist

# %% [markdown]
# # Cargar MNist

# %% [markdown]
# Nos quedamos solo las camisetas que son donde es 0

# %%
def cargar_imagenes():
    (Xtrain, Ytrain), (_, _) = fashion_mnist.load_data()

    # Nos quedamos con las camiseta
    indice = np.where(Ytrain == 0)
    indice = indice[0]
    Xtrain = Xtrain[indice, :,:]
    # Normalizamos los datos
    X = Xtrain.astype('float32') / 255.0
    return X

dataset = cargar_imagenes()

for i in range(49):
  plt.subplot(7, 7, 1 + i)
  plt.axis('off')
  plt.imshow(dataset[i], cmap="binary")

dataset.shape
# Out:
# (6000, 28, 28)

# %% [markdown]
# # Creación del discriminador

# %%
discriminador = Sequential()

# Padding same permite que si es multiplo de 3 no se pierdan valores
discriminador.add(Conv2D(8,kernel_size=3,padding="same",
                         input_shape=(dataset.shape[1],dataset.shape[2],1),activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Conv2D(32,kernel_size=3,padding="same",activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Conv2D(64,kernel_size=3,padding="same",activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Flatten())

discriminador.add(Dense(32,activation="relu"))


discriminador.add(Dense(1,activation="sigmoid"))

discriminador.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 28, 28, 8)         80
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 8)         0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 32)        2336
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 64)          18496
#
#  max_pooling2d_11 (MaxPooli  (None, 3, 3, 64)          0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 576)               0
#
#  dense_12 (Dense)            (None, 32)                18464
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 39409 (153.94 KB)
# Trainable params: 39409 (153.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Tiene que haber poco LR para poder entrenar los modelos con calma
discriminador.compile(loss="binary_crossentropy", optimizer = Adam(learning_rate=0.00001), metrics=["accuracy"])

# %%
discriminador.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 28, 28, 8)         80
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 8)         0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 32)        2336
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 64)          18496
#
#  max_pooling2d_11 (MaxPooli  (None, 3, 3, 64)          0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 576)               0
#
#  dense_12 (Dense)            (None, 32)                18464
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 39409 (153.94 KB)
# Trainable params: 39409 (153.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Creación del generador

# %%
generador = Sequential()

# Vamos en incremento para intentar simular el Flatten del modelo Discriminador
generador.add(Dense(32,input_shape=(1,),activation="relu"))

# No tiene porqué pero va beneficiar la cantidad de neuronas = al discriminador
generador.add(Dense(576,activation="relu"))

# La capa de MaxPooling2D antes del Flatten para darle ya un Shape
generador.add(Reshape((3,3,64)))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Lo que hace es que vaya a saltos de 2 como iba la capa de MaxPooling2D duplicando el tamaño x2
# Con Padding = "valid" tendría el mismo (None, 7, 7, 32) en la última capa que el Discriminador
# Ya que podemos gestionar el valor de diferencia con +1 o -1 de tamaño de imagen
generador.add(Conv2DTranspose(64,kernel_size=3, strides=2,padding="valid",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Ahora tenemos que pasar de 7 a 14 con un 16 de Neuronas
generador.add(Conv2DTranspose(32,kernel_size=3, strides=2,padding="same",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Ahora tenemos que pasar de 14 a 28 con 8 de Neuronas
generador.add(Conv2DTranspose(8,kernel_size=3, strides=2,padding="same",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Borra la mitad de las neuronas de vez en cuando
generador.add(Dropout(0.5))

# Ahora una capa con 1 y sin modificar el tamaño con strides=1 y que acabe entre 0 y 1 con sigmoid
generador.add(Conv2DTranspose(1,kernel_size=3,strides=1,padding="same",activation="sigmoid"))

generador.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 32)                64
#
#  dense_15 (Dense)            (None, 576)               19008
#
#  reshape_3 (Reshape)         (None, 3, 3, 64)          0
#
#  batch_normalization_12 (Ba  (None, 3, 3, 64)          256
#  tchNormalization)
#
#  conv2d_transpose_12 (Conv2  (None, 7, 7, 64)          36928
#  DTranspose)
#
#  batch_normalization_13 (Ba  (None, 7, 7, 64)          256
#  tchNormalization)
#
#  conv2d_transpose_13 (Conv2  (None, 14, 14, 32)        18464
#  DTranspose)
#
#  batch_normalization_14 (Ba  (None, 14, 14, 32)        128
#  tchNormalization)
#
#  conv2d_transpose_14 (Conv2  (None, 28, 28, 8)         2312
#  DTranspose)
#
#  batch_normalization_15 (Ba  (None, 28, 28, 8)         32
#  tchNormalization)
#
#  dropout_3 (Dropout)         (None, 28, 28, 8)         0
#
#  conv2d_transpose_15 (Conv2  (None, 28, 28, 1)         73
#  DTranspose)
#
# =================================================================
# Total params: 77521 (302.82 KB)
# Trainable params: 77185 (301.50 KB)
# Non-trainable params: 336 (1.31 KB)
# _________________________________________________________________

# %%
gan = Sequential()
gan.add(generador)
gan.add(discriminador)
gan.compile(loss="binary_crossentropy", optimizer = Adam(learning_rate=0.00001), metrics=["accuracy"])

# %%
def get_datos_true(nmuestras):
    """Devuelve imagenes verdaderas del DataSet

    Args:
        muestras (pd.DataFrame): DataFrame de Pandas

    Returns:
        List: Devuelve el X e Y del DataSet 
    """
    v = np.random.randint(0,dataset.shape[0],nmuestras)
    X = dataset[v]
    y = np.ones((nmuestras,1))
    return X,y

def get_datos_fake(nmuestras):
    """Genera datos falsos con el generador

    Args:
        nmuestras (int): Número de muestras

    Returns:
        List: Devuelve X e Y de un falso DataSet predicho
    """
    input = np.random.rand(nmuestras)
    X = generador.predict(input)
    y = np.zeros((nmuestras,1))
    return X,y

def entrenamiento(epochs=1, batch_size=128):
    """Entrena el modelo de Generador y Detector

    Args:
        epochs (int, optional): Nº de Epochs. Defaults to 1.
        batch_size (int, optional): Tamaño de los saltos. Defaults to 128.
    """
    max_len = dataset.shape[0]
    nbatchs = int(max_len // batch_size)
    acc_r,acc_f,acc_g=[],[],[]
    fake_counter=0
    for epoch in range(epochs):
        print("Epoch : ", epoch)
        for batch in range(nbatchs):

            #region Discriminador
            acc_real = 0.0
            discriminador.trainable = True
            while acc_real < 0.1:
                X_real,y_real = get_datos_true(batch_size//2)
                # Permite entrenar a cachos el discriminador
                loss_real, acc_real = discriminador.train_on_batch(X_real,y_real)

            acc_fake=0.0
            while acc_fake < 0.1:
                X_fake,y_fake = get_datos_fake(batch_size//2)
                # Permite entrenar a cachos el discriminador
                loss_fake, acc_fake = discriminador.train_on_batch(X_fake,y_fake)
                
            discriminador.trainable = False

            #endregion

            #region Generador
            X_gan = np.random.randn(batch_size).reshape(batch_size,1)

            # Tenemos que intentar engañarlo, por lo que ponemos por la salida unos ya que significaría que son correctos
            # Hasta que el otro diga lo contrario
            y_gan = np.ones((batch_size,1))

            acc_gan,indice = 0.0,0
            while acc_gan < 0.1:
                if indice==40: break
                loss_gan, acc_gan = gan.train_on_batch(X_gan,y_gan)
                indice+=1
            #endregion

            print(f"Epoch: {epoch} - Batch: {batch}")
            print(f"loss_real: {loss_real} - loss_fake: {loss_fake} - loss_gan: {loss_gan}")
            print(f"acc_real: {acc_real} - acc_fake: {acc_fake} - acc_gan: {acc_gan}")
            acc_r.append(acc_real)
            acc_f.append(acc_fake)
            acc_g.append(acc_gan)
    return acc_r,acc_f,acc_g

# %%
values=entrenamiento(epochs=50,batch_size=32)
# Out:
# Epoch :  0
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 0
# loss_real: 0.6816678047180176 - loss_fake: 0.6779824495315552 - loss_gan: 0.6294642686843872
# acc_real: 0.9375 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# Epoch: 0 - Batch: 1
# loss_real: 0.5580422878265381 - loss_fake: 0.686128556728363 - loss_gan: 0.6658661961555481
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 0.8125
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 2
# loss_real: 0.5579918622970581 - loss_fake: 0.6835638880729675 - loss_gan: 0.5649629831314087
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# Epoch: 0 - Batch: 3
# loss_real: 0.4746267795562744 - loss_fake: 0.6847761869430542 - loss_gan: 0.49407970905303955
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 4
# loss_real: 0.4209049344062805 - loss_fake: 0.672831654548645 - loss_gan: 0.414599746465683
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 5
# loss_real: 0.3492076098918915 - loss_fake: 0.6527357697486877 - loss_gan: 0.31736570596694946
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 6
# loss_real: 0.28344839811325073 - loss_fake: 0.6839739084243774 - loss_gan: 0.1851537525653839
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# Epoch: 0 - Batch: 7
# loss_real: 0.20662444829940796 - loss_fake: 0.6577982902526855 - loss_gan: 0.11475883424282074
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 8
# loss_real: 0.15026777982711792 - loss_fake: 0.6466939449310303 - loss_gan: 0.0626617968082428
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 9
# loss_real: 0.11348797380924225 - loss_fake: 0.6352675557136536 - loss_gan: 0.029110394418239594
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 10
# loss_real: 0.07006888836622238 - loss_fake: 0.6403400897979736 - loss_gan: 0.011914090253412724
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 27ms/step
# Epoch: 0 - Batch: 11
# loss_real: 0.061119094491004944 - loss_fake: 0.6042910218238831 - loss_gan: 0.004353114403784275
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 12
# loss_real: 0.036239687353372574 - loss_fake: 0.5907255411148071 - loss_gan: 0.0015389745822176337
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 13
# loss_real: 0.028534788638353348 - loss_fake: 0.5777820348739624 - loss_gan: 0.00038426340324804187
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 14
# loss_real: 0.01777416095137596 - loss_fake: 0.5577610731124878 - loss_gan: 9.436235995963216e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 15
# loss_real: 0.012231158092617989 - loss_fake: 0.531449019908905 - loss_gan: 2.101630343531724e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 0 - Batch: 16
# loss_real: 0.006051685661077499 - loss_fake: 0.5034104585647583 - loss_gan: 5.63510957363178e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# Epoch: 0 - Batch: 17
# loss_real: 0.0034720550756901503 - loss_fake: 0.471488893032074 - loss_gan: 6.957491223147372e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 18ms/step
# Epoch: 0 - Batch: 18
# loss_real: 0.0035694516263902187 - loss_fake: 0.43535441160202026 - loss_gan: 1.7936469021151424e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# Epoch: 0 - Batch: 19
# loss_real: 0.0016998236533254385 - loss_fake: 0.39755478501319885 - loss_gan: 9.311261095490408e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 20
# loss_real: 0.0020134823862463236 - loss_fake: 0.34719228744506836 - loss_gan: 6.523336537611613e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 21
# loss_real: 0.0018067670753225684 - loss_fake: 0.2995380163192749 - loss_gan: 4.5682021720949706e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 22
# loss_real: 0.002194326603785157 - loss_fake: 0.24967195093631744 - loss_gan: 2.0048332771693822e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 23
# loss_real: 0.0015524118207395077 - loss_fake: 0.19960501790046692 - loss_gan: 1.593840970315341e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 20ms/step
# Epoch: 0 - Batch: 24
# loss_real: 0.009199140593409538 - loss_fake: 0.15248867869377136 - loss_gan: 2.2341277716719787e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 20ms/step
# Epoch: 0 - Batch: 25
# loss_real: 0.0013248708564788103 - loss_fake: 0.11125706136226654 - loss_gan: 4.018080590473261e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 26
# loss_real: 0.001495887292549014 - loss_fake: 0.07879111170768738 - loss_gan: 5.028472083168367e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# Epoch: 0 - Batch: 27
# loss_real: 0.0007757783168926835 - loss_fake: 0.05581985414028168 - loss_gan: 1.6819400039391752e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 28
# loss_real: 0.0002895956567954272 - loss_fake: 0.038103487342596054 - loss_gan: 1.4058363848046262e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 29
# loss_real: 0.0004752478562295437 - loss_fake: 0.02418345771729946 - loss_gan: 6.596155913141111e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 30
# loss_real: 0.0013231659540906549 - loss_fake: 0.015565479174256325 - loss_gan: 7.667554959012168e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 0 - Batch: 31
# loss_real: 0.003051062347367406 - loss_fake: 0.01061302050948143 - loss_gan: 2.363610175637465e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 32
# loss_real: 0.021402476355433464 - loss_fake: 0.010848363861441612 - loss_gan: 3.248532966606578e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 33
# loss_real: 0.00015385716687887907 - loss_fake: 0.022280095145106316 - loss_gan: 6.022551638710898e-15
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 34
# loss_real: 2.7272501029074192e-05 - loss_fake: 0.010728009976446629 - loss_gan: 8.717846052257866e-15
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 35
# loss_real: 0.0001810161047615111 - loss_fake: 0.00498239416629076 - loss_gan: 2.4665047158563616e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 36
# loss_real: 0.001482366002164781 - loss_fake: 0.0030926396138966084 - loss_gan: 4.007545976927179e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 37
# loss_real: 0.0019309226190671325 - loss_fake: 0.0023008398711681366 - loss_gan: 1.9254414143805854e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 38
# loss_real: 0.0007340369047597051 - loss_fake: 0.0019135135225951672 - loss_gan: 3.339741474366921e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 39
# loss_real: 0.00285051460377872 - loss_fake: 0.0016615130007266998 - loss_gan: 1.0101135558418864e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 42ms/step
# Epoch: 0 - Batch: 40
# loss_real: 0.00577015895396471 - loss_fake: 0.0016031195409595966 - loss_gan: 9.945528406228197e-16
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 41
# loss_real: 0.00023794079606886953 - loss_fake: 0.0017624512547627091 - loss_gan: 2.1432245700782007e-16
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 42
# loss_real: 0.00013650720939040184 - loss_fake: 0.001965843141078949 - loss_gan: 3.289866371840597e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 43
# loss_real: 0.00027522124582901597 - loss_fake: 0.002158230636268854 - loss_gan: 2.978336587391081e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 20ms/step
# Epoch: 0 - Batch: 44
# loss_real: 7.345019548665732e-05 - loss_fake: 0.002186718862503767 - loss_gan: 4.370485694220889e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 45
# loss_real: 0.00015441558207385242 - loss_fake: 0.002051274525001645 - loss_gan: 3.262600513617379e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 46
# loss_real: 2.8622491299756803e-05 - loss_fake: 0.001780700869858265 - loss_gan: 5.084735473645115e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 10ms/step
# Epoch: 0 - Batch: 47
# loss_real: 1.7165251847472973e-05 - loss_fake: 0.0014826913829892874 - loss_gan: 7.669065255761875e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 48
# loss_real: 3.4252585464855656e-05 - loss_fake: 0.0012196952011436224 - loss_gan: 5.8518028031323825e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 33ms/step
# Epoch: 0 - Batch: 49
# loss_real: 0.0001508610585005954 - loss_fake: 0.0010099150240421295 - loss_gan: 1.8861312770430033e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 50
# loss_real: 0.0005895147914998233 - loss_fake: 0.0008697978919371963 - loss_gan: 9.364679797813297e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 51
# loss_real: 5.8419940614840016e-05 - loss_fake: 0.0007710885256528854 - loss_gan: 6.788754667028443e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 52
# loss_real: 0.00015610529226250947 - loss_fake: 0.0007104903925210238 - loss_gan: 1.82188746758846e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 53
# loss_real: 5.9389076341176406e-05 - loss_fake: 0.0006655929028056562 - loss_gan: 2.4900728821885874e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 27ms/step
# Epoch: 0 - Batch: 54
# loss_real: 0.00067380431573838 - loss_fake: 0.0006389240734279156 - loss_gan: 2.9926180261029313e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 32ms/step
# Epoch: 0 - Batch: 55
# loss_real: 0.2829497158527374 - loss_fake: 0.005472306162118912 - loss_gan: 7.62954586875809e-23
# acc_real: 0.9375 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 56
# loss_real: 4.2236582231680586e-08 - loss_fake: 0.4241035282611847 - loss_gan: 5.179145432359648e-21
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 57
# loss_real: 4.25120560976211e-06 - loss_fake: 0.0006454649264924228 - loss_gan: 7.871248141125275e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 58
# loss_real: 0.02222229354083538 - loss_fake: 0.0004705338506028056 - loss_gan: 3.89682286439097e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 59
# loss_real: 0.46818870306015015 - loss_fake: 0.0005697684828191996 - loss_gan: 9.158195903025135e-12
# acc_real: 0.75 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 60
# loss_real: 0.07358246296644211 - loss_fake: 0.0009866682812571526 - loss_gan: 7.330004591038324e-15
# acc_real: 0.9375 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 20ms/step
# Epoch: 0 - Batch: 61
# loss_real: 0.01097740326076746 - loss_fake: 0.0016104155220091343 - loss_gan: 1.6128597539769223e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 10ms/step
# Epoch: 0 - Batch: 62
# loss_real: 1.8151646145270206e-05 - loss_fake: 0.002608558628708124 - loss_gan: 3.536399777914269e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 63
# loss_real: 0.0001180373365059495 - loss_fake: 0.007099091075360775 - loss_gan: 9.57457318113903e-22
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 64
# loss_real: 1.060907948158274e-07 - loss_fake: 0.020734865218400955 - loss_gan: 4.937929740949927e-23
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 65
# loss_real: 1.9649181837166907e-08 - loss_fake: 0.036945462226867676 - loss_gan: 4.279363729266821e-24
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 66
# loss_real: 1.279004457899191e-08 - loss_fake: 0.03276614472270012 - loss_gan: 7.421521354785136e-24
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 67
# loss_real: 1.2979802122004003e-08 - loss_fake: 0.019675971940159798 - loss_gan: 1.149437991618246e-22
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 68
# loss_real: 1.5275110953894e-08 - loss_fake: 0.011756297200918198 - loss_gan: 9.53246265005863e-23
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 69
# loss_real: 2.598343940007908e-07 - loss_fake: 0.00842873752117157 - loss_gan: 7.05143956733082e-22
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 70
# loss_real: 3.345310233271448e-06 - loss_fake: 0.006800037808716297 - loss_gan: 7.323238373672226e-21
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 12ms/step
# Epoch: 0 - Batch: 71
# loss_real: 2.6071966203744523e-06 - loss_fake: 0.005847002845257521 - loss_gan: 4.860175944768034e-20
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 72
# loss_real: 2.3981140628848152e-08 - loss_fake: 0.0053734444081783295 - loss_gan: 6.451814907457549e-20
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 73
# loss_real: 1.0384655979578383e-07 - loss_fake: 0.005026613362133503 - loss_gan: 5.627505516358875e-20
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 74
# loss_real: 6.198081337061012e-08 - loss_fake: 0.004727560095489025 - loss_gan: 8.867788949081166e-21
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 75
# loss_real: 1.8123731138075527e-07 - loss_fake: 0.004458834882825613 - loss_gan: 5.508322361021908e-20
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 0 - Batch: 76
# loss_real: 6.781118031540245e-07 - loss_fake: 0.004216579720377922 - loss_gan: 4.764590830590527e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 77
# loss_real: 1.320891129807933e-07 - loss_fake: 0.004021598957479 - loss_gan: 5.116802784451958e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 78
# loss_real: 4.781540610565571e-06 - loss_fake: 0.003839877201244235 - loss_gan: 1.4204719002505947e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 16ms/step
# Epoch: 0 - Batch: 79
# loss_real: 3.4356019114056835e-06 - loss_fake: 0.003663519164547324 - loss_gan: 2.0078146736693515e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 80
# loss_real: 1.0619483958862475e-07 - loss_fake: 0.003486036788672209 - loss_gan: 1.8666321846524426e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 81
# loss_real: 1.8712960354605457e-06 - loss_fake: 0.003337169997394085 - loss_gan: 3.7437431967022835e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 82
# loss_real: 2.371477421547752e-05 - loss_fake: 0.0032046507112681866 - loss_gan: 1.74784400805797e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 83
# loss_real: 5.252722985460423e-06 - loss_fake: 0.0030632736161351204 - loss_gan: 1.087939374493019e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 8ms/step
# Epoch: 0 - Batch: 84
# loss_real: 2.8816991743951803e-06 - loss_fake: 0.0029380102641880512 - loss_gan: 2.1857991260723865e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 85
# loss_real: 2.8089488068872015e-07 - loss_fake: 0.0028128894045948982 - loss_gan: 7.495552541750301e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 28ms/step
# Epoch: 0 - Batch: 86
# loss_real: 5.98131748574815e-07 - loss_fake: 0.002686294261366129 - loss_gan: 1.102122730263736e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 87
# loss_real: 1.2619166511740332e-07 - loss_fake: 0.00258841086179018 - loss_gan: 3.691192670880731e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 88
# loss_real: 2.0417626274138456e-06 - loss_fake: 0.002480108290910721 - loss_gan: 4.479321156136941e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 89
# loss_real: 6.242996732908068e-07 - loss_fake: 0.0023840852081775665 - loss_gan: 3.002536376596779e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 33ms/step
# Epoch: 0 - Batch: 90
# loss_real: 4.468603975738006e-08 - loss_fake: 0.002293751575052738 - loss_gan: 7.6016037137245e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 28ms/step
# Epoch: 0 - Batch: 91
# loss_real: 1.6133984104271804e-07 - loss_fake: 0.0022061539348214865 - loss_gan: 4.47814614607681e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 92
# loss_real: 1.8666007406409335e-07 - loss_fake: 0.0021208710968494415 - loss_gan: 1.5518766491380323e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 93
# loss_real: 1.1951335920912243e-07 - loss_fake: 0.0020395079627633095 - loss_gan: 6.296619177532773e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 94
# loss_real: 1.748745853547007e-05 - loss_fake: 0.001966102747246623 - loss_gan: 2.7662387929360527e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 40ms/step
# Epoch: 0 - Batch: 95
# loss_real: 0.0007027151295915246 - loss_fake: 0.0018932339735329151 - loss_gan: 1.6061521050306992e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 37ms/step
# Epoch: 0 - Batch: 96
# loss_real: 1.0449595720274374e-05 - loss_fake: 0.0018333048792555928 - loss_gan: 1.917005131662055e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 97
# loss_real: 7.042707875370979e-05 - loss_fake: 0.0017670795787125826 - loss_gan: 1.119063906196705e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 33ms/step
# Epoch: 0 - Batch: 98
# loss_real: 4.908256232738495e-05 - loss_fake: 0.0017168561462312937 - loss_gan: 1.8762234731019657e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 14ms/step
# Epoch: 0 - Batch: 99
# loss_real: 4.5752931328024715e-06 - loss_fake: 0.0016542798839509487 - loss_gan: 2.629052335910205e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 42ms/step
# Epoch: 0 - Batch: 100
# loss_real: 7.415418076561764e-05 - loss_fake: 0.0016025921795517206 - loss_gan: 1.0967409070828282e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 101
# loss_real: 7.814396099092846e-07 - loss_fake: 0.0015548024093732238 - loss_gan: 7.861771144924092e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 102
# loss_real: 2.756177934770676e-07 - loss_fake: 0.0015026906039565802 - loss_gan: 9.162864726911946e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 103
# loss_real: 1.3530834053199214e-07 - loss_fake: 0.0014480729587376118 - loss_gan: 3.1699000367297863e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 38ms/step
# Epoch: 0 - Batch: 104
# loss_real: 0.0009319047094322741 - loss_fake: 0.0014066752046346664 - loss_gan: 6.025639048161041e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# Epoch: 0 - Batch: 105
# loss_real: 9.087055730105931e-08 - loss_fake: 0.0013697603717446327 - loss_gan: 8.708144932627765e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 106
# loss_real: 4.817019885194895e-07 - loss_fake: 0.0013261187123134732 - loss_gan: 1.0309331886031614e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 0 - Batch: 107
# loss_real: 8.454470616925391e-07 - loss_fake: 0.0012881082948297262 - loss_gan: 9.619432235889418e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 108
# loss_real: 5.59369425445766e-07 - loss_fake: 0.001248842803761363 - loss_gan: 1.6482147561669035e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 109
# loss_real: 4.408153415624838e-07 - loss_fake: 0.0012118809390813112 - loss_gan: 1.0679943955631404e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 110
# loss_real: 1.1390940017008688e-05 - loss_fake: 0.0011825659312307835 - loss_gan: 1.632267618685676e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 111
# loss_real: 5.288597094477154e-06 - loss_fake: 0.0011469470337033272 - loss_gan: 6.164867503926552e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 0 - Batch: 112
# loss_real: 1.1783997251768596e-05 - loss_fake: 0.0011115038068965077 - loss_gan: 1.4705424610475307e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 29ms/step
# Epoch: 0 - Batch: 113
# loss_real: 3.0540434181602905e-07 - loss_fake: 0.0010838434100151062 - loss_gan: 5.887520048392116e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 114
# loss_real: 2.8879494351485846e-08 - loss_fake: 0.0010550380684435368 - loss_gan: 5.163039285561528e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 115
# loss_real: 1.3477915672410745e-06 - loss_fake: 0.001029723440296948 - loss_gan: 1.154024591388682e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 116
# loss_real: 0.0003442350425757468 - loss_fake: 0.0009961017640307546 - loss_gan: 4.1493079381818665e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 117
# loss_real: 3.3409235129511217e-06 - loss_fake: 0.0009712123428471386 - loss_gan: 5.083338675783242e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 118
# loss_real: 3.818826371571049e-05 - loss_fake: 0.0009486150229349732 - loss_gan: 3.621510976079264e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 119
# loss_real: 1.7467397128712037e-06 - loss_fake: 0.000926081498619169 - loss_gan: 2.4514876776680407e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 40ms/step
# Epoch: 0 - Batch: 120
# loss_real: 7.154318154789507e-05 - loss_fake: 0.0009004086023196578 - loss_gan: 7.578657723532279e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 121
# loss_real: 3.4088288884959184e-06 - loss_fake: 0.0008802515803836286 - loss_gan: 2.1998154947569444e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 122
# loss_real: 0.0008027299772948027 - loss_fake: 0.0008548077894374728 - loss_gan: 6.35150219758536e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 123
# loss_real: 3.4039694583043456e-05 - loss_fake: 0.0008384076645597816 - loss_gan: 1.0453250972858184e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 26ms/step
# Epoch: 0 - Batch: 124
# loss_real: 1.5442037692992017e-05 - loss_fake: 0.0008216631831601262 - loss_gan: 3.805590819018626e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 0 - Batch: 125
# loss_real: 2.3740540200378746e-05 - loss_fake: 0.0008053104393184185 - loss_gan: 5.103062280501686e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 126
# loss_real: 1.8783936184263439e-06 - loss_fake: 0.0007889315020292997 - loss_gan: 1.4552628841700278e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 127
# loss_real: 0.0010870856931433082 - loss_fake: 0.0007764615584164858 - loss_gan: 1.2742412313528512e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 128
# loss_real: 9.225007033819566e-07 - loss_fake: 0.0007645405712537467 - loss_gan: 9.801221719110197e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 129
# loss_real: 1.1501744268116454e-07 - loss_fake: 0.0007573101902380586 - loss_gan: 3.180551331284902e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 130
# loss_real: 5.685797646037827e-07 - loss_fake: 0.0007474601734429598 - loss_gan: 1.1914128448833492e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 131
# loss_real: 5.422376148089825e-07 - loss_fake: 0.0007394500426016748 - loss_gan: 1.3783009660023284e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 39ms/step
# Epoch: 0 - Batch: 132
# loss_real: 1.8781568655867886e-07 - loss_fake: 0.0007267965120263398 - loss_gan: 2.781180518232116e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 133
# loss_real: 4.90134482333815e-07 - loss_fake: 0.0007172934710979462 - loss_gan: 8.822900732983012e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 20ms/step
# Epoch: 0 - Batch: 134
# loss_real: 0.0027167501393705606 - loss_fake: 0.0007461490458808839 - loss_gan: 5.112514886951636e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 30ms/step
# Epoch: 0 - Batch: 135
# loss_real: 3.192803887941409e-07 - loss_fake: 0.0007801491883583367 - loss_gan: 2.9818935674226354e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 136
# loss_real: 1.23815816550632e-05 - loss_fake: 0.0007964526885189116 - loss_gan: 5.822417315269013e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 137
# loss_real: 3.664811174530769e-07 - loss_fake: 0.000815505743958056 - loss_gan: 1.6328790861041118e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 138
# loss_real: 6.335020316328155e-06 - loss_fake: 0.0008241665200330317 - loss_gan: 4.273982771454967e-20
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 139
# loss_real: 1.4693753200845094e-06 - loss_fake: 0.0008321359055116773 - loss_gan: 3.461276010164027e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 140
# loss_real: 1.655197593208868e-06 - loss_fake: 0.0008646579226478934 - loss_gan: 1.77607733672563e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 27ms/step
# Epoch: 0 - Batch: 141
# loss_real: 7.724250963292434e-07 - loss_fake: 0.0008537498652003706 - loss_gan: 1.891871041954478e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 142
# loss_real: 1.0062910149599702e-07 - loss_fake: 0.0008344126981683075 - loss_gan: 3.0430229901721284e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 143
# loss_real: 3.597953650569252e-07 - loss_fake: 0.0008224558550864458 - loss_gan: 2.0591874235455991e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 144
# loss_real: 0.00037979710032232106 - loss_fake: 0.0008568531484343112 - loss_gan: 1.0324292481385401e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 145
# loss_real: 7.737054693279788e-05 - loss_fake: 0.0008135734824463725 - loss_gan: 3.1926698374515335e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 146
# loss_real: 3.007991108461283e-05 - loss_fake: 0.0008467077859677374 - loss_gan: 2.690438856733837e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 30ms/step
# Epoch: 0 - Batch: 147
# loss_real: 2.3304502860810317e-07 - loss_fake: 0.0007340568699873984 - loss_gan: 2.1121027101678933e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# Epoch: 0 - Batch: 148
# loss_real: 9.638978372095153e-05 - loss_fake: 0.0008079746039584279 - loss_gan: 6.25483828479272e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 26ms/step
# Epoch: 0 - Batch: 149
# loss_real: 6.67816522081921e-08 - loss_fake: 0.0006983321509324014 - loss_gan: 2.4817444969091585e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 150
# loss_real: 1.1452336678985375e-07 - loss_fake: 0.0006942037143744528 - loss_gan: 2.0810076726229237e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 30ms/step
# Epoch: 0 - Batch: 151
# loss_real: 0.0003592424327507615 - loss_fake: 0.0007018992910161614 - loss_gan: 2.5861925928562293e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# Epoch: 0 - Batch: 152
# loss_real: 1.633150503721481e-07 - loss_fake: 0.0006549813551828265 - loss_gan: 1.2368548390145623e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 153
# loss_real: 3.382555462394521e-07 - loss_fake: 0.0006711818277835846 - loss_gan: 2.778281963628396e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 154
# loss_real: 3.3744749998732004e-06 - loss_fake: 0.0006149918772280216 - loss_gan: 2.384373137897632e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 155
# loss_real: 6.701990059809759e-05 - loss_fake: 0.0006174200098030269 - loss_gan: 1.912875225658731e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 156
# loss_real: 0.006140717305243015 - loss_fake: 0.0006109846290200949 - loss_gan: 5.693056607223376e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 157
# loss_real: 8.51608774610213e-07 - loss_fake: 0.0007788985967636108 - loss_gan: 3.337790569553959e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 158
# loss_real: 1.672927112394973e-07 - loss_fake: 0.0008470391039736569 - loss_gan: 6.54179613147895e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 159
# loss_real: 3.976179527853674e-07 - loss_fake: 0.0009050558437593281 - loss_gan: 3.5065209802130878e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 160
# loss_real: 2.416567213003873e-07 - loss_fake: 0.0009794433135539293 - loss_gan: 3.5621302648434964e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 161
# loss_real: 1.466557705498417e-06 - loss_fake: 0.0011610151268541813 - loss_gan: 3.831910568736721e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 162
# loss_real: 6.802176812925609e-07 - loss_fake: 0.001151378732174635 - loss_gan: 2.973321598132325e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 36ms/step
# Epoch: 0 - Batch: 163
# loss_real: 2.3009420146991033e-07 - loss_fake: 0.00106844212859869 - loss_gan: 5.86651534769998e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 39ms/step
# Epoch: 0 - Batch: 164
# loss_real: 3.4433654946042225e-05 - loss_fake: 0.0009768418967723846 - loss_gan: 2.9832911924651203e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 0 - Batch: 165
# loss_real: 7.367949729086831e-05 - loss_fake: 0.0009953802218660712 - loss_gan: 1.6008755199032234e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 166
# loss_real: 8.064408234531584e-07 - loss_fake: 0.0007255336968228221 - loss_gan: 3.07715385811335e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 167
# loss_real: 7.98679975559935e-05 - loss_fake: 0.0007538341451436281 - loss_gan: 2.815453475123059e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 168
# loss_real: 2.915047332407994e-07 - loss_fake: 0.0005996417021378875 - loss_gan: 2.226581115504721e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 169
# loss_real: 4.0898763131735905e-07 - loss_fake: 0.0005900922697037458 - loss_gan: 1.6180311217304814e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 27ms/step
# Epoch: 0 - Batch: 170
# loss_real: 1.6568438923059148e-06 - loss_fake: 0.00053162791300565 - loss_gan: 2.4857394483955446e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 14ms/step
# Epoch: 0 - Batch: 171
# loss_real: 7.424156365232193e-07 - loss_fake: 0.0005333660519681871 - loss_gan: 3.2460400268818223e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 172
# loss_real: 0.0012603867799043655 - loss_fake: 0.0005312178982421756 - loss_gan: 5.941757718674401e-16
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 0 - Batch: 173
# loss_real: 1.1066606475651497e-06 - loss_fake: 0.0005708530079573393 - loss_gan: 2.528065949467638e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 41ms/step
# Epoch: 0 - Batch: 174
# loss_real: 3.5925620522903046e-06 - loss_fake: 0.000511940976139158 - loss_gan: 7.905760506502086e-18
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 175
# loss_real: 5.872372526027902e-07 - loss_fake: 0.0005577744450420141 - loss_gan: 6.388450204878511e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 176
# loss_real: 4.1566539721316076e-07 - loss_fake: 0.0006000922294333577 - loss_gan: 3.861764158108734e-17
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 28ms/step
# Epoch: 0 - Batch: 177
# loss_real: 0.03693780675530434 - loss_fake: 0.0009947540238499641 - loss_gan: 8.389998861330682e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# Epoch: 0 - Batch: 178
# loss_real: 0.06968805193901062 - loss_fake: 0.010499179363250732 - loss_gan: 2.5540138453112387e-21
# acc_real: 0.9375 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 179
# loss_real: 7.195598300313577e-05 - loss_fake: 0.13641831278800964 - loss_gan: 7.901204912676027e-19
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 180
# loss_real: 2.9287544833778156e-08 - loss_fake: 0.0005836234195157886 - loss_gan: 2.7102257409345777e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 181
# loss_real: 1.734625357130426e-06 - loss_fake: 0.0003150206175632775 - loss_gan: 2.8117561057250384e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 0 - Batch: 182
# loss_real: 0.00013039491022937 - loss_fake: 0.0002718964242376387 - loss_gan: 1.5327020719269058e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 43ms/step
# Epoch: 0 - Batch: 183
# loss_real: 0.0001835102157201618 - loss_fake: 0.00023401372891385108 - loss_gan: 1.9111686924588867e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 29ms/step
# Epoch: 0 - Batch: 184
# loss_real: 0.1793752908706665 - loss_fake: 0.00025528910919092596 - loss_gan: 5.52305709788925e-06
# acc_real: 0.875 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 185
# loss_real: 0.011877368204295635 - loss_fake: 0.0003622549120336771 - loss_gan: 2.8139425012341235e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 0 - Batch: 186
# loss_real: 0.07654846459627151 - loss_fake: 0.0006187468534335494 - loss_gan: 1.185410614112925e-08
# acc_real: 0.9375 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  1
# 1/1 [==============================] - 0s 39ms/step
# Epoch: 1 - Batch: 0
# loss_real: 3.1680135634815088e-06 - loss_fake: 0.0013076013419777155 - loss_gan: 8.616676122619182e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 1 - Batch: 1
# loss_real: 5.8993318816646934e-05 - loss_fake: 0.0037848467472940683 - loss_gan: 5.365176185267995e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 1 - Batch: 2
# loss_real: 7.180905470249854e-08 - loss_fake: 0.009112400934100151 - loss_gan: 2.1582295412631014e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 1 - Batch: 3
# loss_real: 7.675700075537861e-09 - loss_fake: 0.01658274233341217 - loss_gan: 1.1273060393154899e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 34ms/step
# Epoch: 1 - Batch: 4
# loss_real: 1.3974017498696867e-08 - loss_fake: 0.022717664018273354 - loss_gan: 3.194070442164021e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 35ms/step
# Epoch: 1 - Batch: 5
# loss_real: 3.7476522720680805e-06 - loss_fake: 0.02180795557796955 - loss_gan: 1.5679901225074816e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 10ms/step
# Epoch: 1 - Batch: 6
# loss_real: 2.9358286468550432e-08 - loss_fake: 0.016090769320726395 - loss_gan: 1.2935700823219279e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# Epoch: 1 - Batch: 7
# loss_real: 2.734408810489697e-10 - loss_fake: 0.010599233210086823 - loss_gan: 1.3388475508910487e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 45ms/step
# Epoch: 1 - Batch: 8
# loss_real: 1.505472546625697e-08 - loss_fake: 0.0065201749093830585 - loss_gan: 1.9554242123090426e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 96ms/step
# Epoch: 1 - Batch: 9
# loss_real: 3.3513274502183776e-06 - loss_fake: 0.00419152807444334 - loss_gan: 6.969741488593514e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 1 - Batch: 10
# loss_real: 1.2303263474677806e-06 - loss_fake: 0.00305144558660686 - loss_gan: 2.609091057353269e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 1 - Batch: 11
# loss_real: 2.3631807621882217e-08 - loss_fake: 0.0025727683678269386 - loss_gan: 1.1422153912803157e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 1 - Batch: 12
# loss_real: 8.703497655915271e-08 - loss_fake: 0.0023168567568063736 - loss_gan: 7.543929538130975e-14
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# Epoch: 1 - Batch: 13
# loss_real: 4.572639600297634e-09 - loss_fake: 0.0021720195654779673 - loss_gan: 2.0112539834537396e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 1 - Batch: 14
# loss_real: 5.762322530245001e-07 - loss_fake: 0.0020365591626614332 - loss_gan: 8.500437766872926e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 1 - Batch: 15
# loss_real: 3.2803384897306387e-07 - loss_fake: 0.0019126513507217169 - loss_gan: 7.0194440537907354e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 36ms/step
# Epoch: 1 - Batch: 16
# loss_real: 2.732522830228845e-07 - loss_fake: 0.0018198506440967321 - loss_gan: 2.288305829545312e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 1 - Batch: 17
# loss_real: 5.747474496331506e-09 - loss_fake: 0.0017056216020137072 - loss_gan: 4.579521657721575e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 10ms/step
# Epoch: 1 - Batch: 18
# loss_real: 2.9306684155017138e-05 - loss_fake: 0.0016428460367023945 - loss_gan: 2.414313974435922e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 1 - Batch: 19
# loss_real: 4.6034338652134466e-07 - loss_fake: 0.001569870742969215 - loss_gan: 5.331414563297665e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 1 - Batch: 20
# loss_real: 2.908283924796251e-08 - loss_fake: 0.0015106932260096073 - loss_gan: 4.255008888634504e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 24ms/step
# Epoch: 1 - Batch: 21
# loss_real: 1.3269607634924796e-08 - loss_fake: 0.0014347757678478956 - loss_gan: 1.7866694994143895e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 1 - Batch: 22
# loss_real: 2.2447326045949012e-05 - loss_fake: 0.0013684898149222136 - loss_gan: 1.2191987870668886e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 1 - Batch: 23
# loss_real: 0.001371888443827629 - loss_fake: 0.001323866075836122 - loss_gan: 5.402096738688078e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 1 - Batch: 24
# loss_real: 7.837804878363386e-05 - loss_fake: 0.0012938078725710511 - loss_gan: 5.859969085496297e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 1 - Batch: 25
# loss_real: 4.055716544826282e-06 - loss_fake: 0.0012539469171315432 - loss_gan: 3.79176074219445e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# Epoch: 1 - Batch: 26
# loss_real: 1.0311293408449274e-05 - loss_fake: 0.0012210211716592312 - loss_gan: 5.613443737617629e-13
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 25ms/step
# Epoch: 1 - Batch: 27
# loss_real: 3.136259252300988e-08 - loss_fake: 0.0011773311998695135 - loss_gan: 2.5723390431608983e-12
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# ...
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 27ms/step
# Epoch: 14 - Batch: 112
# loss_real: 0.00032634218223392963 - loss_fake: 0.5159202814102173 - loss_gan: 0.4721715450286865
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 32ms/step
# Epoch: 14 - Batch: 113
# loss_real: 0.003365579526871443 - loss_fake: 0.05220998823642731 - loss_gan: 0.017426956444978714
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# Epoch: 14 - Batch: 114
# loss_real: 0.00010942995868390426 - loss_fake: 0.02198612131178379 - loss_gan: 0.05282110720872879
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# Epoch: 14 - Batch: 115
# loss_real: 0.0003270016168244183 - loss_fake: 0.5153663158416748 - loss_gan: 0.47234785556793213
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# Epoch: 14 - Batch: 116
# loss_real: 0.00336261885240674 - loss_fake: 0.052218373864889145 - loss_gan: 0.01739651709794998
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 58ms/step
# Epoch: 14 - Batch: 117
# loss_real: 0.00010888735414482653 - loss_fake: 0.0220047477632761 - loss_gan: 0.05274286866188049
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# Epoch: 14 - Batch: 118
# loss_real: 0.00032979677780531347 - loss_fake: 0.5155690908432007 - loss_gan: 0.47229325771331787
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 values=entrenamiento(epochs=50,batch_size=32)
#
# Cell In[35], line 54, in entrenamiento(epochs, batch_size)
#      52 acc_fake=0.0
#      53 while acc_fake < 0.1:
# ---> 54     X_fake,y_fake = get_datos_fake(batch_size//2)
#      55     # Permite entrenar a cachos el discriminador
#      56     loss_fake, acc_fake = discriminador.train_on_batch(X_fake,y_fake)
#
# Cell In[35], line 25, in get_datos_fake(nmuestras)
#      16 """Genera datos falsos con el generador
#      17
#      18 Args:
#    (...)
#      22     List: Devuelve X e Y de un falso DataSet predicho
#      23 """
#      24 input = np.random.rand(nmuestras)
# ---> 25 X = generador.predict(input)
#      26 y = np.zeros((nmuestras,1))
#      27 return X,y
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\keras\src\engine\training.py:2620, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2611     except ValueError:
#    2612         warnings.warn(
#    2613             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2614             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2617             stacklevel=2,
#    2618         )
# -> 2620 data_handler = data_adapter.get_data_handler(
#    2621     x=x,
#    2622     batch_size=batch_size,
#    2623     steps_per_epoch=steps,
#    2624     initial_epoch=0,
#    2625     epochs=1,
#    2626     max_queue_size=max_queue_size,
#    2627     workers=workers,
#    2628     use_multiprocessing=use_multiprocessing,
#    2629     model=self,
#    2630     steps_per_execution=self._steps_per_execution,
#    2631 )
#    2633 # Container that configures and calls `tf.keras.Callback`s.
#    2634 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\keras\src\engine\data_adapter.py:1688, in get_data_handler(*args, **kwargs)
#    1686         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688 return DataHandler(*args, **kwargs)
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\keras\src\engine\data_adapter.py:1292, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1289     self._steps_per_execution = steps_per_execution
#    1291 adapter_cls = select_data_adapter(x, y)
# -> 1292 self._adapter = adapter_cls(
#    1293     x,
#    1294     y,
#    1295     batch_size=batch_size,
#    1296     steps=steps_per_epoch,
#    1297     epochs=epochs - initial_epoch,
#    1298     sample_weights=sample_weight,
#    1299     shuffle=shuffle,
#    1300     max_queue_size=max_queue_size,
#    1301     workers=workers,
#    1302     use_multiprocessing=use_multiprocessing,
#    1303     distribution_strategy=tf.distribute.get_strategy(),
#    1304     model=model,
#    1305     pss_evaluation_shards=pss_evaluation_shards,
#    1306 )
#    1308 strategy = tf.distribute.get_strategy()
#    1310 self._current_step = 0
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\keras\src\engine\data_adapter.py:314, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     307     return indices
#     309 # We prefetch a single element. Computing large permutations can take
#     310 # quite a while so we don't want to wait for prefetching over an epoch
#     311 # boundary to trigger the next permutation. On the other hand, too many
#     312 # simultaneous shuffles can contend on a hardware level and degrade all
#     313 # performance.
# --> 314 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     316 def slice_batch_indices(indices):
#     317     """Convert a Tensor of indices into a dataset of batched indices.
#     318
#     319     This step can be accomplished in several ways. The most natural is
#    (...)
#     331       A Dataset of batched indices.
#     332     """
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2280, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2276 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2277 # dataset_ops).
#    2278 # pylint: disable=g-import-not-at-top,protected-access
#    2279 from tensorflow.python.data.ops import map_op
# -> 2280 return map_op._map_v2(
#    2281     self,
#    2282     map_func,
#    2283     num_parallel_calls=num_parallel_calls,
#    2284     deterministic=deterministic,
#    2285     name=name)
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\data\ops\map_op.py:37, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      34   if deterministic is not None and not debug_mode.DEBUG_MODE:
#      35     warnings.warn("The `deterministic` argument has no effect unless the "
#      36                   "`num_parallel_calls` argument is specified.")
# ---> 37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
#      40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#    (...)
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\data\ops\map_op.py:107, in _MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     105 self._use_inter_op_parallelism = use_inter_op_parallelism
#     106 self._preserve_cardinality = preserve_cardinality
# --> 107 self._map_func = structured_function.StructuredFunctionWrapper(
#     108     map_func,
#     109     self._transformation_name(),
#     110     dataset=input_dataset,
#     111     use_legacy_function=use_legacy_function)
#     112 self._name = name
#     113 variant_tensor = gen_dataset_ops.map_dataset(
#     114     input_dataset._variant_tensor,  # pylint: disable=protected-access
#     115     self._map_func.function.captured_inputs,
#    (...)
#     118     preserve_cardinality=self._preserve_cardinality,
#     119     **self._common_args)
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1227, in Function.get_concrete_function(self, *args, **kwargs)
#    1225 def get_concrete_function(self, *args, **kwargs):
#    1226   # Implements PolymorphicFunction.get_concrete_function.
# -> 1227   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1228   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1229   return concrete
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1197, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1195   if self._variable_creation_config is None:
#    1196     initializers = []
# -> 1197     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1198     self._initialize_uninitialized_variables(initializers)
#    1200 if self._created_variables:
#    1201   # In this case we have created variables on the first call, so we run the
#    1202   # version which is guaranteed to never create variables.
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:695, in Function._initialize(self, args, kwds, add_initializers_to)
#     690 self._variable_creation_config = self._generate_scoped_tracing_options(
#     691     variable_capturing_scope,
#     692     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     693 )
#     694 # Force the definition of the function for these arguments
# --> 695 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696     args, kwds, self._variable_creation_config
#     697 )
#     699 def invalid_creator_scope(*unused_args, **unused_kwds):
#     700   """Disables variable creation."""
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:340, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     331 output_type = trace_type.from_value(
#     332     traced_func_graph.structured_outputs, type_context
#     333 )
#     334 traced_func_type = function_type_lib.FunctionType(
#     335     function_type.parameters.values(),
#     336     traced_func_graph.function_captures.capture_types,
#     337     return_annotation=output_type,
#     338 )
# --> 340 concrete_function = concrete_function_lib.ConcreteFunction.from_func_graph(
#     341     traced_func_graph,
#     342     traced_func_type,
#     343     tracing_options.attributes,
#     344     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     345     # scope. This is not the default behavior since it gets used in some
#     346     # places (like Keras) where the FuncGraph lives longer than the
#     347     # ConcreteFunction.
#     348     shared_func_graph=False,
#     349 )
#     350 _set_arg_keywords(concrete_function)
#     351 transform.call_concrete_function_callbacks(concrete_function)
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1076, in ConcreteFunction.from_func_graph(cls, graph, function_type, attrs, shared_func_graph)
#    1074 @classmethod
#    1075 def from_func_graph(cls, graph, function_type, attrs, shared_func_graph=True):
# -> 1076   atomic_fn = atomic_function.from_func_graph(
#    1077       _inference_name(graph.name), graph, attrs, function_type
#    1078   )
#    1079   return ConcreteFunction(atomic_fn, shared_func_graph=shared_func_graph)
#
# File c:\Users\diego.guizanlopez\AppData\Local\miniconda3\envs\deep-learning\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:537, in from_func_graph(name, graph, attrs, function_type, overwrite)
#     535   output_names = []
#     536 with graph._c_graph.get() as c_graph:  # pylint: disable=protected-access
# --> 537   fn = pywrap_tf_session.TF_GraphToFunction_wrapper(
#     538       c_graph,
#     539       compat.as_str(name),
#     540       False,
#     541       [o._c_op for o in operations],  # pylint: disable=protected-access
#     542       [t._as_tf_output() for t in graph.inputs],  # pylint: disable=protected-access
#     543       [t._as_tf_output() for t in graph.outputs],  # pylint: disable=protected-access
#     544       output_names,
#     545       [o._c_op for o in graph.control_outputs],  # pylint: disable=protected-access
#     546       [],  # control_output_names
#     547       None,
#     548       compat.as_str(""),
#     549   )
#     551 attrs = attributes_lib.parse_func_attrs(attrs or {})
#     552 for attr_name, attr_value in attrs.items():
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(16, 12))

plt.plot(values[0])
plt.plot(values[1])
plt.plot(values[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 plt.figure(figsize=(16, 12))
# ----> 3 plt.plot(values[0])
#       4 plt.plot(values[1])
#       5 plt.plot(values[2])
#
# NameError: name 'values' is not defined

# %%
# Hay que intentar estabilizar la red

X_pru = np.random.randn(49)
generadas = generador.predict(X_pru)
for i in range(49):
  plt.subplot(7,7,i+1)
  plt.axis('off')
  plt.imshow(generadas[i], cmap="binary")
plt.show()
# Out:
# 2/2 [==============================] - 0s 407us/step

# %%
gan.save("gan.keras")
