# %%
import random

import matplotlib.pyplot as plt
import numpy as np

import tensorflow
import keras
from tensorflow.keras.layers import Dense, Conv2DTranspose, LeakyReLU, Reshape, BatchNormalization, Activation, Conv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dropout, MaxPool2D
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.datasets import  fashion_mnist

# %% [markdown]
# # Cargar MNist

# %% [markdown]
# Nos quedamos solo las camisetas que son donde es 0

# %%
def cargar_imagenes():
    (Xtrain, Ytrain), (_, _) = fashion_mnist.load_data()

    # Nos quedamos con las camiseta
    indice = np.where(Ytrain == 0)
    indice = indice[0]
    Xtrain = Xtrain[indice, :,:]
    # Normalizamos los datos
    X = Xtrain.astype('float32') / 255.0
    return X

dataset = cargar_imagenes()

for i in range(49):
  plt.subplot(7, 7, 1 + i)
  plt.axis('off')
  plt.imshow(dataset[i], cmap="binary")

dataset.shape
# Out:
# (6000, 28, 28)

# %% [markdown]
# # Creación del discriminador

# %%
discriminador = Sequential()

# Padding same permite que si es multiplo de 3 no se pierdan valores
discriminador.add(Conv2D(8,kernel_size=3,padding="same",
                         input_shape=(dataset.shape[1],dataset.shape[2],1),activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Conv2D(32,kernel_size=3,padding="same",activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Conv2D(64,kernel_size=3,padding="same",activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Flatten())

discriminador.add(Dense(32,activation="relu"))


discriminador.add(Dense(1,activation="sigmoid"))

discriminador.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 8)         80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        2336
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                18464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 39,409
# Trainable params: 39,409
# Non-trainable params: 0
# _________________________________________________________________
# 2024-04-30 15:06:19.531603: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Tiene que haber poco LR para poder entrenar los modelos con calma
discriminador.compile(loss="binary_crossentropy", optimizer = Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
discriminador.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 8)         80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 8)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        2336
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                18464
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 39,409
# Trainable params: 39,409
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Creación del generador

# %%
generador = Sequential()

# Vamos en incremento para intentar simular el Flatten del modelo Discriminador
generador.add(Dense(32,input_shape=(1,),activation="relu"))

# No tiene porqué pero va beneficiar la cantidad de neuronas = al discriminador
generador.add(Dense(576,activation="relu"))

# La capa de MaxPooling2D antes del Flatten para darle ya un Shape
generador.add(Reshape((3,3,64)))

# Lo que hace es que vaya a saltos de 2 como iba la capa de MaxPooling2D duplicando el tamaño x2
# Con Padding = "valid" tendría el mismo (None, 7, 7, 32) en la última capa que el Discriminador
# Ya que podemos gestionar el valor de diferencia con +1 o -1 de tamaño de imagen
generador.add(Conv2DTranspose(64,kernel_size=3, strides=2,padding="valid",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())


# Ahora tenemos que pasar de 7 a 14 con un 16 de Neuronas
generador.add(Conv2DTranspose(32,kernel_size=3, strides=2,padding="same",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Borra la mitad de las neuronas de vez en cuando
generador.add(Dropout(0.5))

# Ahora tenemos que pasar de 14 a 28 con 8 de Neuronas
generador.add(Conv2DTranspose(8,kernel_size=3, strides=2,padding="same",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())


# Ahora una capa con 1 y sin modificar el tamaño con strides=1 y que acabe entre 0 y 1 con sigmoid
generador.add(Conv2DTranspose(1,kernel_size=3,strides=1,padding="same",activation="sigmoid"))

generador.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 32)                64
# _________________________________________________________________
# dense_3 (Dense)              (None, 576)               19008
# _________________________________________________________________
# reshape (Reshape)            (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 7, 7, 64)          256
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 14, 14, 32)        18464
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 8)         2312
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 8)         32
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 1)         73
# =================================================================
# Total params: 77,265
# Trainable params: 77,057
# Non-trainable params: 208
# _________________________________________________________________

# %%
gan = Sequential()
gan.add(generador)
gan.add(discriminador)
gan.compile(loss="binary_crossentropy", optimizer = Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
import sys

def get_datos_true(nmuestras):
    """Devuelve imagenes verdaderas del DataSet

    Args:
        muestras (pd.DataFrame): DataFrame de Pandas

    Returns:
        List: Devuelve el X e Y del DataSet 
    """
    v = np.random.randint(0,dataset.shape[0],nmuestras)
    X = dataset[v]
    y = np.ones((nmuestras,1))
    X = X.reshape(-1, 28, 28, 1)
    return X,y

def get_datos_fake(nmuestras):
    """Genera datos falsos con el generador

    Args:
        nmuestras (int): Número de muestras

    Returns:
        List: Devuelve X e Y de un falso DataSet predicho
    """
    input = np.random.rand(nmuestras)
    X = generador.predict(input)
    y = np.zeros((nmuestras,1))
    X = X.reshape(-1, 28, 28, 1)
    return X,y

def entrenamiento(epochs=1, batch_size=128,x=sys.maxsize):
    """Entrena el modelo de Generador y Detector

    Args:
        epochs (int, optional): Nº de Epochs. Defaults to 1.
        batch_size (int, optional): Tamaño de los saltos. Defaults to 128.
    """
    max_len = dataset.shape[0]
    nbatchs = int(max_len / batch_size)
    acc_r,acc_f,acc_g=[],[],[]
    for epoch in range(epochs):
        print("Epoch : ", epoch)
        for batch in range(nbatchs):

            #region Discriminador
            acc_real = 0.0
            discriminador.trainable = True
            while acc_real < 0.1:
                X_real,y_real = get_datos_true(batch_size//2)
                # Permite entrenar a cachos el discriminador
                loss_real, acc_real = discriminador.train_on_batch(X_real,y_real)
                if epoch>x : break

            acc_fake=0.0
            while acc_fake < 0.1:
                X_fake,y_fake = get_datos_fake(batch_size//2)
                # Permite entrenar a cachos el discriminador
                loss_fake, acc_fake = discriminador.train_on_batch(X_fake,y_fake)

            discriminador.trainable = False

            #endregion

            #region Generador
            X_gan = np.random.randn(batch_size).reshape(batch_size,1)

            # Tenemos que intentar engañarlo, por lo que ponemos por la salida unos ya que significaría que son correctos
            # Hasta que el otro diga lo contrario
            y_gan = np.ones((batch_size,1))

            acc_gan,indice = 0.0,0
            while acc_gan < 0.1:
                if indice==40: break
                loss_gan, acc_gan = gan.train_on_batch(X_gan,y_gan)
                indice+=1
                if epoch>x : break
            #endregion

            print(f"Epoch: {epoch} - Batch: {batch}")
            print(f"loss_real: {loss_real} - loss_fake: {loss_fake} - loss_gan: {loss_gan}")
            print(f"acc_real: {acc_real} - acc_fake: {acc_fake} - acc_gan: {acc_gan}")
            acc_r.append(acc_real)
            acc_f.append(acc_fake)
            acc_g.append(acc_gan)
    return acc_r,acc_f,acc_g

# %%
values=entrenamiento(epochs=30,batch_size=64)
# Out:
# Epoch :  0
# 2024-04-30 15:06:19.830164: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-04-30 15:06:19.831510: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3792610000 Hz
# Epoch: 0 - Batch: 0
# loss_real: 0.6753460764884949 - loss_fake: 0.6916387677192688 - loss_gan: 0.6894357800483704
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 0.703125
# Epoch: 0 - Batch: 1
# loss_real: 0.673629879951477 - loss_fake: 0.6907211542129517 - loss_gan: 0.6869416832923889
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 0.921875
# Epoch: 0 - Batch: 2
# loss_real: 0.6708213090896606 - loss_fake: 0.6907851099967957 - loss_gan: 0.6812090873718262
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 0.984375
# Epoch: 0 - Batch: 3
# loss_real: 0.663504958152771 - loss_fake: 0.6914932727813721 - loss_gan: 0.6747215986251831
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 4
# loss_real: 0.6534271240234375 - loss_fake: 0.693001925945282 - loss_gan: 0.6677260398864746
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 5
# loss_real: 0.6451828479766846 - loss_fake: 0.6925212144851685 - loss_gan: 0.6600608825683594
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 6
# loss_real: 0.6365201473236084 - loss_fake: 0.6924960017204285 - loss_gan: 0.6565808057785034
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 7
# loss_real: 0.6286658048629761 - loss_fake: 0.6926020383834839 - loss_gan: 0.6482944488525391
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 8
# loss_real: 0.6286646127700806 - loss_fake: 0.6928995847702026 - loss_gan: 0.6425975561141968
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 9
# loss_real: 0.6164406538009644 - loss_fake: 0.6922609806060791 - loss_gan: 0.6375882625579834
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 10
# loss_real: 0.6087340712547302 - loss_fake: 0.6923084855079651 - loss_gan: 0.6275572180747986
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 11
# loss_real: 0.6026108264923096 - loss_fake: 0.6925289630889893 - loss_gan: 0.6223187446594238
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 12
# loss_real: 0.6004694700241089 - loss_fake: 0.6928926706314087 - loss_gan: 0.6166024804115295
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 13
# loss_real: 0.5872197151184082 - loss_fake: 0.6931576728820801 - loss_gan: 0.6043068170547485
# acc_real: 1.0 - acc_fake: 0.34375 - acc_gan: 1.0
# Epoch: 0 - Batch: 14
# loss_real: 0.5775051116943359 - loss_fake: 0.6920863389968872 - loss_gan: 0.597874641418457
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 15
# loss_real: 0.5723041296005249 - loss_fake: 0.6918011903762817 - loss_gan: 0.5875754952430725
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 16
# loss_real: 0.5606200098991394 - loss_fake: 0.6921216249465942 - loss_gan: 0.5798124074935913
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 17
# loss_real: 0.5531301498413086 - loss_fake: 0.6924208402633667 - loss_gan: 0.5780173540115356
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 18
# loss_real: 0.5488162040710449 - loss_fake: 0.6923578977584839 - loss_gan: 0.5671579241752625
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 19
# loss_real: 0.5353015661239624 - loss_fake: 0.6924360990524292 - loss_gan: 0.5517003536224365
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 20
# loss_real: 0.5203276872634888 - loss_fake: 0.6926847696304321 - loss_gan: 0.5393335223197937
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 21
# loss_real: 0.5149158239364624 - loss_fake: 0.6926312446594238 - loss_gan: 0.5192150473594666
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 22
# loss_real: 0.5192380547523499 - loss_fake: 0.6922383308410645 - loss_gan: 0.5127282738685608
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 23
# loss_real: 0.5000172257423401 - loss_fake: 0.6915392875671387 - loss_gan: 0.49302929639816284
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 24
# loss_real: 0.4928293824195862 - loss_fake: 0.6909860968589783 - loss_gan: 0.4757460057735443
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 25
# loss_real: 0.4776538610458374 - loss_fake: 0.6930638551712036 - loss_gan: 0.47093600034713745
# acc_real: 1.0 - acc_fake: 0.6875 - acc_gan: 1.0
# Epoch: 0 - Batch: 26
# loss_real: 0.47532790899276733 - loss_fake: 0.6908048391342163 - loss_gan: 0.454692542552948
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 27
# loss_real: 0.4724733531475067 - loss_fake: 0.6922361254692078 - loss_gan: 0.4347842335700989
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 28
# loss_real: 0.4370514154434204 - loss_fake: 0.6922364234924316 - loss_gan: 0.41784924268722534
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 29
# loss_real: 0.4187975525856018 - loss_fake: 0.6915135383605957 - loss_gan: 0.4002511501312256
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 30
# loss_real: 0.42521587014198303 - loss_fake: 0.6900454759597778 - loss_gan: 0.389104425907135
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 31
# loss_real: 0.39638447761535645 - loss_fake: 0.6920861601829529 - loss_gan: 0.3562089800834656
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 32
# loss_real: 0.39806288480758667 - loss_fake: 0.6919160485267639 - loss_gan: 0.3340293765068054
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 33
# loss_real: 0.3930756449699402 - loss_fake: 0.6904580593109131 - loss_gan: 0.30654019117355347
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 34
# loss_real: 0.3653978705406189 - loss_fake: 0.6922116875648499 - loss_gan: 0.2840798497200012
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 35
# loss_real: 0.3538578748703003 - loss_fake: 0.6914526224136353 - loss_gan: 0.2675696611404419
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 36
# loss_real: 0.3422102928161621 - loss_fake: 0.6893266439437866 - loss_gan: 0.2405044436454773
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 37
# loss_real: 0.3334800601005554 - loss_fake: 0.6908538341522217 - loss_gan: 0.223209947347641
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 38
# loss_real: 0.31443890929222107 - loss_fake: 0.6893645524978638 - loss_gan: 0.19866621494293213
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 39
# loss_real: 0.29510343074798584 - loss_fake: 0.6907594203948975 - loss_gan: 0.17682784795761108
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 40
# loss_real: 0.27786093950271606 - loss_fake: 0.6933730244636536 - loss_gan: 0.1610967516899109
# acc_real: 1.0 - acc_fake: 0.21875 - acc_gan: 1.0
# Epoch: 0 - Batch: 41
# loss_real: 0.26061826944351196 - loss_fake: 0.6915490031242371 - loss_gan: 0.14544612169265747
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 42
# loss_real: 0.2590084969997406 - loss_fake: 0.6921541690826416 - loss_gan: 0.12994210422039032
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 43
# loss_real: 0.25052207708358765 - loss_fake: 0.6890405416488647 - loss_gan: 0.11109699308872223
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 44
# loss_real: 0.23369050025939941 - loss_fake: 0.6886687278747559 - loss_gan: 0.09915650635957718
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 45
# loss_real: 0.23206958174705505 - loss_fake: 0.6889854669570923 - loss_gan: 0.08686571568250656
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 46
# loss_real: 0.22262954711914062 - loss_fake: 0.6896292567253113 - loss_gan: 0.07132335007190704
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 47
# loss_real: 0.1862073838710785 - loss_fake: 0.6902047395706177 - loss_gan: 0.0664541944861412
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 48
# loss_real: 0.19982439279556274 - loss_fake: 0.6903712153434753 - loss_gan: 0.05823284760117531
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 49
# loss_real: 0.17365483939647675 - loss_fake: 0.6899162530899048 - loss_gan: 0.046900078654289246
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 50
# loss_real: 0.16308660805225372 - loss_fake: 0.6888100504875183 - loss_gan: 0.03894088789820671
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 51
# loss_real: 0.16100430488586426 - loss_fake: 0.6875303983688354 - loss_gan: 0.038932304829359055
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 52
# loss_real: 0.14124777913093567 - loss_fake: 0.6850659847259521 - loss_gan: 0.028102915734052658
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 53
# loss_real: 0.14601090550422668 - loss_fake: 0.6820929050445557 - loss_gan: 0.025017596781253815
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 54
# loss_real: 0.14992249011993408 - loss_fake: 0.6788175106048584 - loss_gan: 0.021206483244895935
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 55
# loss_real: 0.1459016501903534 - loss_fake: 0.675960123538971 - loss_gan: 0.019691184163093567
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 56
# loss_real: 0.12405239045619965 - loss_fake: 0.6736253499984741 - loss_gan: 0.016353588551282883
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 57
# loss_real: 0.12051167339086533 - loss_fake: 0.6707320213317871 - loss_gan: 0.012258713133633137
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 58
# loss_real: 0.11933481693267822 - loss_fake: 0.6674997210502625 - loss_gan: 0.011733734980225563
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 59
# loss_real: 0.1127891093492508 - loss_fake: 0.6629600524902344 - loss_gan: 0.011959313414990902
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 60
# loss_real: 0.10902988910675049 - loss_fake: 0.6591193675994873 - loss_gan: 0.01006731390953064
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 61
# loss_real: 0.1052398830652237 - loss_fake: 0.6551409959793091 - loss_gan: 0.007069255691021681
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 62
# loss_real: 0.09700556099414825 - loss_fake: 0.6514583826065063 - loss_gan: 0.0060396622866392136
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 63
# loss_real: 0.093325175344944 - loss_fake: 0.6470111012458801 - loss_gan: 0.005283551290631294
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 64
# loss_real: 0.08616696298122406 - loss_fake: 0.6427765488624573 - loss_gan: 0.004527609795331955
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 65
# loss_real: 0.08145163953304291 - loss_fake: 0.6376423835754395 - loss_gan: 0.004367871209979057
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 66
# loss_real: 0.07492458820343018 - loss_fake: 0.6326281428337097 - loss_gan: 0.003811537753790617
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 67
# loss_real: 0.07607364654541016 - loss_fake: 0.6273058652877808 - loss_gan: 0.0033287445548921824
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 68
# loss_real: 0.07956692576408386 - loss_fake: 0.6222387552261353 - loss_gan: 0.0029784543439745903
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 69
# loss_real: 0.07818666100502014 - loss_fake: 0.6170673966407776 - loss_gan: 0.002747391117736697
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 70
# loss_real: 0.05676550790667534 - loss_fake: 0.6123623847961426 - loss_gan: 0.0022238411474972963
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 71
# loss_real: 0.059625446796417236 - loss_fake: 0.6077207326889038 - loss_gan: 0.001969489734619856
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 72
# loss_real: 0.06303438544273376 - loss_fake: 0.6026340126991272 - loss_gan: 0.00210033031180501
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 73
# loss_real: 0.05954748019576073 - loss_fake: 0.5975538492202759 - loss_gan: 0.0013543730601668358
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 74
# loss_real: 0.04552657529711723 - loss_fake: 0.5927380323410034 - loss_gan: 0.0012660747161135077
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 75
# loss_real: 0.04511523246765137 - loss_fake: 0.5883835554122925 - loss_gan: 0.001587296836078167
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 76
# loss_real: 0.059167295694351196 - loss_fake: 0.5844986438751221 - loss_gan: 0.0010296525433659554
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 77
# loss_real: 0.0501309372484684 - loss_fake: 0.5804585218429565 - loss_gan: 0.0010311828227713704
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 78
# loss_real: 0.04942428693175316 - loss_fake: 0.5759238004684448 - loss_gan: 0.0008464426500722766
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 79
# loss_real: 0.05957651883363724 - loss_fake: 0.5713667869567871 - loss_gan: 0.000697346986271441
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 80
# loss_real: 0.050401072949171066 - loss_fake: 0.5660886168479919 - loss_gan: 0.0006674129981547594
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 81
# loss_real: 0.05073879659175873 - loss_fake: 0.5612596273422241 - loss_gan: 0.0007198637467809021
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 82
# loss_real: 0.04764503240585327 - loss_fake: 0.5565977096557617 - loss_gan: 0.0005210653762333095
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 83
# loss_real: 0.03809330612421036 - loss_fake: 0.552008330821991 - loss_gan: 0.000593501899857074
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 84
# loss_real: 0.0398072674870491 - loss_fake: 0.5472434163093567 - loss_gan: 0.00044418073957785964
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 85
# loss_real: 0.04356131702661514 - loss_fake: 0.5425641536712646 - loss_gan: 0.00041749633965082467
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 86
# loss_real: 0.038980334997177124 - loss_fake: 0.5380105972290039 - loss_gan: 0.00040670824819244444
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 87
# loss_real: 0.044307976961135864 - loss_fake: 0.5329818725585938 - loss_gan: 0.0003365085576660931
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 88
# loss_real: 0.04624427855014801 - loss_fake: 0.5274858474731445 - loss_gan: 0.0002628995571285486
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 89
# loss_real: 0.03978358954191208 - loss_fake: 0.5229393243789673 - loss_gan: 0.00029147783061489463
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 90
# loss_real: 0.035222798585891724 - loss_fake: 0.5185360908508301 - loss_gan: 0.00021337741054594517
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 91
# loss_real: 0.029434388503432274 - loss_fake: 0.5138182640075684 - loss_gan: 0.00020175239478703588
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 0 - Batch: 92
# loss_real: 0.03318900242447853 - loss_fake: 0.5093425512313843 - loss_gan: 0.00017017379286698997
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  1
# Epoch: 1 - Batch: 0
# loss_real: 0.04068353772163391 - loss_fake: 0.5053105354309082 - loss_gan: 0.0001561729732202366
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 1
# loss_real: 0.03416772931814194 - loss_fake: 0.5000863671302795 - loss_gan: 0.00019585105474106967
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 2
# loss_real: 0.03386319428682327 - loss_fake: 0.49491119384765625 - loss_gan: 0.00016510389104951173
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 3
# loss_real: 0.03451482951641083 - loss_fake: 0.49022629857063293 - loss_gan: 0.0001321985910180956
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 4
# loss_real: 0.026015326380729675 - loss_fake: 0.4851365089416504 - loss_gan: 0.0001181962143164128
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 5
# loss_real: 0.031083671376109123 - loss_fake: 0.4796293079853058 - loss_gan: 9.752892219694331e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 6
# loss_real: 0.023580919951200485 - loss_fake: 0.4745165705680847 - loss_gan: 9.660574869485572e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 7
# loss_real: 0.026417862623929977 - loss_fake: 0.46923667192459106 - loss_gan: 8.993560913950205e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 8
# loss_real: 0.031159114092588425 - loss_fake: 0.4636937975883484 - loss_gan: 0.00010529997234698385
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 9
# loss_real: 0.026409097015857697 - loss_fake: 0.45833683013916016 - loss_gan: 7.556141645181924e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 10
# loss_real: 0.02789122611284256 - loss_fake: 0.452682763338089 - loss_gan: 6.736311479471624e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 11
# loss_real: 0.025271106511354446 - loss_fake: 0.44726046919822693 - loss_gan: 6.216893962118775e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 12
# loss_real: 0.02136867865920067 - loss_fake: 0.4410027861595154 - loss_gan: 6.150965054985136e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 13
# loss_real: 0.03093637153506279 - loss_fake: 0.4348773956298828 - loss_gan: 6.87792562530376e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 14
# loss_real: 0.019636601209640503 - loss_fake: 0.4289587140083313 - loss_gan: 5.92851938563399e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 15
# loss_real: 0.04100225865840912 - loss_fake: 0.42311620712280273 - loss_gan: 5.205653724260628e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 16
# loss_real: 0.021223949268460274 - loss_fake: 0.41753989458084106 - loss_gan: 4.373806223156862e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 17
# loss_real: 0.0216271560639143 - loss_fake: 0.41084420680999756 - loss_gan: 4.075482502230443e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 18
# loss_real: 0.028158137574791908 - loss_fake: 0.4042562246322632 - loss_gan: 3.7068853998789564e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 19
# loss_real: 0.021658821031451225 - loss_fake: 0.3980972170829773 - loss_gan: 2.7251278879703023e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 20
# loss_real: 0.021739892661571503 - loss_fake: 0.3916960656642914 - loss_gan: 3.870188083965331e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 21
# loss_real: 0.027462828904390335 - loss_fake: 0.3849208354949951 - loss_gan: 2.69767660938669e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 22
# loss_real: 0.02496732771396637 - loss_fake: 0.378158837556839 - loss_gan: 3.349514736328274e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 23
# loss_real: 0.024938661605119705 - loss_fake: 0.3718189001083374 - loss_gan: 2.422255238343496e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 24
# loss_real: 0.023485001176595688 - loss_fake: 0.3668956756591797 - loss_gan: 2.4697559638298117e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 25
# loss_real: 0.022272098809480667 - loss_fake: 0.3585273027420044 - loss_gan: 2.677939301065635e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 26
# loss_real: 0.02513376995921135 - loss_fake: 0.35190683603286743 - loss_gan: 2.5823203031904995e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 27
# loss_real: 0.032336052507162094 - loss_fake: 0.3452308475971222 - loss_gan: 2.4407734599662945e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 28
# loss_real: 0.019607841968536377 - loss_fake: 0.3387504518032074 - loss_gan: 1.970252014871221e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 29
# loss_real: 0.02040207013487816 - loss_fake: 0.3316620886325836 - loss_gan: 1.7232770915143192e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 30
# loss_real: 0.02548076957464218 - loss_fake: 0.32512056827545166 - loss_gan: 2.6522300686337985e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 31
# loss_real: 0.020645998418331146 - loss_fake: 0.3182998299598694 - loss_gan: 1.60632607730804e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 32
# loss_real: 0.018309811130166054 - loss_fake: 0.3121544420719147 - loss_gan: 1.8936872947961092e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 33
# loss_real: 0.029059387743473053 - loss_fake: 0.3045583963394165 - loss_gan: 2.0135517843300477e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 34
# loss_real: 0.012672627344727516 - loss_fake: 0.29781925678253174 - loss_gan: 1.8594644643599167e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 35
# loss_real: 0.02031632326543331 - loss_fake: 0.29028257727622986 - loss_gan: 1.4835568435955793e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 36
# loss_real: 0.016338787972927094 - loss_fake: 0.2832786440849304 - loss_gan: 1.1721613191184588e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 37
# loss_real: 0.020650723949074745 - loss_fake: 0.27673694491386414 - loss_gan: 1.0650730473571457e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 38
# loss_real: 0.028083503246307373 - loss_fake: 0.2700793147087097 - loss_gan: 8.220073141274042e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 39
# loss_real: 0.029213804751634598 - loss_fake: 0.26363062858581543 - loss_gan: 9.181017048831563e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 40
# loss_real: 0.018095986917614937 - loss_fake: 0.2576022744178772 - loss_gan: 8.312957106682006e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 41
# loss_real: 0.020522769540548325 - loss_fake: 0.2504424452781677 - loss_gan: 6.683886567770969e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 42
# loss_real: 0.01796586439013481 - loss_fake: 0.24372762441635132 - loss_gan: 6.918977760506095e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 43
# loss_real: 0.013834824785590172 - loss_fake: 0.23707328736782074 - loss_gan: 1.1859226106025744e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 44
# loss_real: 0.020012373104691505 - loss_fake: 0.23075087368488312 - loss_gan: 9.030274668475613e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 45
# loss_real: 0.015293700620532036 - loss_fake: 0.22441186010837555 - loss_gan: 7.334057954722084e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 46
# loss_real: 0.01517343521118164 - loss_fake: 0.2183743715286255 - loss_gan: 7.700149581069127e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 47
# loss_real: 0.019707750529050827 - loss_fake: 0.21229347586631775 - loss_gan: 5.038028575654607e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 48
# loss_real: 0.01482040248811245 - loss_fake: 0.20808222889900208 - loss_gan: 7.258577625179896e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 49
# loss_real: 0.022832922637462616 - loss_fake: 0.20053911209106445 - loss_gan: 6.0694692365359515e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 50
# loss_real: 0.017584044486284256 - loss_fake: 0.19476060569286346 - loss_gan: 5.660376700689085e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 51
# loss_real: 0.012392965145409107 - loss_fake: 0.18884344398975372 - loss_gan: 7.593851023557363e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 52
# loss_real: 0.018644170835614204 - loss_fake: 0.18332095444202423 - loss_gan: 6.9762654675287195e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 53
# loss_real: 0.032383617013692856 - loss_fake: 0.17816594243049622 - loss_gan: 6.444442078645807e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 54
# loss_real: 0.027271904051303864 - loss_fake: 0.1752270609140396 - loss_gan: 2.603125267341966e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 55
# loss_real: 0.02021804451942444 - loss_fake: 0.16948634386062622 - loss_gan: 3.159667812724365e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 56
# loss_real: 0.017964374274015427 - loss_fake: 0.16395869851112366 - loss_gan: 5.112043709232239e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 57
# loss_real: 0.01565280184149742 - loss_fake: 0.15937639772891998 - loss_gan: 3.2239001939160516e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 58
# loss_real: 0.01758885569870472 - loss_fake: 0.154117614030838 - loss_gan: 3.002851826749975e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 59
# loss_real: 0.02429649978876114 - loss_fake: 0.1496405303478241 - loss_gan: 1.9879787487298017e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 60
# loss_real: 0.018978944048285484 - loss_fake: 0.14592799544334412 - loss_gan: 1.8306707261217525e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 61
# loss_real: 0.022075660526752472 - loss_fake: 0.1425684690475464 - loss_gan: 1.670698566158535e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 62
# loss_real: 0.014335821382701397 - loss_fake: 0.13941483199596405 - loss_gan: 2.423481873847777e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 63
# loss_real: 0.02439340204000473 - loss_fake: 0.1350795030593872 - loss_gan: 1.942022208822891e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 64
# loss_real: 0.04201802611351013 - loss_fake: 0.1309058964252472 - loss_gan: 1.8178434402216226e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 65
# loss_real: 0.014272864907979965 - loss_fake: 0.12797324359416962 - loss_gan: 1.5490394389416906e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 66
# loss_real: 0.019444232806563377 - loss_fake: 0.12504059076309204 - loss_gan: 1.7400914202880813e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 67
# loss_real: 0.03334415704011917 - loss_fake: 0.12222781777381897 - loss_gan: 1.623651769477874e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 68
# loss_real: 0.018854759633541107 - loss_fake: 0.11887985467910767 - loss_gan: 1.3906419553677551e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 69
# loss_real: 0.012112262658774853 - loss_fake: 0.11539032310247421 - loss_gan: 1.1062379599025007e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 70
# loss_real: 0.025559112429618835 - loss_fake: 0.11271107196807861 - loss_gan: 8.011217005332583e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 71
# loss_real: 0.012955762445926666 - loss_fake: 0.1096055656671524 - loss_gan: 1.2140025091866846e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 72
# loss_real: 0.012111028656363487 - loss_fake: 0.1063278391957283 - loss_gan: 7.394141903205309e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 73
# loss_real: 0.01252309326082468 - loss_fake: 0.10407461225986481 - loss_gan: 8.788158538663993e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 74
# loss_real: 0.02323388122022152 - loss_fake: 0.10127484798431396 - loss_gan: 1.7696827399049653e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 75
# loss_real: 0.02000751718878746 - loss_fake: 0.09919458627700806 - loss_gan: 7.523147473875724e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 76
# loss_real: 0.017728257924318314 - loss_fake: 0.09731557220220566 - loss_gan: 6.893370709804003e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 77
# loss_real: 0.011446302756667137 - loss_fake: 0.0940888524055481 - loss_gan: 7.18385365416907e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 78
# loss_real: 0.012537323869764805 - loss_fake: 0.09297319501638412 - loss_gan: 4.339461270319589e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 79
# loss_real: 0.017727935686707497 - loss_fake: 0.08932673931121826 - loss_gan: 2.8978820409975015e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 80
# loss_real: 0.021744560450315475 - loss_fake: 0.08672219514846802 - loss_gan: 2.1653538340160594e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 81
# loss_real: 0.008393319323658943 - loss_fake: 0.08472585678100586 - loss_gan: 3.488331401513278e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 82
# loss_real: 0.012265647761523724 - loss_fake: 0.08269074559211731 - loss_gan: 3.140564501791232e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 83
# loss_real: 0.005461577326059341 - loss_fake: 0.08076493442058563 - loss_gan: 3.0957963303990255e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 84
# loss_real: 0.007396687287837267 - loss_fake: 0.0779968798160553 - loss_gan: 1.3227013084815553e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 85
# loss_real: 0.011365750804543495 - loss_fake: 0.07622947543859482 - loss_gan: 2.6467841962585226e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 86
# loss_real: 0.06513211131095886 - loss_fake: 0.07431194186210632 - loss_gan: 1.4709686979585967e-07
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 87
# loss_real: 0.006883575581014156 - loss_fake: 0.07340751588344574 - loss_gan: 1.846017880779982e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 88
# loss_real: 0.011402454227209091 - loss_fake: 0.07295282185077667 - loss_gan: 2.5944137860278715e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 89
# loss_real: 0.018718065693974495 - loss_fake: 0.07069925963878632 - loss_gan: 2.37533512859045e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 90
# loss_real: 0.007135522086173296 - loss_fake: 0.06831441819667816 - loss_gan: 1.983082142942294e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 91
# loss_real: 0.017538605257868767 - loss_fake: 0.06721445918083191 - loss_gan: 1.1681059675083816e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 1 - Batch: 92
# loss_real: 0.016524968668818474 - loss_fake: 0.06534947454929352 - loss_gan: 1.0169641484480962e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  2
# Epoch: 2 - Batch: 0
# loss_real: 0.013723833486437798 - loss_fake: 0.06389199197292328 - loss_gan: 2.301898121004342e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 1
# loss_real: 0.02003677375614643 - loss_fake: 0.06283177435398102 - loss_gan: 1.7128499507634842e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 2
# loss_real: 0.01729264110326767 - loss_fake: 0.061742618680000305 - loss_gan: 6.898885374084784e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 3
# loss_real: 0.0052121649496257305 - loss_fake: 0.06105555593967438 - loss_gan: 1.3324373071554874e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 4
# loss_real: 0.02114110440015793 - loss_fake: 0.0606280192732811 - loss_gan: 7.358316622685379e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 5
# loss_real: 0.005488811060786247 - loss_fake: 0.05924910679459572 - loss_gan: 5.8739143327102283e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 6
# loss_real: 0.004240754991769791 - loss_fake: 0.057190462946891785 - loss_gan: 4.713682244528172e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 7
# loss_real: 0.0200494471937418 - loss_fake: 0.0553404837846756 - loss_gan: 9.409825452166842e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 8
# loss_real: 0.013777724467217922 - loss_fake: 0.05479343980550766 - loss_gan: 4.4373393848218257e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 9
# loss_real: 0.031473226845264435 - loss_fake: 0.053395070135593414 - loss_gan: 4.3038973274178716e-08
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 10
# loss_real: 0.014753134921193123 - loss_fake: 0.05496760830283165 - loss_gan: 9.319002458596515e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 11
# loss_real: 0.007768010720610619 - loss_fake: 0.05390764772891998 - loss_gan: 6.237445404622122e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 12
# loss_real: 0.010964020155370235 - loss_fake: 0.05231446772813797 - loss_gan: 2.8658918793667e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 13
# loss_real: 0.0063071539625525475 - loss_fake: 0.050469595938920975 - loss_gan: 1.809960537002553e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 14
# loss_real: 0.005788916721940041 - loss_fake: 0.049190767109394073 - loss_gan: 2.586335767773562e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 15
# loss_real: 0.010130127891898155 - loss_fake: 0.047866340726614 - loss_gan: 4.1084081914277704e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 16
# loss_real: 0.013175786472856998 - loss_fake: 0.04716617986559868 - loss_gan: 5.030691596630277e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 17
# loss_real: 0.00927819311618805 - loss_fake: 0.045786693692207336 - loss_gan: 2.3979364272008752e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 18
# loss_real: 0.004855487961322069 - loss_fake: 0.044879548251628876 - loss_gan: 1.7846286226586017e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 19
# loss_real: 0.016870735213160515 - loss_fake: 0.04452162981033325 - loss_gan: 1.5951513887557667e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 20
# loss_real: 0.003278604708611965 - loss_fake: 0.04382968321442604 - loss_gan: 2.045586100507535e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 21
# loss_real: 0.003087265882641077 - loss_fake: 0.04334835708141327 - loss_gan: 2.3977641205874534e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 22
# loss_real: 0.012307806871831417 - loss_fake: 0.04334304481744766 - loss_gan: 1.1938483091000762e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 23
# loss_real: 0.022469306364655495 - loss_fake: 0.042238324880599976 - loss_gan: 1.1548405787209504e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 24
# loss_real: 0.03131001070141792 - loss_fake: 0.04269019514322281 - loss_gan: 1.4945968018764688e-08
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 25
# loss_real: 0.0020520880352705717 - loss_fake: 0.04219013452529907 - loss_gan: 1.321586928781926e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 26
# loss_real: 0.028210129588842392 - loss_fake: 0.04084112122654915 - loss_gan: 7.115172451221952e-09
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 27
# loss_real: 0.013384921476244926 - loss_fake: 0.041212297976017 - loss_gan: 1.4984873786261232e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 28
# loss_real: 0.01780468411743641 - loss_fake: 0.03919665887951851 - loss_gan: 1.0045664744495753e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 29
# loss_real: 0.003725061658769846 - loss_fake: 0.03973741829395294 - loss_gan: 7.091338183329299e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 30
# loss_real: 0.008161685429513454 - loss_fake: 0.03860567510128021 - loss_gan: 6.778084316039212e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 31
# loss_real: 0.008100483566522598 - loss_fake: 0.03801647573709488 - loss_gan: 5.296557858969209e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 32
# loss_real: 0.003375911619514227 - loss_fake: 0.03729712963104248 - loss_gan: 7.51419282352117e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 33
# loss_real: 0.009444817900657654 - loss_fake: 0.03593769669532776 - loss_gan: 5.174346284775311e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 34
# loss_real: 0.0032392716966569424 - loss_fake: 0.03574593737721443 - loss_gan: 1.1434005742216868e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 35
# loss_real: 0.07086304575204849 - loss_fake: 0.035225994884967804 - loss_gan: 1.3920265828915035e-08
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 36
# loss_real: 0.00967875961214304 - loss_fake: 0.035444632172584534 - loss_gan: 3.4868794518416735e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 37
# loss_real: 0.012451838701963425 - loss_fake: 0.03533191978931427 - loss_gan: 3.2020934792598155e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 38
# loss_real: 0.01062319241464138 - loss_fake: 0.03759495168924332 - loss_gan: 1.0623593116321217e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 39
# loss_real: 0.005705945659428835 - loss_fake: 0.03640836477279663 - loss_gan: 4.7537982439394e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 40
# loss_real: 0.002268366049975157 - loss_fake: 0.035068683326244354 - loss_gan: 1.245380132353091e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 41
# loss_real: 0.0020202803425490856 - loss_fake: 0.03369634598493576 - loss_gan: 2.891854311570796e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 42
# loss_real: 0.004008566960692406 - loss_fake: 0.03234665468335152 - loss_gan: 3.5400620213010825e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 43
# loss_real: 0.003392273560166359 - loss_fake: 0.03133769705891609 - loss_gan: 4.386854435267651e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 44
# loss_real: 0.004565270617604256 - loss_fake: 0.030439026653766632 - loss_gan: 8.365562464973664e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 45
# loss_real: 0.010829807259142399 - loss_fake: 0.029685519635677338 - loss_gan: 5.4473363597651314e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 46
# loss_real: 0.011164129711687565 - loss_fake: 0.029151134192943573 - loss_gan: 2.0426393909644958e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 47
# loss_real: 0.007798966020345688 - loss_fake: 0.028839292004704475 - loss_gan: 1.7332876245390594e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 48
# loss_real: 0.005115156061947346 - loss_fake: 0.02885095402598381 - loss_gan: 8.69281924220644e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 49
# loss_real: 0.002142029581591487 - loss_fake: 0.02837851271033287 - loss_gan: 4.548552645644577e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 50
# loss_real: 0.03266832232475281 - loss_fake: 0.028138816356658936 - loss_gan: 1.5767966932145328e-09
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 51
# loss_real: 0.006335209123790264 - loss_fake: 0.029812712222337723 - loss_gan: 2.898785655958136e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 52
# loss_real: 0.006372449919581413 - loss_fake: 0.030844464898109436 - loss_gan: 1.6620651521748186e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 53
# loss_real: 0.008540361188352108 - loss_fake: 0.02952856570482254 - loss_gan: 2.8610864788447543e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 54
# loss_real: 0.02077183872461319 - loss_fake: 0.029352707788348198 - loss_gan: 9.763461150669173e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 55
# loss_real: 0.016520598903298378 - loss_fake: 0.02970714680850506 - loss_gan: 1.2398277959846382e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 56
# loss_real: 0.0007968922145664692 - loss_fake: 0.029380634427070618 - loss_gan: 7.731860707238525e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 57
# loss_real: 0.0020004245452582836 - loss_fake: 0.027912484481930733 - loss_gan: 7.724643702466949e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 58
# loss_real: 0.0015716952038928866 - loss_fake: 0.0271073579788208 - loss_gan: 5.633569721830156e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 59
# loss_real: 0.024980520829558372 - loss_fake: 0.02653626725077629 - loss_gan: 1.2044664154942097e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 60
# loss_real: 0.00938684307038784 - loss_fake: 0.02517281100153923 - loss_gan: 8.373938764627553e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 61
# loss_real: 0.003959613852202892 - loss_fake: 0.026376444846391678 - loss_gan: 1.3690854006043196e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 62
# loss_real: 0.0041213734075427055 - loss_fake: 0.025415224954485893 - loss_gan: 6.086998682874878e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 63
# loss_real: 0.014249912463128567 - loss_fake: 0.024393348023295403 - loss_gan: 1.0513616643947898e-09
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 64
# loss_real: 0.006255550310015678 - loss_fake: 0.025759154930710793 - loss_gan: 5.613903231171946e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 65
# loss_real: 0.0010449254186823964 - loss_fake: 0.024160010740160942 - loss_gan: 2.110207841798939e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 66
# loss_real: 0.001067466102540493 - loss_fake: 0.024332724511623383 - loss_gan: 2.890174488623387e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 67
# loss_real: 0.0117102125659585 - loss_fake: 0.022645680233836174 - loss_gan: 4.696434352524648e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 68
# loss_real: 0.0711393877863884 - loss_fake: 0.02346816100180149 - loss_gan: 6.2123672872616e-10
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 69
# loss_real: 0.0822499543428421 - loss_fake: 0.02677139639854431 - loss_gan: 2.0832191527375699e-10
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 70
# loss_real: 0.0007988348370417953 - loss_fake: 0.029983367770910263 - loss_gan: 2.78869705105933e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 71
# loss_real: 0.004269515164196491 - loss_fake: 0.03120475634932518 - loss_gan: 1.0084461044002069e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 72
# loss_real: 0.0016131158918142319 - loss_fake: 0.029717912897467613 - loss_gan: 1.6635112731755441e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 73
# loss_real: 0.003995426930487156 - loss_fake: 0.02948772720992565 - loss_gan: 3.890584729382418e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 74
# loss_real: 0.0015684406971558928 - loss_fake: 0.025953199714422226 - loss_gan: 9.507199194569438e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 75
# loss_real: 0.000714553170837462 - loss_fake: 0.024933870881795883 - loss_gan: 5.465558006179094e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 76
# loss_real: 0.0017869757721200585 - loss_fake: 0.021861495450139046 - loss_gan: 2.455994019268104e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 77
# loss_real: 0.0012368345633149147 - loss_fake: 0.020853467285633087 - loss_gan: 3.174519258575259e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 78
# loss_real: 0.006046902853995562 - loss_fake: 0.020186878740787506 - loss_gan: 4.853297208562424e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 79
# loss_real: 0.08242129534482956 - loss_fake: 0.019830312579870224 - loss_gan: 1.8634763176983427e-10
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 80
# loss_real: 0.002546454779803753 - loss_fake: 0.019886653870344162 - loss_gan: 3.9778128013701064e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 81
# loss_real: 0.0016747599001973867 - loss_fake: 0.020083703100681305 - loss_gan: 5.40595013198697e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 82
# loss_real: 0.02536889724433422 - loss_fake: 0.02068345621228218 - loss_gan: 3.052304520245741e-10
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 83
# loss_real: 0.0007796987192705274 - loss_fake: 0.020450983196496964 - loss_gan: 2.0741733330886802e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 84
# loss_real: 0.037284668534994125 - loss_fake: 0.023673702031373978 - loss_gan: 7.694196668683873e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 85
# loss_real: 0.0009809487964957952 - loss_fake: 0.02622121199965477 - loss_gan: 6.851750417036229e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 86
# loss_real: 0.0005017778603360057 - loss_fake: 0.027119135484099388 - loss_gan: 7.520033207253363e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 87
# loss_real: 0.0010525246616452932 - loss_fake: 0.02464910037815571 - loss_gan: 5.182212298171507e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 88
# loss_real: 0.0017567416653037071 - loss_fake: 0.023028582334518433 - loss_gan: 1.3738878090752138e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 89
# loss_real: 0.0017872191965579987 - loss_fake: 0.022227860987186432 - loss_gan: 1.7980962552233137e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 90
# loss_real: 0.051962487399578094 - loss_fake: 0.020120974630117416 - loss_gan: 1.5487561233484826e-10
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 91
# loss_real: 0.002557324478402734 - loss_fake: 0.02081196941435337 - loss_gan: 7.369439086746254e-11
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 2 - Batch: 92
# loss_real: 0.001220066100358963 - loss_fake: 0.01953257992863655 - loss_gan: 1.4276756166164972e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  3
# Epoch: 3 - Batch: 0
# loss_real: 0.0004271498182788491 - loss_fake: 0.019300756976008415 - loss_gan: 1.558758955244599e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 1
# loss_real: 0.0060388618148863316 - loss_fake: 0.01985711045563221 - loss_gan: 2.1665211291654884e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 2
# loss_real: 0.000629704911261797 - loss_fake: 0.018489468842744827 - loss_gan: 1.245128999904921e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 3
# loss_real: 0.0032171104103326797 - loss_fake: 0.018348172307014465 - loss_gan: 1.3895673500741168e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 4
# loss_real: 0.0010047276737168431 - loss_fake: 0.017344290390610695 - loss_gan: 2.658400166666297e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 5
# loss_real: 0.0063975597731769085 - loss_fake: 0.017369210720062256 - loss_gan: 1.0214930290519675e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 6
# loss_real: 0.014648866839706898 - loss_fake: 0.01778283528983593 - loss_gan: 2.671219911931644e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 7
# loss_real: 0.000944000028539449 - loss_fake: 0.01752866618335247 - loss_gan: 1.9161412734280958e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 8
# loss_real: 0.0015110259409993887 - loss_fake: 0.017336349934339523 - loss_gan: 3.7170397315655634e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 9
# loss_real: 0.01669338345527649 - loss_fake: 0.016194332391023636 - loss_gan: 1.8305315596656158e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 10
# loss_real: 0.0027882028371095657 - loss_fake: 0.016942493617534637 - loss_gan: 2.3880963873068595e-10
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch: 3 - Batch: 11
# loss_real: 0.0036657892633229494 - loss_fake: 0.01622021198272705 - loss_gan: 6.1050742239388e-10
# ...
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 28 - Batch: 88
# loss_real: 0.2782802879810333 - loss_fake: 1.5596386194229126 - loss_gan: 0.5383996963500977
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 28 - Batch: 89
# loss_real: 0.314230740070343 - loss_fake: 1.5371780395507812 - loss_gan: 0.5363308787345886
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 28 - Batch: 90
# loss_real: 0.3280142843723297 - loss_fake: 1.5376518964767456 - loss_gan: 0.5431248545646667
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 28 - Batch: 91
# loss_real: 0.27829408645629883 - loss_fake: 1.546187162399292 - loss_gan: 0.5297362804412842
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 28 - Batch: 92
# loss_real: 0.3343021273612976 - loss_fake: 1.5721933841705322 - loss_gan: 0.5248549580574036
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch :  29
# Epoch: 29 - Batch: 0
# loss_real: 0.2965652346611023 - loss_fake: 1.5735419988632202 - loss_gan: 0.5152381658554077
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 1
# loss_real: 0.27590078115463257 - loss_fake: 1.5875954627990723 - loss_gan: 0.5078208446502686
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 2
# loss_real: 0.2826087772846222 - loss_fake: 1.603105068206787 - loss_gan: 0.5073003768920898
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 3
# loss_real: 0.2723962068557739 - loss_fake: 1.5883891582489014 - loss_gan: 0.5077928304672241
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 4
# loss_real: 0.26316896080970764 - loss_fake: 1.5901939868927002 - loss_gan: 0.5075504779815674
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 5
# loss_real: 0.23657357692718506 - loss_fake: 1.583892583847046 - loss_gan: 0.5127648115158081
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 6
# loss_real: 0.2717345356941223 - loss_fake: 1.670992374420166 - loss_gan: 0.4917113184928894
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 7
# loss_real: 0.25650209188461304 - loss_fake: 1.6488674879074097 - loss_gan: 0.5132066607475281
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 8
# loss_real: 0.23299695551395416 - loss_fake: 1.591930866241455 - loss_gan: 0.541704535484314
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 9
# loss_real: 0.2814113199710846 - loss_fake: 1.5459377765655518 - loss_gan: 0.5547816753387451
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 10
# loss_real: 0.231833815574646 - loss_fake: 1.5061492919921875 - loss_gan: 0.5992345809936523
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 11
# loss_real: 0.2943118214607239 - loss_fake: 1.4883205890655518 - loss_gan: 0.6045630574226379
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 0.96875
# Epoch: 29 - Batch: 12
# loss_real: 0.3512936532497406 - loss_fake: 1.500470519065857 - loss_gan: 0.5745500922203064
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 13
# loss_real: 0.2587142884731293 - loss_fake: 1.5058093070983887 - loss_gan: 0.5669708251953125
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 14
# loss_real: 0.2484327107667923 - loss_fake: 1.5257513523101807 - loss_gan: 0.564741849899292
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 15
# loss_real: 0.280437171459198 - loss_fake: 1.5264849662780762 - loss_gan: 0.567777693271637
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 16
# loss_real: 0.2527414560317993 - loss_fake: 1.540206789970398 - loss_gan: 0.5613437294960022
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 17
# loss_real: 0.21750804781913757 - loss_fake: 1.5560626983642578 - loss_gan: 0.5570345520973206
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 18
# loss_real: 0.2928483486175537 - loss_fake: 1.5802478790283203 - loss_gan: 0.5358868837356567
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 19
# loss_real: 0.2532948851585388 - loss_fake: 1.6052874326705933 - loss_gan: 0.5333760976791382
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 20
# loss_real: 0.2129659503698349 - loss_fake: 1.624877691268921 - loss_gan: 0.5297415256500244
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 21
# loss_real: 0.2160036712884903 - loss_fake: 1.6114153861999512 - loss_gan: 0.5230093598365784
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 22
# loss_real: 0.24681298434734344 - loss_fake: 1.6001698970794678 - loss_gan: 0.5391830205917358
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 23
# loss_real: 0.22663483023643494 - loss_fake: 1.5906130075454712 - loss_gan: 0.5343426465988159
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 24
# loss_real: 0.2557280957698822 - loss_fake: 1.5847218036651611 - loss_gan: 0.540664553642273
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 25
# loss_real: 0.26503270864486694 - loss_fake: 1.5954885482788086 - loss_gan: 0.5373446941375732
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 26
# loss_real: 0.2576451003551483 - loss_fake: 1.5937457084655762 - loss_gan: 0.5392777323722839
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 27
# loss_real: 0.3047972321510315 - loss_fake: 1.6079158782958984 - loss_gan: 0.527375340461731
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 28
# loss_real: 0.22218632698059082 - loss_fake: 1.6276158094406128 - loss_gan: 0.531679630279541
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 29
# loss_real: 0.2681124210357666 - loss_fake: 1.6255345344543457 - loss_gan: 0.5320380330085754
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 30
# loss_real: 0.2866970896720886 - loss_fake: 1.6307079792022705 - loss_gan: 0.523815393447876
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 31
# loss_real: 0.22930386662483215 - loss_fake: 1.637294888496399 - loss_gan: 0.5148025751113892
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 32
# loss_real: 0.35489076375961304 - loss_fake: 1.647691011428833 - loss_gan: 0.497727632522583
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 33
# loss_real: 0.23780104517936707 - loss_fake: 1.6568431854248047 - loss_gan: 0.5050083994865417
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 34
# loss_real: 0.22831952571868896 - loss_fake: 1.6648073196411133 - loss_gan: 0.49911773204803467
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 35
# loss_real: 0.21712541580200195 - loss_fake: 1.6256245374679565 - loss_gan: 0.5213100910186768
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 36
# loss_real: 0.2560524642467499 - loss_fake: 1.589965581893921 - loss_gan: 0.5352627635002136
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 37
# loss_real: 0.32822686433792114 - loss_fake: 1.5705809593200684 - loss_gan: 0.5361355543136597
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 38
# loss_real: 0.24712055921554565 - loss_fake: 1.564850091934204 - loss_gan: 0.5334032773971558
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 39
# loss_real: 0.24040958285331726 - loss_fake: 1.5701289176940918 - loss_gan: 0.540534496307373
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 40
# loss_real: 0.23894494771957397 - loss_fake: 1.5549848079681396 - loss_gan: 0.5395995378494263
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 41
# loss_real: 0.24153724312782288 - loss_fake: 1.5532511472702026 - loss_gan: 0.5343835949897766
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 42
# loss_real: 0.2756490707397461 - loss_fake: 1.56693434715271 - loss_gan: 0.5354869365692139
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 43
# loss_real: 0.22099065780639648 - loss_fake: 1.5562107563018799 - loss_gan: 0.5407027006149292
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 44
# loss_real: 0.24451753497123718 - loss_fake: 1.5619451999664307 - loss_gan: 0.5418579578399658
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 45
# loss_real: 0.262124240398407 - loss_fake: 1.5741956233978271 - loss_gan: 0.5283476114273071
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 46
# loss_real: 0.25570499897003174 - loss_fake: 1.602952003479004 - loss_gan: 0.5383734107017517
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 47
# loss_real: 0.2800446152687073 - loss_fake: 1.6017415523529053 - loss_gan: 0.5336673259735107
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 48
# loss_real: 0.26161298155784607 - loss_fake: 1.5998435020446777 - loss_gan: 0.5361752510070801
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 49
# loss_real: 0.26695793867111206 - loss_fake: 1.599902629852295 - loss_gan: 0.5195193290710449
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 50
# loss_real: 0.2702779769897461 - loss_fake: 1.6118721961975098 - loss_gan: 0.5126482248306274
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 51
# loss_real: 0.26306527853012085 - loss_fake: 1.6236937046051025 - loss_gan: 0.5253829956054688
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 52
# loss_real: 0.2439679503440857 - loss_fake: 1.6391140222549438 - loss_gan: 0.515028715133667
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 53
# loss_real: 0.2429082989692688 - loss_fake: 1.6208657026290894 - loss_gan: 0.5251047611236572
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 54
# loss_real: 0.3411019444465637 - loss_fake: 1.5885450839996338 - loss_gan: 0.530421257019043
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 55
# loss_real: 0.2772260308265686 - loss_fake: 1.5809763669967651 - loss_gan: 0.5279907584190369
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 56
# loss_real: 0.32114386558532715 - loss_fake: 1.5823588371276855 - loss_gan: 0.5124855637550354
# acc_real: 0.90625 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 57
# loss_real: 0.3115144371986389 - loss_fake: 1.6120412349700928 - loss_gan: 0.5269612073898315
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 58
# loss_real: 0.3019271790981293 - loss_fake: 1.6256821155548096 - loss_gan: 0.5078426003456116
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 59
# loss_real: 0.3014885485172272 - loss_fake: 1.6700694561004639 - loss_gan: 0.4934341311454773
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 60
# loss_real: 0.37574830651283264 - loss_fake: 1.695284366607666 - loss_gan: 0.476123571395874
# acc_real: 0.875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 61
# loss_real: 0.2733127176761627 - loss_fake: 1.7258546352386475 - loss_gan: 0.4772568345069885
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 62
# loss_real: 0.25117364525794983 - loss_fake: 1.7457472085952759 - loss_gan: 0.4623994827270508
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 63
# loss_real: 0.28996068239212036 - loss_fake: 1.757185697555542 - loss_gan: 0.4423644542694092
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 64
# loss_real: 0.25411027669906616 - loss_fake: 1.743654727935791 - loss_gan: 0.4660320281982422
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 65
# loss_real: 0.28636395931243896 - loss_fake: 1.7308473587036133 - loss_gan: 0.467779278755188
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 66
# loss_real: 0.27263808250427246 - loss_fake: 1.7222704887390137 - loss_gan: 0.46537742018699646
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 67
# loss_real: 0.3032638728618622 - loss_fake: 1.7279798984527588 - loss_gan: 0.465079128742218
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 68
# loss_real: 0.28858208656311035 - loss_fake: 1.7120704650878906 - loss_gan: 0.4574165940284729
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 69
# loss_real: 0.3200110197067261 - loss_fake: 1.668745756149292 - loss_gan: 0.48953521251678467
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 70
# loss_real: 0.26955413818359375 - loss_fake: 1.638425350189209 - loss_gan: 0.5046072602272034
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 71
# loss_real: 0.32596004009246826 - loss_fake: 1.620915412902832 - loss_gan: 0.4973607063293457
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 72
# loss_real: 0.3586812913417816 - loss_fake: 1.6272211074829102 - loss_gan: 0.5089165568351746
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 73
# loss_real: 0.41790714859962463 - loss_fake: 1.6482889652252197 - loss_gan: 0.4822099804878235
# acc_real: 0.875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 74
# loss_real: 0.30718252062797546 - loss_fake: 1.6884231567382812 - loss_gan: 0.45721790194511414
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 75
# loss_real: 0.3158523440361023 - loss_fake: 1.7248682975769043 - loss_gan: 0.4514448642730713
# acc_real: 0.90625 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 76
# loss_real: 0.2885354161262512 - loss_fake: 1.720605731010437 - loss_gan: 0.4466823637485504
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 77
# loss_real: 0.3861123323440552 - loss_fake: 1.7018163204193115 - loss_gan: 0.4464775323867798
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 78
# loss_real: 0.33514559268951416 - loss_fake: 1.7076473236083984 - loss_gan: 0.45120400190353394
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 79
# loss_real: 0.3799077272415161 - loss_fake: 1.721712589263916 - loss_gan: 0.4477192759513855
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 80
# loss_real: 0.3081209659576416 - loss_fake: 1.749138355255127 - loss_gan: 0.42569994926452637
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 81
# loss_real: 0.2909620404243469 - loss_fake: 1.7535226345062256 - loss_gan: 0.43469488620758057
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 82
# loss_real: 0.3364531397819519 - loss_fake: 1.7484009265899658 - loss_gan: 0.4246518015861511
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 83
# loss_real: 0.32312440872192383 - loss_fake: 1.7329976558685303 - loss_gan: 0.4511730372905731
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 84
# loss_real: 0.3210151493549347 - loss_fake: 1.7144386768341064 - loss_gan: 0.4584103226661682
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 85
# loss_real: 0.33322420716285706 - loss_fake: 1.704912543296814 - loss_gan: 0.46176648139953613
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 86
# loss_real: 0.36275625228881836 - loss_fake: 1.705052375793457 - loss_gan: 0.4619913697242737
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 87
# loss_real: 0.3365781009197235 - loss_fake: 1.6956851482391357 - loss_gan: 0.46301835775375366
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 88
# loss_real: 0.30278080701828003 - loss_fake: 1.6846325397491455 - loss_gan: 0.46292102336883545
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 89
# loss_real: 0.3852718770503998 - loss_fake: 1.6815688610076904 - loss_gan: 0.459281861782074
# acc_real: 0.90625 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 90
# loss_real: 0.31686222553253174 - loss_fake: 1.6962950229644775 - loss_gan: 0.45547375082969666
# acc_real: 1.0 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 91
# loss_real: 0.36040568351745605 - loss_fake: 1.7101541757583618 - loss_gan: 0.4579066038131714
# acc_real: 0.96875 - acc_fake: 0.0 - acc_gan: 1.0
# Epoch: 29 - Batch: 92
# loss_real: 0.3194471597671509 - loss_fake: 1.7199158668518066 - loss_gan: 0.4456520676612854
# acc_real: 0.9375 - acc_fake: 0.0 - acc_gan: 1.0

# %%
plt.figure(figsize=(16, 12))

plt.plot(values[0])
plt.plot(values[1])
plt.plot(values[2])

# %%
# Hay que intentar estabilizar la red

X_pru = np.random.randn(49)
generadas = generador.predict(X_pru)
for i in range(49):
  plt.subplot(7,7,i+1)
  plt.axis('off')
  plt.imshow(generadas[i], cmap="binary")
plt.show()

# %%
gan.save("gan.keras")
