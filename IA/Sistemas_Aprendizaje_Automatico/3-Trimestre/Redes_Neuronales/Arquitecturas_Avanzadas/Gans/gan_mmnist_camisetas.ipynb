# %%
import random

import matplotlib.pyplot as plt
import numpy as np

import tensorflow
import keras
from tensorflow.keras.layers import Dense, Conv2DTranspose, LeakyReLU, Reshape, BatchNormalization, Activation, Conv2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dropout, MaxPool2D
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.datasets import  fashion_mnist

# %% [markdown]
# # Cargar MNist

# %% [markdown]
# Nos quedamos solo las camisetas que son donde es 0

# %%
def cargar_imagenes():
    (Xtrain, Ytrain), (_, _) = fashion_mnist.load_data()

    # Nos quedamos con las camiseta
    indice = np.where(Ytrain == 0)
    indice = indice[0]
    Xtrain = Xtrain[indice, :,:]
    # Normalizamos los datos
    X = Xtrain.astype('float32') / 255.0
    return X

dataset = cargar_imagenes()

for i in range(49):
  plt.subplot(7, 7, 1 + i)
  plt.axis('off')
  plt.imshow(dataset[i], cmap="binary")

dataset.shape
# Out:
# (6000, 28, 28)

# %% [markdown]
# # Creación del discriminador

# %%
discriminador = Sequential()

# Padding same permite que si es multiplo de 3 no se pierdan valores
discriminador.add(Conv2D(8,kernel_size=3,padding="same",
                         input_shape=(dataset.shape[1],dataset.shape[2],1),activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Conv2D(32,kernel_size=3,padding="same",activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Conv2D(64,kernel_size=3,padding="same",activation="relu"))

discriminador.add(MaxPool2D((2,2)))

discriminador.add(Flatten())

discriminador.add(Dense(32,activation="relu"))


discriminador.add(Dense(1,activation="sigmoid"))

discriminador.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 8)         80
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 8)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 32)        2336
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 3, 3, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 576)               0
#
#  dense_4 (Dense)             (None, 32)                18464
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 39409 (153.94 KB)
# Trainable params: 39409 (153.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Tiene que haber poco LR para poder entrenar los modelos con calma
discriminador.compile(loss="binary_crossentropy", optimizer = Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
discriminador.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 8)         80
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 8)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 14, 14, 32)        2336
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 3, 3, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 576)               0
#
#  dense_4 (Dense)             (None, 32)                18464
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 39409 (153.94 KB)
# Trainable params: 39409 (153.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Creación del generador

# %%
generador = Sequential()

# Vamos en incremento para intentar simular el Flatten del modelo Discriminador
generador.add(Dense(32,input_shape=(1,),activation="relu"))

# No tiene porqué pero va beneficiar la cantidad de neuronas = al discriminador
generador.add(Dense(576,activation="relu"))

# La capa de MaxPooling2D antes del Flatten para darle ya un Shape
generador.add(Reshape((3,3,64)))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Lo que hace es que vaya a saltos de 2 como iba la capa de MaxPooling2D duplicando el tamaño x2
# Con Padding = "valid" tendría el mismo (None, 7, 7, 32) en la última capa que el Discriminador
# Ya que podemos gestionar el valor de diferencia con +1 o -1 de tamaño de imagen
generador.add(Conv2DTranspose(64,kernel_size=3, strides=2,padding="valid",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Ahora tenemos que pasar de 7 a 14 con un 16 de Neuronas
generador.add(Conv2DTranspose(32,kernel_size=3, strides=2,padding="same",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Ahora tenemos que pasar de 14 a 28 con 8 de Neuronas
generador.add(Conv2DTranspose(8,kernel_size=3, strides=2,padding="same",activation="relu"))

# Añadimos una normalización del tipo BatchNormalization, cada Bach hace un repaso y los normaliza
generador.add(BatchNormalization())

# Borra la mitad de las neuronas de vez en cuando
generador.add(Dropout(0.5))

# Ahora una capa con 1 y sin modificar el tamaño con strides=1 y que acabe entre 0 y 1 con sigmoid
generador.add(Conv2DTranspose(1,kernel_size=3,strides=1,padding="same",activation="sigmoid"))

generador.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 32)                64
#
#  dense_7 (Dense)             (None, 576)               19008
#
#  reshape_1 (Reshape)         (None, 3, 3, 64)          0
#
#  batch_normalization_4 (Bat  (None, 3, 3, 64)          256
#  chNormalization)
#
#  conv2d_transpose_4 (Conv2D  (None, 7, 7, 64)          36928
#  Transpose)
#
#  batch_normalization_5 (Bat  (None, 7, 7, 64)          256
#  chNormalization)
#
#  conv2d_transpose_5 (Conv2D  (None, 14, 14, 32)        18464
#  Transpose)
#
#  batch_normalization_6 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  conv2d_transpose_6 (Conv2D  (None, 28, 28, 8)         2312
#  Transpose)
#
#  batch_normalization_7 (Bat  (None, 28, 28, 8)         32
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 28, 28, 8)         0
#
#  conv2d_transpose_7 (Conv2D  (None, 28, 28, 1)         73
#  Transpose)
#
# =================================================================
# Total params: 77521 (302.82 KB)
# Trainable params: 77185 (301.50 KB)
# Non-trainable params: 336 (1.31 KB)
# _________________________________________________________________

# %%
gan = Sequential()
gan.add(generador)
gan.add(discriminador)
gan.compile(loss="binary_crossentropy", optimizer = Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
def get_datos_true(nmuestras):
    """Devuelve imagenes verdaderas del DataSet

    Args:
        muestras (pd.DataFrame): DataFrame de Pandas

    Returns:
        List: Devuelve el X e Y del DataSet 
    """
    v = np.random.randint(0,dataset.shape[0],nmuestras)
    X = dataset[v]
    y = np.ones((nmuestras,1))
    return X,y

def get_datos_fake(nmuestras):
    """Genera datos falsos con el generador

    Args:
        nmuestras (int): Número de muestras

    Returns:
        List: Devuelve X e Y de un falso DataSet predicho
    """
    input = np.random.rand(nmuestras)
    X = generador.predict(input)
    y = np.zeros((nmuestras,1))
    return X,y

def entrenamiento(epochs=1, batch_size=128):
    """Entrena el modelo de Generador y Detector

    Args:
        epochs (int, optional): Nº de Epochs. Defaults to 1.
        batch_size (int, optional): Tamaño de los saltos. Defaults to 128.
    """
    max_len = dataset.shape[0]
    nbatchs = int(max_len / batch_size)
    acc_r,acc_f,acc_g=[],[],[]
    for epoch in range(epochs):
        print("Epoch : ", epoch)
        for batch in range(nbatchs):

            #region Discriminador
            acc_real = 0.0
            discriminador.trainable = True
            while acc_real < 0.2:
                X_real,y_real = get_datos_true(batch_size//2)
                # Permite entrenar a cachos el discriminador
                loss_real, acc_real = discriminador.train_on_batch(X_real,y_real)

            acc_fake=0.0
            while acc_fake < 0.2:
                X_fake,y_fake = get_datos_fake(batch_size//2)
                # Permite entrenar a cachos el discriminador
                loss_fake, acc_fake = discriminador.train_on_batch(X_fake,y_fake)

            discriminador.trainable = False

            #endregion

            #region Generador
            X_gan = np.random.randn(batch_size).reshape(batch_size,1)

            # Tenemos que intentar engañarlo, por lo que ponemos por la salida unos ya que significaría que son correctos
            # Hasta que el otro diga lo contrario
            y_gan = np.ones((batch_size,1))

            acc_gan,indice = 0.0,0
            while acc_gan < 0.2:
                if indice==40: break
                loss_gan, acc_gan = gan.train_on_batch(X_gan,y_gan)
                indice+=1
            #endregion

            print(f"Epoch: {epoch} - Batch: {batch}")
            print(f"loss_real: {loss_real} - loss_fake: {loss_fake} - loss_gan: {loss_gan}")
            print(f"acc_real: {acc_real} - acc_fake: {acc_fake} - acc_gan: {acc_gan}")
            acc_r.append(acc_real)
            acc_f.append(acc_fake)
            acc_g.append(acc_gan)
    return acc_r,acc_f,acc_g

# %%
values=entrenamiento(epochs=150)
# Out:
# Epoch :  0
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 0
# loss_real: 0.643081784248352 - loss_fake: 0.6889194250106812 - loss_gan: 0.6968224048614502
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 0.3203125
# 2/2 [==============================] - 0s 443us/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 1
# loss_real: 0.6643834710121155 - loss_fake: 0.6864880323410034 - loss_gan: 0.6887684464454651
# acc_real: 0.96875 - acc_fake: 1.0 - acc_gan: 0.703125
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 2
# loss_real: 0.662168562412262 - loss_fake: 0.688643217086792 - loss_gan: 0.6933756470680237
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 0.390625
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 0 - Batch: 3
# loss_real: 0.6590912342071533 - loss_fake: 0.6893215179443359 - loss_gan: 0.6853703856468201
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 0.78125
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 0 - Batch: 4
# loss_real: 0.65481036901474 - loss_fake: 0.6885260343551636 - loss_gan: 0.6836919784545898
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 0.75
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 5
# loss_real: 0.650780439376831 - loss_fake: 0.6910830736160278 - loss_gan: 0.6761484146118164
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 0.953125
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 0 - Batch: 6
# loss_real: 0.6422529220581055 - loss_fake: 0.6900721788406372 - loss_gan: 0.6724718809127808
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 0.984375
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 0 - Batch: 7
# loss_real: 0.6351494193077087 - loss_fake: 0.6898177862167358 - loss_gan: 0.669924795627594
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 0.984375
# 2/2 [==============================] - 0s 975us/step
# Epoch: 0 - Batch: 8
# loss_real: 0.6280375719070435 - loss_fake: 0.6930267214775085 - loss_gan: 0.6590316295623779
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 9
# loss_real: 0.6236585378646851 - loss_fake: 0.689325213432312 - loss_gan: 0.6593198180198669
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 0 - Batch: 10
# loss_real: 0.6201655864715576 - loss_fake: 0.6915163397789001 - loss_gan: 0.6522191762924194
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 842us/step
# Epoch: 0 - Batch: 11
# loss_real: 0.6099710464477539 - loss_fake: 0.6913254261016846 - loss_gan: 0.6482905745506287
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 12
# loss_real: 0.607205867767334 - loss_fake: 0.6905076503753662 - loss_gan: 0.6438227891921997
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 0 - Batch: 13
# loss_real: 0.6000462770462036 - loss_fake: 0.693158745765686 - loss_gan: 0.6342699527740479
# acc_real: 1.0 - acc_fake: 0.390625 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 14
# loss_real: 0.5917772650718689 - loss_fake: 0.6885306239128113 - loss_gan: 0.6406290531158447
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 18ms/step
# Epoch: 0 - Batch: 15
# loss_real: 0.5794765949249268 - loss_fake: 0.6902658939361572 - loss_gan: 0.6246055364608765
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 16
# loss_real: 0.5772707462310791 - loss_fake: 0.6895067691802979 - loss_gan: 0.6157720685005188
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 17
# loss_real: 0.57442307472229 - loss_fake: 0.6889160871505737 - loss_gan: 0.6085222959518433
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 0 - Batch: 18
# loss_real: 0.5471648573875427 - loss_fake: 0.6882991194725037 - loss_gan: 0.6032928228378296
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 19
# loss_real: 0.538486123085022 - loss_fake: 0.6911700367927551 - loss_gan: 0.5854538679122925
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 20
# loss_real: 0.5343101620674133 - loss_fake: 0.6909762024879456 - loss_gan: 0.5736013054847717
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 21
# loss_real: 0.5254110097885132 - loss_fake: 0.6891266107559204 - loss_gan: 0.5722920298576355
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 22
# loss_real: 0.5164283514022827 - loss_fake: 0.6930965185165405 - loss_gan: 0.5476852059364319
# acc_real: 1.0 - acc_fake: 0.75 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 0 - Batch: 23
# loss_real: 0.4965730905532837 - loss_fake: 0.6859651803970337 - loss_gan: 0.5489505529403687
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 0 - Batch: 24
# loss_real: 0.49166083335876465 - loss_fake: 0.6895585060119629 - loss_gan: 0.5282671451568604
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 25
# loss_real: 0.4736088514328003 - loss_fake: 0.6889191269874573 - loss_gan: 0.5160579085350037
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 26
# loss_real: 0.4721865653991699 - loss_fake: 0.6845898032188416 - loss_gan: 0.495097279548645
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 27
# loss_real: 0.45609229803085327 - loss_fake: 0.687507152557373 - loss_gan: 0.4877128601074219
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 0 - Batch: 28
# loss_real: 0.45031431317329407 - loss_fake: 0.6839947700500488 - loss_gan: 0.4744626581668854
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 0 - Batch: 29
# loss_real: 0.43907254934310913 - loss_fake: 0.6885859370231628 - loss_gan: 0.449450820684433
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 0 - Batch: 30
# loss_real: 0.42271384596824646 - loss_fake: 0.6848019361495972 - loss_gan: 0.4369909167289734
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 31
# loss_real: 0.412496954202652 - loss_fake: 0.6886075735092163 - loss_gan: 0.41835325956344604
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 32
# loss_real: 0.39874422550201416 - loss_fake: 0.6861087083816528 - loss_gan: 0.4141610264778137
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 33
# loss_real: 0.40274640917778015 - loss_fake: 0.6904052495956421 - loss_gan: 0.39758145809173584
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 34
# loss_real: 0.37330085039138794 - loss_fake: 0.6851690411567688 - loss_gan: 0.37150561809539795
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 384us/step
# Epoch: 0 - Batch: 35
# loss_real: 0.35574179887771606 - loss_fake: 0.6879521608352661 - loss_gan: 0.3485976755619049
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 36
# loss_real: 0.34768450260162354 - loss_fake: 0.6791567206382751 - loss_gan: 0.3375421166419983
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 0 - Batch: 37
# loss_real: 0.3443760275840759 - loss_fake: 0.679892897605896 - loss_gan: 0.32764577865600586
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 38
# loss_real: 0.3293251395225525 - loss_fake: 0.6839334964752197 - loss_gan: 0.29012972116470337
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 0 - Batch: 39
# loss_real: 0.3346850872039795 - loss_fake: 0.6893910765647888 - loss_gan: 0.2725696563720703
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 0 - Batch: 40
# loss_real: 0.313679039478302 - loss_fake: 0.6790212392807007 - loss_gan: 0.26287007331848145
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 0 - Batch: 41
# loss_real: 0.30650216341018677 - loss_fake: 0.6780132055282593 - loss_gan: 0.24883884191513062
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 0 - Batch: 42
# loss_real: 0.2756069004535675 - loss_fake: 0.6790497303009033 - loss_gan: 0.23187783360481262
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 0 - Batch: 43
# loss_real: 0.27176183462142944 - loss_fake: 0.6826501488685608 - loss_gan: 0.20703253149986267
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 19ms/step
# Epoch: 0 - Batch: 44
# loss_real: 0.276211678981781 - loss_fake: 0.6857199668884277 - loss_gan: 0.19173972308635712
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 0 - Batch: 45
# loss_real: 0.27013248205184937 - loss_fake: 0.6870442628860474 - loss_gan: 0.17511914670467377
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  1
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 0
# loss_real: 0.2648548185825348 - loss_fake: 0.686269223690033 - loss_gan: 0.1589479148387909
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 1 - Batch: 1
# loss_real: 0.23807580769062042 - loss_fake: 0.6839139461517334 - loss_gan: 0.14435625076293945
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 2
# loss_real: 0.23559582233428955 - loss_fake: 0.6817450523376465 - loss_gan: 0.1315772831439972
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 1 - Batch: 3
# loss_real: 0.2188650518655777 - loss_fake: 0.6792566776275635 - loss_gan: 0.11988210678100586
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 1 - Batch: 4
# loss_real: 0.22955960035324097 - loss_fake: 0.6759152412414551 - loss_gan: 0.1066301017999649
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 5
# loss_real: 0.20955103635787964 - loss_fake: 0.6717546582221985 - loss_gan: 0.09618860483169556
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 6
# loss_real: 0.2017698734998703 - loss_fake: 0.6674877405166626 - loss_gan: 0.08864379674196243
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 1 - Batch: 7
# loss_real: 0.19486454129219055 - loss_fake: 0.661342978477478 - loss_gan: 0.07801558077335358
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 8
# loss_real: 0.18670645356178284 - loss_fake: 0.6548970341682434 - loss_gan: 0.07037179172039032
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 1 - Batch: 9
# loss_real: 0.16964834928512573 - loss_fake: 0.6472092866897583 - loss_gan: 0.06426644325256348
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 10
# loss_real: 0.1825089305639267 - loss_fake: 0.638160765171051 - loss_gan: 0.05641993507742882
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 11
# loss_real: 0.15779905021190643 - loss_fake: 0.6311588287353516 - loss_gan: 0.05112744867801666
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 1 - Batch: 12
# loss_real: 0.16601979732513428 - loss_fake: 0.6237329244613647 - loss_gan: 0.04598550871014595
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 13
# loss_real: 0.16389821469783783 - loss_fake: 0.6154090166091919 - loss_gan: 0.04017778858542442
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 1 - Batch: 14
# loss_real: 0.15549734234809875 - loss_fake: 0.6083763241767883 - loss_gan: 0.0340450219810009
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 1 - Batch: 15
# loss_real: 0.1419299840927124 - loss_fake: 0.6021686792373657 - loss_gan: 0.03278904780745506
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1 - Batch: 16
# loss_real: 0.14098036289215088 - loss_fake: 0.5935311913490295 - loss_gan: 0.026813402771949768
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 17
# loss_real: 0.14731857180595398 - loss_fake: 0.5856138467788696 - loss_gan: 0.023822885006666183
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 18
# loss_real: 0.12482190877199173 - loss_fake: 0.5780072212219238 - loss_gan: 0.021578671410679817
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 19
# loss_real: 0.12580500543117523 - loss_fake: 0.5708777904510498 - loss_gan: 0.017858248203992844
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 1 - Batch: 20
# loss_real: 0.13276046514511108 - loss_fake: 0.5627851486206055 - loss_gan: 0.01602543145418167
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 21
# loss_real: 0.12411218881607056 - loss_fake: 0.5551413297653198 - loss_gan: 0.014358950778841972
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 1 - Batch: 22
# loss_real: 0.11563747376203537 - loss_fake: 0.5475144386291504 - loss_gan: 0.01271603163331747
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 1 - Batch: 23
# loss_real: 0.10974188148975372 - loss_fake: 0.5402262210845947 - loss_gan: 0.010939395055174828
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 24
# loss_real: 0.1050088107585907 - loss_fake: 0.5332672595977783 - loss_gan: 0.010004134848713875
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 25
# loss_real: 0.1076427698135376 - loss_fake: 0.52528315782547 - loss_gan: 0.008803949691355228
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 1ms/step
# Epoch: 1 - Batch: 26
# loss_real: 0.09511987864971161 - loss_fake: 0.5163524746894836 - loss_gan: 0.007458467502146959
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 27
# loss_real: 0.1052297055721283 - loss_fake: 0.507564902305603 - loss_gan: 0.007101835682988167
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 28
# loss_real: 0.09179089218378067 - loss_fake: 0.5008376836776733 - loss_gan: 0.00562200415879488
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 29
# loss_real: 0.07564601302146912 - loss_fake: 0.49171310663223267 - loss_gan: 0.005324632860720158
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 410us/step
# Epoch: 1 - Batch: 30
# loss_real: 0.09662041813135147 - loss_fake: 0.4828951060771942 - loss_gan: 0.004409394226968288
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 31
# loss_real: 0.0838015228509903 - loss_fake: 0.47527945041656494 - loss_gan: 0.0038099605590105057
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 32
# loss_real: 0.08274436742067337 - loss_fake: 0.4673295021057129 - loss_gan: 0.0036425332073122263
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 33
# loss_real: 0.07943296432495117 - loss_fake: 0.4588932991027832 - loss_gan: 0.0031028976663947105
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 34
# loss_real: 0.07584451138973236 - loss_fake: 0.4524547755718231 - loss_gan: 0.003035665024071932
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 35
# loss_real: 0.06785798072814941 - loss_fake: 0.44494330883026123 - loss_gan: 0.002216826658695936
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 36
# loss_real: 0.06916562467813492 - loss_fake: 0.4384024441242218 - loss_gan: 0.0020426646806299686
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 37
# loss_real: 0.0589141771197319 - loss_fake: 0.43148064613342285 - loss_gan: 0.0018047387711703777
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 1 - Batch: 38
# loss_real: 0.0648181214928627 - loss_fake: 0.424846887588501 - loss_gan: 0.0014695243444293737
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1 - Batch: 39
# loss_real: 0.06575216352939606 - loss_fake: 0.4179186224937439 - loss_gan: 0.0013903907965868711
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 1 - Batch: 40
# loss_real: 0.07539211213588715 - loss_fake: 0.4108903408050537 - loss_gan: 0.0013738723937422037
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 41
# loss_real: 0.0661604255437851 - loss_fake: 0.404632031917572 - loss_gan: 0.0010476862080395222
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 1 - Batch: 42
# loss_real: 0.05273129791021347 - loss_fake: 0.3970276415348053 - loss_gan: 0.0008961067069321871
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 1 - Batch: 43
# loss_real: 0.05536547303199768 - loss_fake: 0.39072585105895996 - loss_gan: 0.0008527004974894226
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 44
# loss_real: 0.048856765031814575 - loss_fake: 0.38369762897491455 - loss_gan: 0.0007649677572771907
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 1 - Batch: 45
# loss_real: 0.04863189905881882 - loss_fake: 0.3769111633300781 - loss_gan: 0.000618190853856504
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  2
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 2 - Batch: 0
# loss_real: 0.04663647711277008 - loss_fake: 0.3699859082698822 - loss_gan: 0.0005882843397557735
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 1ms/step
# Epoch: 2 - Batch: 1
# loss_real: 0.04820507764816284 - loss_fake: 0.3631760776042938 - loss_gan: 0.0005518518155440688
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 2
# loss_real: 0.03929125890135765 - loss_fake: 0.3566017150878906 - loss_gan: 0.0004639383405447006
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 18ms/step
# Epoch: 2 - Batch: 3
# loss_real: 0.04678796976804733 - loss_fake: 0.3493517339229584 - loss_gan: 0.00045727420365437865
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 4
# loss_real: 0.047046396881341934 - loss_fake: 0.34300416707992554 - loss_gan: 0.0003770175972022116
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 5
# loss_real: 0.05211251974105835 - loss_fake: 0.3356752395629883 - loss_gan: 0.0003292667679488659
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 6
# loss_real: 0.03997842222452164 - loss_fake: 0.32880279421806335 - loss_gan: 0.0003054292465094477
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 7
# loss_real: 0.03910886496305466 - loss_fake: 0.3230322003364563 - loss_gan: 0.0002545167808420956
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 8
# loss_real: 0.04638651758432388 - loss_fake: 0.3151577115058899 - loss_gan: 0.00021729579020757228
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 2 - Batch: 9
# loss_real: 0.035131387412548065 - loss_fake: 0.30823907256126404 - loss_gan: 0.0001872069260571152
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 10
# loss_real: 0.034380845725536346 - loss_fake: 0.3019411563873291 - loss_gan: 0.00018100622401107103
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 11
# loss_real: 0.03977148234844208 - loss_fake: 0.29487988352775574 - loss_gan: 0.00017171222134493291
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 12
# loss_real: 0.029872922226786613 - loss_fake: 0.2880989909172058 - loss_gan: 0.00014859013026580215
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 13
# loss_real: 0.02963290363550186 - loss_fake: 0.2816596031188965 - loss_gan: 0.0001224486477440223
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 2 - Batch: 14
# loss_real: 0.04018533229827881 - loss_fake: 0.2745989263057709 - loss_gan: 0.00011703855125233531
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 2 - Batch: 15
# loss_real: 0.027256295084953308 - loss_fake: 0.26843172311782837 - loss_gan: 0.00013322477752808481
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 16
# loss_real: 0.031398121267557144 - loss_fake: 0.26162904500961304 - loss_gan: 8.905245340429246e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 2 - Batch: 17
# loss_real: 0.031606197357177734 - loss_fake: 0.25504639744758606 - loss_gan: 9.515760029898956e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 18
# loss_real: 0.02780032716691494 - loss_fake: 0.24878785014152527 - loss_gan: 7.382909825537354e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 19
# loss_real: 0.03138609230518341 - loss_fake: 0.24204638600349426 - loss_gan: 6.715094059472904e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 2 - Batch: 20
# loss_real: 0.030902504920959473 - loss_fake: 0.2359248250722885 - loss_gan: 5.997638072585687e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 21
# loss_real: 0.02674815058708191 - loss_fake: 0.22945508360862732 - loss_gan: 5.835761839989573e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 22
# loss_real: 0.023415347561240196 - loss_fake: 0.22304092347621918 - loss_gan: 4.8172936658374965e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 23
# loss_real: 0.0349474661052227 - loss_fake: 0.21698802709579468 - loss_gan: 5.349593993742019e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 263us/step
# Epoch: 2 - Batch: 24
# loss_real: 0.024073634296655655 - loss_fake: 0.2110150158405304 - loss_gan: 4.002823698101565e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 2 - Batch: 25
# loss_real: 0.025393299758434296 - loss_fake: 0.20491918921470642 - loss_gan: 3.395120074856095e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 26
# loss_real: 0.02331499382853508 - loss_fake: 0.19905102252960205 - loss_gan: 4.1724455513758585e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 20ms/step
# Epoch: 2 - Batch: 27
# loss_real: 0.025663577020168304 - loss_fake: 0.19336992502212524 - loss_gan: 4.546716081677005e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 28
# loss_real: 0.02316318266093731 - loss_fake: 0.18812620639801025 - loss_gan: 3.4695454814936966e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 2 - Batch: 29
# loss_real: 0.02974054589867592 - loss_fake: 0.1826121211051941 - loss_gan: 2.9679533326998353e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 2 - Batch: 30
# loss_real: 0.021552179008722305 - loss_fake: 0.1771087646484375 - loss_gan: 2.8606969863176346e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 31
# loss_real: 0.023619813844561577 - loss_fake: 0.1720494031906128 - loss_gan: 2.5988862034864724e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 2 - Batch: 32
# loss_real: 0.02469748817384243 - loss_fake: 0.16694164276123047 - loss_gan: 2.445894460834097e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 33
# loss_real: 0.025605041533708572 - loss_fake: 0.16219159960746765 - loss_gan: 1.963511749636382e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 2 - Batch: 34
# loss_real: 0.024551598355174065 - loss_fake: 0.15706008672714233 - loss_gan: 2.396507261437364e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 35
# loss_real: 0.020239384844899178 - loss_fake: 0.15229949355125427 - loss_gan: 1.9277673345641233e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 2 - Batch: 36
# loss_real: 0.020279595628380775 - loss_fake: 0.14799222350120544 - loss_gan: 1.9160588635713793e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 2 - Batch: 37
# loss_real: 0.02468455582857132 - loss_fake: 0.14394015073776245 - loss_gan: 1.9957715267082676e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 38
# loss_real: 0.02401086688041687 - loss_fake: 0.13907156884670258 - loss_gan: 2.14627380046295e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 39
# loss_real: 0.020057033747434616 - loss_fake: 0.1349467635154724 - loss_gan: 1.2467684427974746e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 2 - Batch: 40
# loss_real: 0.030065732076764107 - loss_fake: 0.1315407156944275 - loss_gan: 1.5674773749196902e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 2 - Batch: 41
# loss_real: 0.026270972564816475 - loss_fake: 0.1272485852241516 - loss_gan: 1.2268825230421498e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 42
# loss_real: 0.02051980420947075 - loss_fake: 0.12347175180912018 - loss_gan: 9.516288628219627e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 43
# loss_real: 0.025283966213464737 - loss_fake: 0.11859949678182602 - loss_gan: 1.1514463039929979e-05
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 2 - Batch: 44
# loss_real: 0.030788041651248932 - loss_fake: 0.11433784663677216 - loss_gan: 9.631006832933053e-06
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 2 - Batch: 45
# loss_real: 0.025396622717380524 - loss_fake: 0.10863198339939117 - loss_gan: 8.866667485563084e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  3
# 2/2 [==============================] - 0s 1ms/step
# Epoch: 3 - Batch: 0
# loss_real: 0.017803901806473732 - loss_fake: 0.10374978184700012 - loss_gan: 9.214663805323653e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 3 - Batch: 1
# loss_real: 0.016980275511741638 - loss_fake: 0.09878955036401749 - loss_gan: 9.185223461827263e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 3 - Batch: 2
# loss_real: 0.01778567023575306 - loss_fake: 0.09436998516321182 - loss_gan: 8.593116945121437e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 3
# loss_real: 0.01955494098365307 - loss_fake: 0.0901387631893158 - loss_gan: 7.26094458514126e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 18ms/step
# Epoch: 3 - Batch: 4
# loss_real: 0.025879019871354103 - loss_fake: 0.08617827296257019 - loss_gan: 5.604436410067137e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 3 - Batch: 5
# loss_real: 0.016731180250644684 - loss_fake: 0.08206228911876678 - loss_gan: 5.242305633146316e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 6
# loss_real: 0.013699420727789402 - loss_fake: 0.07832546532154083 - loss_gan: 5.394329946284415e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 3 - Batch: 7
# loss_real: 0.02986827678978443 - loss_fake: 0.07508202642202377 - loss_gan: 4.037718099425547e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 8
# loss_real: 0.022517018020153046 - loss_fake: 0.07270805537700653 - loss_gan: 4.215567969367839e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 3 - Batch: 9
# loss_real: 0.034501541405916214 - loss_fake: 0.06965182721614838 - loss_gan: 4.430955868883757e-06
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 10
# loss_real: 0.03178362548351288 - loss_fake: 0.06674791872501373 - loss_gan: 3.1755960208101897e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 3 - Batch: 11
# loss_real: 0.021917851641774178 - loss_fake: 0.06465958058834076 - loss_gan: 2.814885647239862e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 12
# loss_real: 0.019669868052005768 - loss_fake: 0.062208689749240875 - loss_gan: 2.709053205762757e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 3 - Batch: 13
# loss_real: 0.04887234792113304 - loss_fake: 0.06016234681010246 - loss_gan: 2.071707513096044e-06
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 14
# loss_real: 0.018783483654260635 - loss_fake: 0.05850717052817345 - loss_gan: 1.9875060388585553e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 15
# loss_real: 0.025245439261198044 - loss_fake: 0.05645090341567993 - loss_gan: 1.9072407440035022e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 3 - Batch: 16
# loss_real: 0.013985544443130493 - loss_fake: 0.05450276657938957 - loss_gan: 2.081209686366492e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 3 - Batch: 17
# loss_real: 0.0145096555352211 - loss_fake: 0.05276496708393097 - loss_gan: 1.4740875258212327e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 926us/step
# Epoch: 3 - Batch: 18
# loss_real: 0.017830541357398033 - loss_fake: 0.050786204636096954 - loss_gan: 1.7156974081444787e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 19
# loss_real: 0.026995137333869934 - loss_fake: 0.04970356822013855 - loss_gan: 1.3778469565295381e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 3 - Batch: 20
# loss_real: 0.024271808564662933 - loss_fake: 0.04916944354772568 - loss_gan: 9.845618933468359e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 3 - Batch: 21
# loss_real: 0.018065061420202255 - loss_fake: 0.04703490063548088 - loss_gan: 1.0027097232523374e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 22
# loss_real: 0.012897491455078125 - loss_fake: 0.045556649565696716 - loss_gan: 9.649978665038361e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 23
# loss_real: 0.045659139752388 - loss_fake: 0.04385863617062569 - loss_gan: 8.366747579202638e-07
# acc_real: 0.984375 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 3 - Batch: 24
# loss_real: 0.015693364664912224 - loss_fake: 0.04291451722383499 - loss_gan: 1.0812080972755211e-06
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 3 - Batch: 25
# loss_real: 0.013019826263189316 - loss_fake: 0.042083144187927246 - loss_gan: 8.072494779298722e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 3 - Batch: 26
# loss_real: 0.01159011758863926 - loss_fake: 0.041032351553440094 - loss_gan: 4.220422056278039e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 27
# loss_real: 0.012530838139355183 - loss_fake: 0.039826661348342896 - loss_gan: 5.54206224023801e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 3 - Batch: 28
# loss_real: 0.01184738427400589 - loss_fake: 0.03825293481349945 - loss_gan: 6.74629745844868e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 29
# loss_real: 0.008288264274597168 - loss_fake: 0.0370650514960289 - loss_gan: 4.823476160709106e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 3 - Batch: 30
# loss_real: 0.013812095858156681 - loss_fake: 0.0362878143787384 - loss_gan: 4.540890472526371e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 31
# loss_real: 0.014169290661811829 - loss_fake: 0.03559674322605133 - loss_gan: 3.752759312192211e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 32
# loss_real: 0.018497785553336143 - loss_fake: 0.03443404287099838 - loss_gan: 3.702100457303459e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 3 - Batch: 33
# loss_real: 0.020678909495472908 - loss_fake: 0.034008920192718506 - loss_gan: 2.5916580170814996e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 3 - Batch: 34
# loss_real: 0.02531544305384159 - loss_fake: 0.03392563387751579 - loss_gan: 2.8111784899920167e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 35
# loss_real: 0.007678654044866562 - loss_fake: 0.032940298318862915 - loss_gan: 2.6754020154839964e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 3 - Batch: 36
# loss_real: 0.010554833337664604 - loss_fake: 0.031443119049072266 - loss_gan: 2.1482247802850907e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 37
# loss_real: 0.015280580148100853 - loss_fake: 0.03042575530707836 - loss_gan: 4.2414731638018566e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 3 - Batch: 38
# loss_real: 0.013449279591441154 - loss_fake: 0.029749788343906403 - loss_gan: 2.0115754750804626e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 3 - Batch: 39
# loss_real: 0.009802846238017082 - loss_fake: 0.029105152934789658 - loss_gan: 2.073873730523701e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 40
# loss_real: 0.01223228219896555 - loss_fake: 0.028596976771950722 - loss_gan: 1.9468420475732273e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 21ms/step
# Epoch: 3 - Batch: 41
# loss_real: 0.009152154438197613 - loss_fake: 0.02795920893549919 - loss_gan: 1.951144525946802e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 42
# loss_real: 0.009140015579760075 - loss_fake: 0.027374623343348503 - loss_gan: 1.7495381143817212e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 3 - Batch: 43
# loss_real: 0.007768142502754927 - loss_fake: 0.026742812246084213 - loss_gan: 1.4002743853325228e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 3 - Batch: 44
# loss_real: 0.007741917390376329 - loss_fake: 0.02607746236026287 - loss_gan: 1.3271800014535984e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 3 - Batch: 45
# loss_real: 0.007292589172720909 - loss_fake: 0.025406263768672943 - loss_gan: 1.327555452235174e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# Epoch :  4
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 0
# loss_real: 0.021100902929902077 - loss_fake: 0.024889986962080002 - loss_gan: 1.22754755693677e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 20ms/step
# Epoch: 4 - Batch: 1
# loss_real: 0.021891389042139053 - loss_fake: 0.024735093116760254 - loss_gan: 1.1898052321157593e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 2
# loss_real: 0.011067632585763931 - loss_fake: 0.02452513389289379 - loss_gan: 9.216006446877145e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 3
# loss_real: 0.009662564843893051 - loss_fake: 0.024561064317822456 - loss_gan: 8.60862314766564e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 4
# loss_real: 0.007859548553824425 - loss_fake: 0.02356065809726715 - loss_gan: 1.1845558844925108e-07
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 5
# loss_real: 0.008845550939440727 - loss_fake: 0.02264326438307762 - loss_gan: 9.235689901743172e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 12ms/step
# Epoch: 4 - Batch: 6
# loss_real: 0.005507743917405605 - loss_fake: 0.021790623664855957 - loss_gan: 8.830512854274275e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 7
# loss_real: 0.011206230148673058 - loss_fake: 0.021426107734441757 - loss_gan: 7.78740059104166e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 8
# loss_real: 0.00668302271515131 - loss_fake: 0.021099265664815903 - loss_gan: 6.562678578347914e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 9
# loss_real: 0.017661001533269882 - loss_fake: 0.02072044461965561 - loss_gan: 4.0344566798466985e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 4 - Batch: 10
# loss_real: 0.005933418404310942 - loss_fake: 0.020644504576921463 - loss_gan: 5.374971223659486e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 11
# loss_real: 0.009312279522418976 - loss_fake: 0.020808536559343338 - loss_gan: 7.403929203064763e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 12
# loss_real: 0.015540854074060917 - loss_fake: 0.020361648872494698 - loss_gan: 5.019071736001024e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 4 - Batch: 13
# loss_real: 0.005982017144560814 - loss_fake: 0.01979224570095539 - loss_gan: 5.127448687858305e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 14
# loss_real: 0.008128213696181774 - loss_fake: 0.019383635371923447 - loss_gan: 3.998148656592093e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 15
# loss_real: 0.00958571769297123 - loss_fake: 0.01915157586336136 - loss_gan: 4.138140496934284e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 16
# loss_real: 0.0075010331347584724 - loss_fake: 0.018812146037817 - loss_gan: 4.509438866762139e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 17
# loss_real: 0.006126848515123129 - loss_fake: 0.01812594383955002 - loss_gan: 3.236448975485473e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 18
# loss_real: 0.012448437511920929 - loss_fake: 0.01787513494491577 - loss_gan: 2.1784458681395336e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 4 - Batch: 19
# loss_real: 0.012736472301185131 - loss_fake: 0.017637422308325768 - loss_gan: 2.677442445531142e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 20
# loss_real: 0.006381746847182512 - loss_fake: 0.017637949436903 - loss_gan: 3.489137512246998e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 4 - Batch: 21
# loss_real: 0.005362310446798801 - loss_fake: 0.017037812620401382 - loss_gan: 3.1241199849318946e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 3ms/step
# Epoch: 4 - Batch: 22
# loss_real: 0.02098725736141205 - loss_fake: 0.01682540774345398 - loss_gan: 3.202350029596346e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 23
# loss_real: 0.008711365982890129 - loss_fake: 0.01702824980020523 - loss_gan: 2.997076009592092e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 24
# loss_real: 0.007128264755010605 - loss_fake: 0.017227811738848686 - loss_gan: 3.598843534291518e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 25
# loss_real: 0.007375933229923248 - loss_fake: 0.01698068156838417 - loss_gan: 1.3076569160830331e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 26
# loss_real: 0.003558805910870433 - loss_fake: 0.016456851735711098 - loss_gan: 2.2832615798051847e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 4 - Batch: 27
# loss_real: 0.020617302507162094 - loss_fake: 0.015880916267633438 - loss_gan: 1.6520953494136847e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 4 - Batch: 28
# loss_real: 0.013111216016113758 - loss_fake: 0.015672538429498672 - loss_gan: 1.7017747211411915e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 4 - Batch: 29
# loss_real: 0.010616208426654339 - loss_fake: 0.015515303239226341 - loss_gan: 2.3216720990149042e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 4 - Batch: 30
# loss_real: 0.003071578685194254 - loss_fake: 0.01532764919102192 - loss_gan: 1.1038404856833495e-08
# acc_real: 1.0 - acc_fake: 1.0 - acc_gan: 1.0
# 2/2 [==============================] - 0s 0s/step
# Epoch: 4 - Batch: 31
# ...
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 148 - Batch: 44
# loss_real: 0.7954039573669434 - loss_fake: 0.6042693257331848 - loss_gan: 0.6898051500320435
# acc_real: 0.546875 - acc_fake: 0.8125 - acc_gan: 0.671875
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 26ms/step
# Epoch: 148 - Batch: 45
# loss_real: 0.9096882939338684 - loss_fake: 0.6433364152908325 - loss_gan: 0.6233556270599365
# acc_real: 0.359375 - acc_fake: 0.609375 - acc_gan: 0.75
# Epoch :  149
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 0
# loss_real: 1.0241925716400146 - loss_fake: 0.7208030223846436 - loss_gan: 0.5784075260162354
# acc_real: 0.421875 - acc_fake: 0.5 - acc_gan: 0.828125
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 149 - Batch: 1
# loss_real: 0.9151935577392578 - loss_fake: 0.7883318066596985 - loss_gan: 0.5332716703414917
# acc_real: 0.515625 - acc_fake: 0.25 - acc_gan: 0.9765625
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 2
# loss_real: 0.937994122505188 - loss_fake: 0.6112900972366333 - loss_gan: 0.701064944267273
# acc_real: 0.4375 - acc_fake: 0.765625 - acc_gan: 0.6171875
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 3
# loss_real: 0.9839529991149902 - loss_fake: 0.6388098001480103 - loss_gan: 0.6578888893127441
# acc_real: 0.375 - acc_fake: 0.65625 - acc_gan: 0.6953125
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 4
# loss_real: 1.1545372009277344 - loss_fake: 0.7044923305511475 - loss_gan: 0.5827147364616394
# acc_real: 0.28125 - acc_fake: 0.484375 - acc_gan: 0.8984375
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 27ms/step
# Epoch: 149 - Batch: 5
# loss_real: 0.9740533828735352 - loss_fake: 0.7676846981048584 - loss_gan: 0.5268091559410095
# acc_real: 0.359375 - acc_fake: 0.296875 - acc_gan: 0.9609375
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 6
# loss_real: 0.964891791343689 - loss_fake: 0.637955904006958 - loss_gan: 0.6990718245506287
# acc_real: 0.53125 - acc_fake: 0.578125 - acc_gan: 0.640625
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 7
# loss_real: 1.099557638168335 - loss_fake: 0.6393111944198608 - loss_gan: 0.6323769092559814
# acc_real: 0.3125 - acc_fake: 0.609375 - acc_gan: 0.7421875
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 8
# loss_real: 1.0404722690582275 - loss_fake: 0.7244530916213989 - loss_gan: 0.5773999691009521
# acc_real: 0.328125 - acc_fake: 0.390625 - acc_gan: 0.921875
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 9
# loss_real: 1.0450043678283691 - loss_fake: 0.7840310335159302 - loss_gan: 0.533227801322937
# acc_real: 0.359375 - acc_fake: 0.296875 - acc_gan: 0.96875
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 149 - Batch: 10
# loss_real: 0.8523422479629517 - loss_fake: 0.5788827538490295 - loss_gan: 0.7172514200210571
# acc_real: 0.59375 - acc_fake: 0.84375 - acc_gan: 0.5390625
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 11
# loss_real: 1.1389310359954834 - loss_fake: 0.6016402244567871 - loss_gan: 0.6709524989128113
# acc_real: 0.25 - acc_fake: 0.71875 - acc_gan: 0.671875
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 149 - Batch: 12
# loss_real: 1.0751032829284668 - loss_fake: 0.6918985843658447 - loss_gan: 0.5786641836166382
# acc_real: 0.296875 - acc_fake: 0.46875 - acc_gan: 0.921875
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 149 - Batch: 13
# loss_real: 0.9596890211105347 - loss_fake: 0.7797254323959351 - loss_gan: 0.5331481695175171
# acc_real: 0.53125 - acc_fake: 0.328125 - acc_gan: 0.953125
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 2ms/step
# Epoch: 149 - Batch: 14
# loss_real: 1.1168042421340942 - loss_fake: 0.5936069488525391 - loss_gan: 0.6862097978591919
# acc_real: 0.375 - acc_fake: 0.796875 - acc_gan: 0.671875
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 149 - Batch: 15
# loss_real: 0.9902703762054443 - loss_fake: 0.6417808532714844 - loss_gan: 0.6306970119476318
# acc_real: 0.296875 - acc_fake: 0.546875 - acc_gan: 0.734375
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 16
# loss_real: 1.033060073852539 - loss_fake: 0.7265514135360718 - loss_gan: 0.5680807828903198
# acc_real: 0.390625 - acc_fake: 0.359375 - acc_gan: 0.8828125
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 17
# loss_real: 0.9473738074302673 - loss_fake: 0.8000405430793762 - loss_gan: 0.5377769470214844
# acc_real: 0.484375 - acc_fake: 0.265625 - acc_gan: 0.9140625
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 18
# loss_real: 0.9269696474075317 - loss_fake: 0.810391902923584 - loss_gan: 0.5264471769332886
# acc_real: 0.46875 - acc_fake: 0.21875 - acc_gan: 0.953125
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 19
# loss_real: 1.1146349906921387 - loss_fake: 0.7989408373832703 - loss_gan: 0.5313034653663635
# acc_real: 0.4375 - acc_fake: 0.28125 - acc_gan: 0.9375
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 149 - Batch: 20
# loss_real: 0.9506152868270874 - loss_fake: 0.809613049030304 - loss_gan: 0.534610390663147
# acc_real: 0.390625 - acc_fake: 0.25 - acc_gan: 0.96875
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 149 - Batch: 21
# loss_real: 0.8716282844543457 - loss_fake: 0.7730083465576172 - loss_gan: 0.5651519298553467
# acc_real: 0.46875 - acc_fake: 0.3125 - acc_gan: 0.8984375
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 149 - Batch: 22
# loss_real: 0.955173909664154 - loss_fake: 0.7262797355651855 - loss_gan: 0.593694269657135
# acc_real: 0.421875 - acc_fake: 0.421875 - acc_gan: 0.828125
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 23
# loss_real: 0.9965082406997681 - loss_fake: 0.7110072374343872 - loss_gan: 0.5842195749282837
# acc_real: 0.421875 - acc_fake: 0.453125 - acc_gan: 0.8671875
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 149 - Batch: 24
# loss_real: 0.8535629510879517 - loss_fake: 0.6995090246200562 - loss_gan: 0.5739398002624512
# acc_real: 0.421875 - acc_fake: 0.453125 - acc_gan: 0.8515625
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 0s/step
# Epoch: 149 - Batch: 25
# loss_real: 1.2238694429397583 - loss_fake: 0.7522305250167847 - loss_gan: 0.5597347617149353
# acc_real: 0.296875 - acc_fake: 0.375 - acc_gan: 0.9375
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 26
# loss_real: 0.9790707230567932 - loss_fake: 0.7684227228164673 - loss_gan: 0.5409762859344482
# acc_real: 0.453125 - acc_fake: 0.359375 - acc_gan: 0.9453125
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 17ms/step
# Epoch: 149 - Batch: 27
# loss_real: 1.0641570091247559 - loss_fake: 0.7636280059814453 - loss_gan: 0.5305374264717102
# acc_real: 0.375 - acc_fake: 0.375 - acc_gan: 0.984375
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 28
# loss_real: 0.9520134925842285 - loss_fake: 0.7837861776351929 - loss_gan: 0.544530987739563
# acc_real: 0.296875 - acc_fake: 0.328125 - acc_gan: 0.9375
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 29
# loss_real: 1.0426584482192993 - loss_fake: 0.7601643800735474 - loss_gan: 0.5622835755348206
# acc_real: 0.4375 - acc_fake: 0.453125 - acc_gan: 0.9140625
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 30
# loss_real: 0.9590964913368225 - loss_fake: 0.7874544858932495 - loss_gan: 0.5749618411064148
# acc_real: 0.390625 - acc_fake: 0.28125 - acc_gan: 0.890625
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 16ms/step
# Epoch: 149 - Batch: 31
# loss_real: 0.9828183054924011 - loss_fake: 0.7536152601242065 - loss_gan: 0.5839390158653259
# acc_real: 0.390625 - acc_fake: 0.390625 - acc_gan: 0.8828125
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 21ms/step
# Epoch: 149 - Batch: 32
# loss_real: 0.9017565250396729 - loss_fake: 0.7142170667648315 - loss_gan: 0.607833981513977
# acc_real: 0.4375 - acc_fake: 0.453125 - acc_gan: 0.7890625
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 33
# loss_real: 0.9229955673217773 - loss_fake: 0.7396121025085449 - loss_gan: 0.6102083921432495
# acc_real: 0.296875 - acc_fake: 0.390625 - acc_gan: 0.8359375
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 149 - Batch: 34
# loss_real: 1.1088098287582397 - loss_fake: 0.7643846273422241 - loss_gan: 0.6015598773956299
# acc_real: 0.359375 - acc_fake: 0.359375 - acc_gan: 0.8984375
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 35
# loss_real: 1.1111438274383545 - loss_fake: 0.7936336994171143 - loss_gan: 0.5822361707687378
# acc_real: 0.328125 - acc_fake: 0.3125 - acc_gan: 0.890625
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 36
# loss_real: 0.9929377436637878 - loss_fake: 0.7556891441345215 - loss_gan: 0.5795565843582153
# acc_real: 0.40625 - acc_fake: 0.390625 - acc_gan: 0.921875
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 37
# loss_real: 0.990965723991394 - loss_fake: 0.756500244140625 - loss_gan: 0.5947404503822327
# acc_real: 0.390625 - acc_fake: 0.34375 - acc_gan: 0.8515625
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 38
# loss_real: 1.0042402744293213 - loss_fake: 0.8108053207397461 - loss_gan: 0.5862476825714111
# acc_real: 0.34375 - acc_fake: 0.25 - acc_gan: 0.8671875
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 39
# loss_real: 1.0729235410690308 - loss_fake: 0.7647280693054199 - loss_gan: 0.5695508718490601
# acc_real: 0.25 - acc_fake: 0.421875 - acc_gan: 0.8984375
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 14ms/step
# Epoch: 149 - Batch: 40
# loss_real: 1.071363925933838 - loss_fake: 0.7883181571960449 - loss_gan: 0.558659553527832
# acc_real: 0.359375 - acc_fake: 0.328125 - acc_gan: 0.921875
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 149 - Batch: 41
# loss_real: 1.1779823303222656 - loss_fake: 0.8038637042045593 - loss_gan: 0.5648390054702759
# acc_real: 0.265625 - acc_fake: 0.25 - acc_gan: 0.921875
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 42
# loss_real: 1.1115394830703735 - loss_fake: 0.759838342666626 - loss_gan: 0.5686048269271851
# acc_real: 0.375 - acc_fake: 0.375 - acc_gan: 0.921875
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 43
# loss_real: 1.0529661178588867 - loss_fake: 0.7798235416412354 - loss_gan: 0.5601605176925659
# acc_real: 0.328125 - acc_fake: 0.265625 - acc_gan: 0.9375
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# Epoch: 149 - Batch: 44
# loss_real: 0.9627630114555359 - loss_fake: 0.7535319328308105 - loss_gan: 0.5879199504852295
# acc_real: 0.390625 - acc_fake: 0.3125 - acc_gan: 0.9140625
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 149 - Batch: 45
# loss_real: 1.211546540260315 - loss_fake: 0.762794017791748 - loss_gan: 0.5644242763519287
# acc_real: 0.296875 - acc_fake: 0.25 - acc_gan: 0.9296875

# %%
plt.figure(figsize=(16, 12))

plt.plot(values[0])
plt.plot(values[1])
plt.plot(values[2])

# %%
# Hay que intentar estabilizar la red

X_pru = np.random.randn(49)
generadas = generador.predict(X_pru)
for i in range(49):
  plt.subplot(7,7,i+1)
  plt.axis('off')
  plt.imshow(generadas[i], cmap="binary")
plt.show()
# Out:
# 2/2 [==============================] - 0s 8ms/step

# %%
gan.save("gan.keras")
