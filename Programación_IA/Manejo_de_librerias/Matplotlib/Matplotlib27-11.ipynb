# %% [markdown]
# # **MATPLOT LIB NBA**

# %%
import sys
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

if IN_COLAB:
    # montar el drive, que es donde tenemos el dataset
    from google.colab import drive
    drive.mount("/content/drive")
    data_dir = "/content/drive/MyDrive/2023/Publica/Alumnos/"
    sys.path.append(data_dir)
else:
    import os
    data_dir = os.path.dirname(os.path.abspath('Matplotlib')) + "/"

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

filename = data_dir + "all_seasons.csv"

df = pd.read_csv(filename,usecols=["pts", "reb", "ast"])

# %%
df.head()
# Out:
#     pts  reb  ast
# 0   3.9  1.5  2.4
# 1   3.8  1.3  0.3
# 2   8.3  6.4  1.9
# 3  10.2  2.8  1.7
# 4   2.8  1.7  0.3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12844 entries, 0 to 12843
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pts     12844 non-null  float64
#  1   reb     12844 non-null  float64
#  2   ast     12844 non-null  float64
# dtypes: float64(3)
# memory usage: 301.2 KB

# %%
fig,ax = plt.subplots(figsize=(7,4))
x=df['pts']
y=df['reb']
z=df['ast']
p = ax.scatter(x,y,c=z,s=10,alpha=0.75,cmap='RdBu_r',vmin=z.min(),vmax=z.max())         #S el tamaño de los puntos, alpha difuminación, c es el tercer valor y cmap es el difuminado, vmin y vmax hace que los valores se adapten al tope de asistencias

cb = fig.colorbar(p,ax=ax,label="Asistencias")
ax.set_xlabel('Puntos')                        #Barra de correlación
ax.set_ylabel('Rebotes')
# Out:
# Text(0, 0.5, 'Rebotes')
